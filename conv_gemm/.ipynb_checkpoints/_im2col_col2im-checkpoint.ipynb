# %%
import triton
import triton.language as tl
import torch

# %%
def _out_hw(H, W, KH, KW, SH, SW, PH, PW, DH, DW):
    H_OUT = (H + 2*PH - DH*(KH-1) - 1)//SH + 1
    W_OUT = (W + 2*PW - DW*(KW-1) - 1)//SW + 1
    return H_OUT, W_OUT

# %%
import triton
import triton.language as tl

@triton.jit
def _im2col_kernel_2d(
    x_ptr, cols_ptr,
    N, C, H, W,
    KH, KW, SH, SW, PH, PW, DH, DW,
    H_OUT, W_OUT, K_TOTAL,
    sxn, sxc, sxh, sxw,
    scn, sck, scl,
    BLOCK_X: tl.constexpr,
):
    pid = tl.program_id(0)
    L = H_OUT * W_OUT

    # [n, l] из одномерной сетки
    n = pid // L
    l = pid %  L

    # oh/ow окна и его базовые координаты во входе
    oh = l // W_OUT
    ow = l %  W_OUT
    ih0 = oh * SH - PH
    iw0 = ow * SW - PW

    # Общие константы по этому pid
    base_xn = n * sxn
    base_cols_nl = n * scn + l * scl

    # Основной цикл по K с шагом BLOCK_X
    k0 = 0
    while k0 < K_TOTAL:
        k = k0 + tl.arange(0, BLOCK_X)                      # [BLOCK_X]
        k_mask = k < K_TOTAL

        # Разложение k -> (c, kh, kw)
        r  = k %  (KH * KW)
        c  = k // (KH * KW)
        kh = r // KW
        kw = r %  KW

        # Абсолютные координаты пикселя окна во входе
        ih = ih0 + kh * DH
        iw = iw0 + kw * DW

        # Маска "внутри" входного тензора
        inb = (ih >= 0) & (ih < H) & (iw >= 0) & (iw < W) & k_mask

        # Адреса: x[n, c, ih, iw]
        x_off = base_xn + c * sxc + ih * sxh + iw * sxw

        # Маскированная загрузка (без tl.where — он лишний)
        vals = tl.load(x_ptr + x_off, mask=inb, other=0)

        # Адреса для cols[n, k, l]
        cols_off = base_cols_nl + k * sck

        # Запись с маской
        tl.store(cols_ptr + cols_off, vals, mask=k_mask)

        k0 += BLOCK_X

# %%
def im2col_triton(x, kernel_size, stride=1, padding=0, dilation=1, block_k=256):
    assert x.is_cuda
    if isinstance(kernel_size, int): kernel_size = (kernel_size, kernel_size)
    if isinstance(stride, int): stride = (stride, stride)
    if isinstance(padding, int): padding = (padding, padding)
    if isinstance(dilation, int): dilation = (dilation, dilation)

    N, C, H, W = x.shape
    KH, KW = kernel_size
    SH, SW = stride
    PH, PW = padding
    DH, DW = dilation
    # Выходные  H / W  размеры тензора
    H_OUT, W_OUT = _out_hw(H, W, KH, KW, SH, SW, PH, PW, DH, DW)
    # длина выхожного массива
    L = H_OUT * W_OUT
    #  длинны кернела 
    K_TOTAL = C * KH * KW
    # пустышка выходного тензора
    cols = torch.empty((N, K_TOTAL, L), device=x.device, dtype=torch.float32)
    # страйд по входному массиву
    sxn, sxc, sxh, sxw = x.stride()
    # страйд по выходному массиву
    scn, sck, scl = cols.stride()
    # одномерныя сетка
    grid = (N * L,)
    _im2col_kernel_2d[grid](
        x, cols,
        N, C, H, W,
        KH, KW, SH, SW, PH, PW, DH, DW,
        H_OUT, W_OUT, K_TOTAL,
        sxn, sxc, sxh, sxw,
        scn, sck, scl,
        BLOCK_X=block_k,
        num_warps=4, num_stages=2,
    )
    return cols, (H_OUT, W_OUT)

# %%
import torch
import torch.nn.functional as F


# батч / каналы/ ширина аarray / высота аarray
N, C, H, W = 1, 3, 2000, 2000
# H / W свёртки
KH, KW = 3, 3
# страйд свертки
SH, SW = 1, 1
#  паддинг свертки
PH, PW = 1, 1
# дилатация свертки
DH, DW = 1, 1
#  размер блока НПУ
block_k = 256

# входной тензор N, C, H, W
x = torch.arange(N*C*H*W, dtype=torch.float32, device='cuda').reshape(N, C, H, W)

# базовый unfold
cols_ref = F.unfold(
    x, kernel_size=(KH, KW),
    dilation=(DH, DW),
    padding=(PH, PW),
    stride=(SH, SW)
)

# im2col_triton
cols_tr, (H_out, W_out) = im2col_triton(
    x,
    kernel_size=(KH, KW),
    stride=(SH, SW),
    padding=(PH, PW),
    dilation=(DH, DW),
    block_k=block_k
)

# # проверим совпадение
# print("cols_ref shape:", cols_ref.shape)
# print("cols_tr   shape:", cols_tr.shape)

# max_abs = (cols_tr - cols_ref).abs().max().item()
# print("Макс. разница:", max_abs)
# print("H_out, W_out =", H_out, W_out)

# # убедимся визуально
# print("\nПервый столбец эталон:")
# print(cols_ref[0, :, 0])
# print("\nПервый столбец Triton:")
# print(cols_tr[0, :, 0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 30
#      22 cols_ref = F.unfold(
#      23     x, kernel_size=(KH, KW),
#      24     dilation=(DH, DW),
#      25     padding=(PH, PW),
#      26     stride=(SH, SW)
#      27 )
#      29 # im2col_triton
# ---> 30 cols_tr, (H_out, W_out) = im2col_triton(
#      31     x,
#      32     kernel_size=(KH, KW),
#      33     stride=(SH, SW),
#      34     padding=(PH, PW),
#      35     dilation=(DH, DW),
#      36     block_k=block_k
#      37 )
#      39 # # проверим совпадение
#      40 # print("cols_ref shape:", cols_ref.shape)
#      41 # print("cols_tr   shape:", cols_tr.shape)
#    (...)
#      50 # print("\nПервый столбец Triton:")
#      51 # print(cols_tr[0, :, 0])
#
# Cell In[22], line 27, in im2col_triton(x, kernel_size, stride, padding, dilation, block_k)
#      25 # одномерныя сетка
#      26 grid = (N * L,)
# ---> 27 _im2col_kernel_2d[grid](
#      28     x, cols,
#      29     N, C, H, W,
#      30     KH, KW, SH, SW, PH, PW, DH, DW,
#      31     H_OUT, W_OUT, K_TOTAL,
#      32     sxn, sxc, sxh, sxw,
#      33     scn, sck, scl,
#      34     BLOCK_X=block_k,
#      35     num_warps=4, num_stages=2,
#      36 )
#      37 return cols, (H_OUT, W_OUT)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/triton/runtime/jit.py:390, in KernelInterface.__getitem__.<locals>.<lambda>(*args, **kwargs)
#     384 def __getitem__(self, grid) -> T:
#     385     """
#     386     A JIT function is launched with: fn[grid](*args, **kwargs).
#     387     Hence JITFunction.__getitem__ returns a callable proxy that
#     388     memorizes the grid.
#     389     """
# --> 390     return lambda *args, **kwargs: self.run(grid=grid, warmup=False, *args, **kwargs)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/triton/runtime/jit.py:617, in JITFunction.run(self, grid, warmup, *args, **kwargs)
#     615     # launch kernel
#     616     launch_metadata = kernel.launch_metadata(grid, stream, *bound_args.values())
# --> 617     kernel.run(grid_0, grid_1, grid_2, stream, kernel.function, kernel.packed_metadata, launch_metadata,
#     618                knobs.runtime.launch_enter_hook, knobs.runtime.launch_exit_hook, *bound_args.values())
#     619 return kernel
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/triton/compiler/compiler.py:498, in CompiledKernel.__getattribute__(self, name)
#     496 def __getattribute__(self, name):
#     497     if name == 'run':
# --> 498         self._init_handles()
#     499     return super().__getattribute__(name)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/triton/compiler/compiler.py:490, in CompiledKernel._init_handles(self)
#     488         raise OutOfResources(self.metadata.tmem_size, max_tmem_size, "tensor memory")
#     489 # TODO: n_regs, n_spills should be metadata generated when calling `ptxas`
# --> 490 self.module, self.function, self.n_regs, self.n_spills, self.n_max_threads = driver.active.utils.load_binary(
#     491     self.name, self.kernel, self.metadata.shared, device)
#     492 warp_size = driver.active.get_current_target().warp_size
#     493 if self.metadata.num_warps * warp_size > self.n_max_threads:
#
# RuntimeError: Triton Error [CUDA]: unspecified launch failure

# %%
print("Форма cols_ref:", cols_ref.shape)
print("Один патч 3x3 ", cols_ref[0, :, 0])
print("Первый элемент всех патчей: ",cols_ref[0, 0, :])
# Out:
# Форма cols_ref: torch.Size([1, 27, 4000000])
# Один патч 3x3
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[24], line 2
#       1 print("Форма cols_ref:", cols_ref.shape)
# ----> 2 print("Один патч 3x3 ", cols_ref[0, :, 0])
#       3 print("Первый элемент всех патчей: ",cols_ref[0, 0, :])
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/torch/_tensor.py:590, in Tensor.__repr__(self, tensor_contents)
#     586     return handle_torch_function(
#     587         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     588     )
#     589 # All strings are unicode in Python 3.
# --> 590 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/torch/_tensor_str.py:726, in _str(self, tensor_contents)
#     724 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     725     guard = torch._C._DisableFuncTorch()  # noqa: F841
# --> 726     return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/torch/_tensor_str.py:647, in _str_intern(inp, tensor_contents)
#     645                     tensor_str = _tensor_str(self.to_dense(), indent)
#     646                 else:
# --> 647                     tensor_str = _tensor_str(self, indent)
#     649 if self.layout != torch.strided:
#     650     suffixes.append("layout=" + str(self.layout))
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/torch/_tensor_str.py:379, in _tensor_str(self, indent)
#     375     return _tensor_str_with_formatter(
#     376         self, indent, summarize, real_formatter, imag_formatter
#     377     )
#     378 else:
# --> 379     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     380     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/ITMO/EDLM/venv/lib/python3.10/site-packages/torch/_tensor_str.py:155, in _Formatter.__init__(self, tensor)
#     146 if tensor.dtype == torch.float4_e2m1fn_x2:  # type: ignore[attr-defined]
#     147     # torch.float4_e2m1fn_x2 is special and does not support the casts necessary
#     148     # to print it, we choose to display the uint8 representation here for
#     149     # convenience of being able to print a tensor.
#     150     # TODO(#146647): extend this to other dtypes without casts defined, such
#     151     # as the bits, uint1..7 and int1..7 dtypes.
#     152     tensor_view = tensor_view.view(torch.uint8)
#     154 nonzero_finite_vals = torch.masked_select(
# --> 155     tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0)
#     156 )
#     158 if nonzero_finite_vals.numel() == 0:
#     159     # no valid number, do nothing
#     160     return
#
# AcceleratorError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# %%time
# входной тензор N, C, H, W
x = torch.arange(N*C*H*W, dtype=torch.float32, device='cuda').reshape(N, C, H, W)
for _ in range(1000):
    cols_tr, (H_out, W_out) = im2col_triton(
    x,
    kernel_size=(KH, KW),
    stride=(SH, SW),
    padding=(PH, PW),
    dilation=(DH, DW),
    block_k=block_k
)
# Out:
# CPU times: user 2.93 s, sys: 7.91 s, total: 10.8 s
# Wall time: 10.8 s

# %%
# %%time
# входной тензор N, C, H, W
x = torch.arange(N*C*H*W, dtype=torch.float32, device='cuda').reshape(N, C, H, W)
for _ in range(1000):
    # базовый unfold
    cols_ref = F.unfold(
        x, kernel_size=(KH, KW),
        dilation=(DH, DW),
        padding=(PH, PW),
        stride=(SH, SW)
    )
# Out:
# CPU times: user 4.18 s, sys: 11 s, total: 15.2 s
# Wall time: 15.2 s
