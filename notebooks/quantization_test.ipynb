# %% [markdown]
# # INT8 Conv2d (inference): поиск быстрых конфигураций
#
# Этот ноутбук перебирает конфигурации INT8-свёртки (`TritonConv2dINT8`) и сравнивает их по скорости и точности с FP32/FP16 эталоном. Квантизация предполагается готовой: вход `x_q` и веса `w_q` — симметричные int8 (scale из `act_scale` и `weight_scale`), аккумуляция int32, де-квант в FP32 + bias. Backward не реализован. Все замеры на CUDA, с прогревом.
#
# **Метрики, которые считаются и выводятся:**
# - `time_ms` — среднее время forward INT8-свёртки, мс.
# - (Если есть) `torch_time_ms` — время референса (FP32/FP16 Conv2d).
# - `speedup_vs_ref` или аналогичный столбец — отношение времени референса к INT8; >1 — INT8 быстрее.
# - Ошибки относительно референса:
#   - `mae` — средняя абсолютная ошибка.
#   - `max` — максимальное абсолютное отклонение.
#   - `rel_l2` — относительная L2-норма ошибки.
# - Конфигурация задачи: размеры ядра/входа/батча, Cin/Cout, stride/padding/dilation.
# - Конфигурация Triton блоков: `BLOCK_M`, `BLOCK_N`, `BLOCK_K`, `NUM_WARPS`, `NUM_STAGES` (для img2col_int8, GEMM int8, col2img_int32).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))
print('sys.path[0]=', sys.path[0])
# Out:
# sys.path[0]= /home/manzhura/ITMO/EDLM/conv2d-img2col-gemm

# %%
import torch
import itertools
from typing import List, Dict
import torch.nn as nn
import torch.nn.functional as F
import time
import itertools
import pandas as pd
from tqdm import tqdm

# %%
from conv_gemm.baseline_layers.triton_conv2d_int8 import TritonConv2dINT8

# %%
device = "cuda"
assert torch.cuda.is_available(), "Нужен CUDA для бенчмарка"
torch.manual_seed(0)
torch.cuda.manual_seed(0)

# %%
def bench_forward(layer: nn.Module,
                  x: torch.Tensor,
                  warmup: int = 5,
                  iters: int = 50) -> float:

    layer.eval()
    with torch.no_grad():
        # warmup
        for _ in range(warmup):
            _ = layer(x)
        torch.cuda.synchronize()

        # timed runs
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)
        start.record()
        for _ in range(iters):
            _ = layer(x)
        end.record()
        torch.cuda.synchronize()

        elapsed_ms = start.elapsed_time(end)  
        return elapsed_ms / iters

# %%
def symmetric_scale(x_fp: torch.Tensor, eps: float = 1e-8) -> torch.Tensor:

    x_max = x_fp.abs().max()
    s = x_max / 127.0 + eps
    return s

# %% [markdown]
# #   search ranges

# %%
def make_config_grid() -> List[Dict[str, int]]:

    batch_sizes = [1, 4, 8, 16]
    in_channels = [1, 3, 8, 16, 32]
    out_channels = [3, 8, 16, 32, 64]
    image_sizes = [32, 64, 128, 256, 512]  
    kernels = [1, 3, 5, 7, 9, 11]           
    strides = [1, 2]

    cfgs = []
    for N, Cin, Cout, H, K, S in itertools.product(
        batch_sizes, in_channels, out_channels, image_sizes, kernels, strides
    ):
        if Cin > Cout:
            continue

        if H >= 256 and K >= 9:
            continue  

        if H == 512 and K >= 7:
            continue  
        if H == 512 and N >= 16:
            continue

        P = K // 2 
        cfgs.append({
            "N": N,
            "Cin": Cin,
            "Cout": Cout,
            "H": H,
            "K": K,
            "S": S,
            "P": P,
        })
    return cfgs

# %% [markdown]
# ### Что будет посчитано в гриде INT8
#
# Перебираются комбинации (Kh/Kw, Cin/Cout, H/W/B, stride/padding/dilation, BLOCK_*). Для каждой:
# - Замер `time_ms` INT8 forward.
# - Сравнение с референсом: `mae`, `max`, `rel_l2` (и `speedup_vs_ref`, если референс меряется).
# - Параметры конфигурации записываются в DataFrame `df_int8`.
# Эта таблица позволит отобрать быстрые и точные варианты.

# %%
def run_int8_conv_benchmark(
    warmup: int = 5,
    iters: int = 50,
) -> pd.DataFrame:

    rows: List[Dict[str, float]] = []
    cfgs = make_config_grid()
    total = len(cfgs)


    for idx, cfg in enumerate(cfgs, start=1):
        N   = cfg["N"]
        Cin = cfg["Cin"]
        Cout = cfg["Cout"]
        H   = cfg["H"]
        K   = cfg["K"]
        S   = cfg["S"]
        P   = cfg["P"]

        try:
            
            x_fp16 = torch.randn(N, Cin, H, H, device=device, dtype=torch.float16)
            # torch fp16
            conv_fp = nn.Conv2d(
                in_channels=Cin,
                out_channels=Cout,
                kernel_size=K,
                stride=S,
                padding=P,
                bias=True,
            ).to(device=device, dtype=torch.float16)

            # квантование весов и активаций
            with torch.no_grad():
                act_scale = symmetric_scale(x_fp16.float())
                w_fp32 = conv_fp.weight.detach().float()
                w_scale = symmetric_scale(w_fp32)
                w_q = torch.clamp(torch.round(w_fp32 / w_scale), -128, 127).to(torch.int8)

            # Triton INT8
            conv_int8 = TritonConv2dINT8(
                in_channels=Cin,
                out_channels=Cout,
                kernel_size=K,
                stride=S,
                padding=P,
                dilation=1,
                bias=True,
            ).to(device)

            with torch.no_grad():
                conv_int8.load_quant_params(
                    w_q=w_q,
                    w_scale=w_scale.to(device),
                    act_scale=act_scale.to(device),
                    bias=conv_fp.bias.detach().to(torch.float32),
                )
                x_q = conv_int8.quantize_input(x_fp16)

                # ошибка
                y_ref = conv_fp(x_fp16).float()
                y_int8 = conv_int8(x_q).float()
                diff = (y_ref - y_int8).abs()
                mae = diff.mean().item()
                max_err = diff.max().item()

            # бенч
            t_torch_ms = bench_forward(conv_fp, x_fp16, warmup=warmup, iters=iters)
            t_triton_ms = bench_forward(conv_int8, x_q, warmup=warmup, iters=iters)
            speedup = t_torch_ms / t_triton_ms if t_triton_ms > 0 else float("nan")

            print(
                f"[{idx}/{total}] "
                f"N={N}, Cin={Cin}, Cout={Cout}, H={H}, K={K}, S={S}, P={P} | "
                f"Torch={t_torch_ms:.4f} ms, Triton={t_triton_ms:.4f} ms | "
                f"Speedup={speedup:.4f} | MAE={mae:.5f}"
            )

            rows.append({
                "N": N,
                "Cin": Cin,
                "Cout": Cout,
                "H": H,
                "K": K,
                "S": S,
                "P": P,
                "t_torch_ms": t_torch_ms,
                "t_triton_ms": t_triton_ms,
                "speedup": speedup,
                "mae": mae,
                "max_err": max_err,
                "shape": f"{N} / {Cin}→{Cout} / {H} / {K} / {S} / {P}",
            })

        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                print(
                    f"[{idx}/{total}] OOM: "
                    f"N={N}, Cin={Cin}, Cout={Cout}, H={H}, K={K}, S={S}, P={P} — skip"
                )
                torch.cuda.empty_cache()
                continue
            else:
                raise

    df = pd.DataFrame(rows)
    print("\n>>> Benchmark completed.")
    return df

# %%
df_int8 = run_int8_conv_benchmark(warmup=5, iters=50)
# Out:
# >>> Starting INT8 benchmark: 3686 configurations
#
# [1/3686] N=1, Cin=1, Cout=3, H=32, K=1, S=1, P=0 | Torch=0.0276 ms, Triton=0.2711 ms | Speedup=0.1020 | MAE=0.00215
# [2/3686] N=1, Cin=1, Cout=3, H=32, K=1, S=2, P=0 | Torch=0.0310 ms, Triton=0.2817 ms | Speedup=0.1102 | MAE=0.00310
# [3/3686] N=1, Cin=1, Cout=3, H=32, K=3, S=1, P=1 | Torch=0.0352 ms, Triton=0.2441 ms | Speedup=0.1440 | MAE=0.00523
# [4/3686] N=1, Cin=1, Cout=3, H=32, K=3, S=2, P=1 | Torch=0.0232 ms, Triton=0.2357 ms | Speedup=0.0983 | MAE=0.00421
# [5/3686] N=1, Cin=1, Cout=3, H=32, K=5, S=1, P=2 | Torch=0.0262 ms, Triton=0.2453 ms | Speedup=0.1069 | MAE=0.00429
# [6/3686] N=1, Cin=1, Cout=3, H=32, K=5, S=2, P=2 | Torch=0.0261 ms, Triton=0.2361 ms | Speedup=0.1106 | MAE=0.00354
# [7/3686] N=1, Cin=1, Cout=3, H=32, K=7, S=1, P=3 | Torch=0.0256 ms, Triton=0.2348 ms | Speedup=0.1089 | MAE=0.00395
# [8/3686] N=1, Cin=1, Cout=3, H=32, K=7, S=2, P=3 | Torch=0.0256 ms, Triton=0.2334 ms | Speedup=0.1096 | MAE=0.00344
# [9/3686] N=1, Cin=1, Cout=3, H=32, K=9, S=1, P=4 | Torch=0.0261 ms, Triton=0.2426 ms | Speedup=0.1074 | MAE=0.00352
# [10/3686] N=1, Cin=1, Cout=3, H=32, K=9, S=2, P=4 | Torch=0.0260 ms, Triton=0.2403 ms | Speedup=0.1082 | MAE=0.00425
# [11/3686] N=1, Cin=1, Cout=3, H=32, K=11, S=1, P=5 | Torch=0.0256 ms, Triton=0.2408 ms | Speedup=0.1065 | MAE=0.00353
# [12/3686] N=1, Cin=1, Cout=3, H=32, K=11, S=2, P=5 | Torch=0.0252 ms, Triton=0.2476 ms | Speedup=0.1017 | MAE=0.00381
# [13/3686] N=1, Cin=1, Cout=3, H=64, K=1, S=1, P=0 | Torch=0.0269 ms, Triton=0.2301 ms | Speedup=0.1168 | MAE=0.00531
# [14/3686] N=1, Cin=1, Cout=3, H=64, K=1, S=2, P=0 | Torch=0.0259 ms, Triton=0.2313 ms | Speedup=0.1118 | MAE=0.00284
# [15/3686] N=1, Cin=1, Cout=3, H=64, K=3, S=1, P=1 | Torch=0.0258 ms, Triton=0.2423 ms | Speedup=0.1063 | MAE=0.00528
# [16/3686] N=1, Cin=1, Cout=3, H=64, K=3, S=2, P=1 | Torch=0.0254 ms, Triton=0.2332 ms | Speedup=0.1091 | MAE=0.00332
# [17/3686] N=1, Cin=1, Cout=3, H=64, K=5, S=1, P=2 | Torch=0.0256 ms, Triton=0.2361 ms | Speedup=0.1083 | MAE=0.00444
# [18/3686] N=1, Cin=1, Cout=3, H=64, K=5, S=2, P=2 | Torch=0.0235 ms, Triton=0.2284 ms | Speedup=0.1029 | MAE=0.00420
# [19/3686] N=1, Cin=1, Cout=3, H=64, K=7, S=1, P=3 | Torch=0.0251 ms, Triton=0.2362 ms | Speedup=0.1064 | MAE=0.00433
# [20/3686] N=1, Cin=1, Cout=3, H=64, K=7, S=2, P=3 | Torch=0.0261 ms, Triton=0.2323 ms | Speedup=0.1123 | MAE=0.00453
# [21/3686] N=1, Cin=1, Cout=3, H=64, K=9, S=1, P=4 | Torch=0.0253 ms, Triton=0.2389 ms | Speedup=0.1061 | MAE=0.00387
# [22/3686] N=1, Cin=1, Cout=3, H=64, K=9, S=2, P=4 | Torch=0.0231 ms, Triton=0.2257 ms | Speedup=0.1025 | MAE=0.00450
# [23/3686] N=1, Cin=1, Cout=3, H=64, K=11, S=1, P=5 | Torch=0.0230 ms, Triton=0.2297 ms | Speedup=0.1002 | MAE=0.00432
# [24/3686] N=1, Cin=1, Cout=3, H=64, K=11, S=2, P=5 | Torch=0.0251 ms, Triton=0.2315 ms | Speedup=0.1084 | MAE=0.00412
# [25/3686] N=1, Cin=1, Cout=3, H=128, K=1, S=1, P=0 | Torch=0.0231 ms, Triton=0.2358 ms | Speedup=0.0981 | MAE=0.00277
# [26/3686] N=1, Cin=1, Cout=3, H=128, K=1, S=2, P=0 | Torch=0.0239 ms, Triton=0.2270 ms | Speedup=0.1055 | MAE=0.00529
# [27/3686] N=1, Cin=1, Cout=3, H=128, K=3, S=1, P=1 | Torch=0.0310 ms, Triton=0.2595 ms | Speedup=0.1194 | MAE=0.00416
# [28/3686] N=1, Cin=1, Cout=3, H=128, K=3, S=2, P=1 | Torch=0.0232 ms, Triton=0.2399 ms | Speedup=0.0967 | MAE=0.00437
# [29/3686] N=1, Cin=1, Cout=3, H=128, K=5, S=1, P=2 | Torch=0.0236 ms, Triton=0.2475 ms | Speedup=0.0951 | MAE=0.00475
# [30/3686] N=1, Cin=1, Cout=3, H=128, K=5, S=2, P=2 | Torch=0.0234 ms, Triton=0.2291 ms | Speedup=0.1023 | MAE=0.00410
# [31/3686] N=1, Cin=1, Cout=3, H=128, K=7, S=1, P=3 | Torch=0.0234 ms, Triton=0.2481 ms | Speedup=0.0944 | MAE=0.00498
# [32/3686] N=1, Cin=1, Cout=3, H=128, K=7, S=2, P=3 | Torch=0.0232 ms, Triton=0.2276 ms | Speedup=0.1018 | MAE=0.00438
# [33/3686] N=1, Cin=1, Cout=3, H=128, K=9, S=1, P=4 | Torch=0.0234 ms, Triton=0.2596 ms | Speedup=0.0902 | MAE=0.00554
# [34/3686] N=1, Cin=1, Cout=3, H=128, K=9, S=2, P=4 | Torch=0.0234 ms, Triton=0.2261 ms | Speedup=0.1037 | MAE=0.00495
# [35/3686] N=1, Cin=1, Cout=3, H=128, K=11, S=1, P=5 | Torch=0.0273 ms, Triton=0.2910 ms | Speedup=0.0937 | MAE=0.00460
# [36/3686] N=1, Cin=1, Cout=3, H=128, K=11, S=2, P=5 | Torch=0.0232 ms, Triton=0.2308 ms | Speedup=0.1007 | MAE=0.00422
# [37/3686] N=1, Cin=1, Cout=3, H=256, K=1, S=1, P=0 | Torch=0.0265 ms, Triton=0.2847 ms | Speedup=0.0932 | MAE=0.00489
# [38/3686] N=1, Cin=1, Cout=3, H=256, K=1, S=2, P=0 | Torch=0.0236 ms, Triton=0.2331 ms | Speedup=0.1012 | MAE=0.00449
# [39/3686] N=1, Cin=1, Cout=3, H=256, K=3, S=1, P=1 | Torch=0.0237 ms, Triton=0.3292 ms | Speedup=0.0718 | MAE=0.00528
# [40/3686] N=1, Cin=1, Cout=3, H=256, K=3, S=2, P=1 | Torch=0.0301 ms, Triton=0.2467 ms | Speedup=0.1219 | MAE=0.00538
# [41/3686] N=1, Cin=1, Cout=3, H=256, K=5, S=1, P=2 | Torch=0.0238 ms, Triton=0.3055 ms | Speedup=0.0779 | MAE=0.00450
# [42/3686] N=1, Cin=1, Cout=3, H=256, K=5, S=2, P=2 | Torch=0.0235 ms, Triton=0.2426 ms | Speedup=0.0970 | MAE=0.00468
# [43/3686] N=1, Cin=1, Cout=3, H=256, K=7, S=1, P=3 | Torch=0.0255 ms, Triton=0.3459 ms | Speedup=0.0738 | MAE=0.00565
# [44/3686] N=1, Cin=1, Cout=3, H=256, K=7, S=2, P=3 | Torch=0.0237 ms, Triton=0.2511 ms | Speedup=0.0944 | MAE=0.00435
# [45/3686] N=1, Cin=1, Cout=3, H=512, K=1, S=1, P=0 | Torch=0.0263 ms, Triton=0.4896 ms | Speedup=0.0537 | MAE=0.00253
# [46/3686] N=1, Cin=1, Cout=3, H=512, K=1, S=2, P=0 | Torch=0.0240 ms, Triton=0.2881 ms | Speedup=0.0833 | MAE=0.00685
# [47/3686] N=1, Cin=1, Cout=3, H=512, K=3, S=1, P=1 | Torch=0.0396 ms, Triton=0.6015 ms | Speedup=0.0658 | MAE=0.00576
# [48/3686] N=1, Cin=1, Cout=3, H=512, K=3, S=2, P=1 | Torch=0.0237 ms, Triton=0.3062 ms | Speedup=0.0773 | MAE=0.00638
# [49/3686] N=1, Cin=1, Cout=3, H=512, K=5, S=1, P=2 | Torch=0.0575 ms, Triton=0.6295 ms | Speedup=0.0913 | MAE=0.00487
# [50/3686] N=1, Cin=1, Cout=3, H=512, K=5, S=2, P=2 | Torch=0.0237 ms, Triton=0.3210 ms | Speedup=0.0739 | MAE=0.00513
# [51/3686] N=1, Cin=1, Cout=8, H=32, K=1, S=1, P=0 | Torch=0.0232 ms, Triton=0.2103 ms | Speedup=0.1105 | MAE=0.00455
# [52/3686] N=1, Cin=1, Cout=8, H=32, K=1, S=2, P=0 | Torch=0.0229 ms, Triton=0.2099 ms | Speedup=0.1090 | MAE=0.00399
# [53/3686] N=1, Cin=1, Cout=8, H=32, K=3, S=1, P=1 | Torch=0.0231 ms, Triton=0.2185 ms | Speedup=0.1056 | MAE=0.00412
# [54/3686] N=1, Cin=1, Cout=8, H=32, K=3, S=2, P=1 | Torch=0.0232 ms, Triton=0.2194 ms | Speedup=0.1058 | MAE=0.00412
# [55/3686] N=1, Cin=1, Cout=8, H=32, K=5, S=1, P=2 | Torch=0.0251 ms, Triton=0.2196 ms | Speedup=0.1145 | MAE=0.00445
# [56/3686] N=1, Cin=1, Cout=8, H=32, K=5, S=2, P=2 | Torch=0.0234 ms, Triton=0.2212 ms | Speedup=0.1060 | MAE=0.00358
# [57/3686] N=1, Cin=1, Cout=8, H=32, K=7, S=1, P=3 | Torch=0.0234 ms, Triton=0.2217 ms | Speedup=0.1058 | MAE=0.00342
# [58/3686] N=1, Cin=1, Cout=8, H=32, K=7, S=2, P=3 | Torch=0.0235 ms, Triton=0.2211 ms | Speedup=0.1061 | MAE=0.00366
# [59/3686] N=1, Cin=1, Cout=8, H=32, K=9, S=1, P=4 | Torch=0.0234 ms, Triton=0.2288 ms | Speedup=0.1024 | MAE=0.00395
# [60/3686] N=1, Cin=1, Cout=8, H=32, K=9, S=2, P=4 | Torch=0.0228 ms, Triton=0.2247 ms | Speedup=0.1016 | MAE=0.00326
# [61/3686] N=1, Cin=1, Cout=8, H=32, K=11, S=1, P=5 | Torch=0.0250 ms, Triton=0.2243 ms | Speedup=0.1113 | MAE=0.00381
# [62/3686] N=1, Cin=1, Cout=8, H=32, K=11, S=2, P=5 | Torch=0.0230 ms, Triton=0.2252 ms | Speedup=0.1022 | MAE=0.00365
# [63/3686] N=1, Cin=1, Cout=8, H=64, K=1, S=1, P=0 | Torch=0.0235 ms, Triton=0.2410 ms | Speedup=0.0976 | MAE=0.00512
# [64/3686] N=1, Cin=1, Cout=8, H=64, K=1, S=2, P=0 | Torch=0.0243 ms, Triton=0.2213 ms | Speedup=0.1098 | MAE=0.00506
# [65/3686] N=1, Cin=1, Cout=8, H=64, K=3, S=1, P=1 | Torch=0.0238 ms, Triton=0.2249 ms | Speedup=0.1058 | MAE=0.00412
# [66/3686] N=1, Cin=1, Cout=8, H=64, K=3, S=2, P=1 | Torch=0.0234 ms, Triton=0.2164 ms | Speedup=0.1080 | MAE=0.00444
# [67/3686] N=1, Cin=1, Cout=8, H=64, K=5, S=1, P=2 | Torch=0.0234 ms, Triton=0.2251 ms | Speedup=0.1038 | MAE=0.00416
# [68/3686] N=1, Cin=1, Cout=8, H=64, K=5, S=2, P=2 | Torch=0.0234 ms, Triton=0.2171 ms | Speedup=0.1078 | MAE=0.00421
# [69/3686] N=1, Cin=1, Cout=8, H=64, K=7, S=1, P=3 | Torch=0.0235 ms, Triton=0.2339 ms | Speedup=0.1006 | MAE=0.00419
# [70/3686] N=1, Cin=1, Cout=8, H=64, K=7, S=2, P=3 | Torch=0.0260 ms, Triton=0.2311 ms | Speedup=0.1124 | MAE=0.00422
# [71/3686] N=1, Cin=1, Cout=8, H=64, K=9, S=1, P=4 | Torch=0.0260 ms, Triton=0.2394 ms | Speedup=0.1085 | MAE=0.00408
# [72/3686] N=1, Cin=1, Cout=8, H=64, K=9, S=2, P=4 | Torch=0.0260 ms, Triton=0.2394 ms | Speedup=0.1086 | MAE=0.00424
# [73/3686] N=1, Cin=1, Cout=8, H=64, K=11, S=1, P=5 | Torch=0.0262 ms, Triton=0.2387 ms | Speedup=0.1096 | MAE=0.00436
# [74/3686] N=1, Cin=1, Cout=8, H=64, K=11, S=2, P=5 | Torch=0.0256 ms, Triton=0.2376 ms | Speedup=0.1077 | MAE=0.00376
# [75/3686] N=1, Cin=1, Cout=8, H=128, K=1, S=1, P=0 | Torch=0.0262 ms, Triton=0.2453 ms | Speedup=0.1069 | MAE=0.00563
# [76/3686] N=1, Cin=1, Cout=8, H=128, K=1, S=2, P=0 | Torch=0.0259 ms, Triton=0.2240 ms | Speedup=0.1157 | MAE=0.00428
# [77/3686] N=1, Cin=1, Cout=8, H=128, K=3, S=1, P=1 | Torch=0.0261 ms, Triton=0.2514 ms | Speedup=0.1040 | MAE=0.00416
# [78/3686] N=1, Cin=1, Cout=8, H=128, K=3, S=2, P=1 | Torch=0.0232 ms, Triton=0.2266 ms | Speedup=0.1025 | MAE=0.00454
# [79/3686] N=1, Cin=1, Cout=8, H=128, K=5, S=1, P=2 | Torch=0.0240 ms, Triton=0.2471 ms | Speedup=0.0971 | MAE=0.00447
# [80/3686] N=1, Cin=1, Cout=8, H=128, K=5, S=2, P=2 | Torch=0.0237 ms, Triton=0.2269 ms | Speedup=0.1045 | MAE=0.00499
# [81/3686] N=1, Cin=1, Cout=8, H=128, K=7, S=1, P=3 | Torch=0.0231 ms, Triton=0.2501 ms | Speedup=0.0924 | MAE=0.00449
# [82/3686] N=1, Cin=1, Cout=8, H=128, K=7, S=2, P=3 | Torch=0.0233 ms, Triton=0.2292 ms | Speedup=0.1015 | MAE=0.00494
# [83/3686] N=1, Cin=1, Cout=8, H=128, K=9, S=1, P=4 | Torch=0.0267 ms, Triton=0.2607 ms | Speedup=0.1026 | MAE=0.00448
# [84/3686] N=1, Cin=1, Cout=8, H=128, K=9, S=2, P=4 | Torch=0.0231 ms, Triton=0.2270 ms | Speedup=0.1016 | MAE=0.00463
# [85/3686] N=1, Cin=1, Cout=8, H=128, K=11, S=1, P=5 | Torch=0.0348 ms, Triton=0.2846 ms | Speedup=0.1222 | MAE=0.00473
# [86/3686] N=1, Cin=1, Cout=8, H=128, K=11, S=2, P=5 | Torch=0.0238 ms, Triton=0.2299 ms | Speedup=0.1037 | MAE=0.00422
# [87/3686] N=1, Cin=1, Cout=8, H=256, K=1, S=1, P=0 | Torch=0.0237 ms, Triton=0.2919 ms | Speedup=0.0810 | MAE=0.00437
# [88/3686] N=1, Cin=1, Cout=8, H=256, K=1, S=2, P=0 | Torch=0.0240 ms, Triton=0.2384 ms | Speedup=0.1007 | MAE=0.00409
# [89/3686] N=1, Cin=1, Cout=8, H=256, K=3, S=1, P=1 | Torch=0.0288 ms, Triton=0.3209 ms | Speedup=0.0897 | MAE=0.00498
# [90/3686] N=1, Cin=1, Cout=8, H=256, K=3, S=2, P=1 | Torch=0.0333 ms, Triton=0.2506 ms | Speedup=0.1328 | MAE=0.00500
# [91/3686] N=1, Cin=1, Cout=8, H=256, K=5, S=1, P=2 | Torch=0.0289 ms, Triton=0.3340 ms | Speedup=0.0866 | MAE=0.00489
# [92/3686] N=1, Cin=1, Cout=8, H=256, K=5, S=2, P=2 | Torch=0.0265 ms, Triton=0.2577 ms | Speedup=0.1027 | MAE=0.00477
# [93/3686] N=1, Cin=1, Cout=8, H=256, K=7, S=1, P=3 | Torch=0.0419 ms, Triton=0.3495 ms | Speedup=0.1199 | MAE=0.00488
# [94/3686] N=1, Cin=1, Cout=8, H=256, K=7, S=2, P=3 | Torch=0.0270 ms, Triton=0.2610 ms | Speedup=0.1036 | MAE=0.00557
# [95/3686] N=1, Cin=1, Cout=8, H=512, K=1, S=1, P=0 | Torch=0.0462 ms, Triton=0.5885 ms | Speedup=0.0786 | MAE=0.00497
# [96/3686] N=1, Cin=1, Cout=8, H=512, K=1, S=2, P=0 | Torch=0.0237 ms, Triton=0.2891 ms | Speedup=0.0820 | MAE=0.00665
# [97/3686] N=1, Cin=1, Cout=8, H=512, K=3, S=1, P=1 | Torch=0.0685 ms, Triton=0.7217 ms | Speedup=0.0949 | MAE=0.00552
# [98/3686] N=1, Cin=1, Cout=8, H=512, K=3, S=2, P=1 | Torch=0.0236 ms, Triton=0.3032 ms | Speedup=0.0777 | MAE=0.00484
# [99/3686] N=1, Cin=1, Cout=8, H=512, K=5, S=1, P=2 | Torch=0.1013 ms, Triton=0.7597 ms | Speedup=0.1333 | MAE=0.00477
# [100/3686] N=1, Cin=1, Cout=8, H=512, K=5, S=2, P=2 | Torch=0.0289 ms, Triton=0.3279 ms | Speedup=0.0881 | MAE=0.00548
# [101/3686] N=1, Cin=1, Cout=16, H=32, K=1, S=1, P=0 | Torch=0.0253 ms, Triton=0.2214 ms | Speedup=0.1144 | MAE=0.00403
# [102/3686] N=1, Cin=1, Cout=16, H=32, K=1, S=2, P=0 | Torch=0.0250 ms, Triton=0.2247 ms | Speedup=0.1115 | MAE=0.00317
# [103/3686] N=1, Cin=1, Cout=16, H=32, K=3, S=1, P=1 | Torch=0.0265 ms, Triton=0.2307 ms | Speedup=0.1147 | MAE=0.00429
# [104/3686] N=1, Cin=1, Cout=16, H=32, K=3, S=2, P=1 | Torch=0.0238 ms, Triton=0.2304 ms | Speedup=0.1034 | MAE=0.00443
# [105/3686] N=1, Cin=1, Cout=16, H=32, K=5, S=1, P=2 | Torch=0.0280 ms, Triton=0.2323 ms | Speedup=0.1204 | MAE=0.00428
# [106/3686] N=1, Cin=1, Cout=16, H=32, K=5, S=2, P=2 | Torch=0.0263 ms, Triton=0.2313 ms | Speedup=0.1135 | MAE=0.00343
# [107/3686] N=1, Cin=1, Cout=16, H=32, K=7, S=1, P=3 | Torch=0.0262 ms, Triton=0.2327 ms | Speedup=0.1127 | MAE=0.00333
# [108/3686] N=1, Cin=1, Cout=16, H=32, K=7, S=2, P=3 | Torch=0.0261 ms, Triton=0.2336 ms | Speedup=0.1116 | MAE=0.00371
# [109/3686] N=1, Cin=1, Cout=16, H=32, K=9, S=1, P=4 | Torch=0.0262 ms, Triton=0.2421 ms | Speedup=0.1082 | MAE=0.00399
# [110/3686] N=1, Cin=1, Cout=16, H=32, K=9, S=2, P=4 | Torch=0.0238 ms, Triton=0.2498 ms | Speedup=0.0954 | MAE=0.00350
# [111/3686] N=1, Cin=1, Cout=16, H=32, K=11, S=1, P=5 | Torch=0.0258 ms, Triton=0.2315 ms | Speedup=0.1115 | MAE=0.00352
# [112/3686] N=1, Cin=1, Cout=16, H=32, K=11, S=2, P=5 | Torch=0.0231 ms, Triton=0.2494 ms | Speedup=0.0927 | MAE=0.00342
# [113/3686] N=1, Cin=1, Cout=16, H=64, K=1, S=1, P=0 | Torch=0.0375 ms, Triton=0.2568 ms | Speedup=0.1462 | MAE=0.00303
# [114/3686] N=1, Cin=1, Cout=16, H=64, K=1, S=2, P=0 | Torch=0.0333 ms, Triton=0.2549 ms | Speedup=0.1306 | MAE=0.00429
# [115/3686] N=1, Cin=1, Cout=16, H=64, K=3, S=1, P=1 | Torch=0.0238 ms, Triton=0.2543 ms | Speedup=0.0937 | MAE=0.00448
# [116/3686] N=1, Cin=1, Cout=16, H=64, K=3, S=2, P=1 | Torch=0.0244 ms, Triton=0.2392 ms | Speedup=0.1021 | MAE=0.00418
# [117/3686] N=1, Cin=1, Cout=16, H=64, K=5, S=1, P=2 | Torch=0.0232 ms, Triton=0.2529 ms | Speedup=0.0918 | MAE=0.00434
# [118/3686] N=1, Cin=1, Cout=16, H=64, K=5, S=2, P=2 | Torch=0.0244 ms, Triton=0.2362 ms | Speedup=0.1031 | MAE=0.00418
# [119/3686] N=1, Cin=1, Cout=16, H=64, K=7, S=1, P=3 | Torch=0.0266 ms, Triton=0.2644 ms | Speedup=0.1007 | MAE=0.00397
# [120/3686] N=1, Cin=1, Cout=16, H=64, K=7, S=2, P=3 | Torch=0.0253 ms, Triton=0.2306 ms | Speedup=0.1098 | MAE=0.00432
# [121/3686] N=1, Cin=1, Cout=16, H=64, K=9, S=1, P=4 | Torch=0.0241 ms, Triton=0.2390 ms | Speedup=0.1009 | MAE=0.00423
# [122/3686] N=1, Cin=1, Cout=16, H=64, K=9, S=2, P=4 | Torch=0.0240 ms, Triton=0.2326 ms | Speedup=0.1031 | MAE=0.00410
# [123/3686] N=1, Cin=1, Cout=16, H=64, K=11, S=1, P=5 | Torch=0.0237 ms, Triton=0.2387 ms | Speedup=0.0994 | MAE=0.00404
# [124/3686] N=1, Cin=1, Cout=16, H=64, K=11, S=2, P=5 | Torch=0.0239 ms, Triton=0.2385 ms | Speedup=0.1000 | MAE=0.00378
# [125/3686] N=1, Cin=1, Cout=16, H=128, K=1, S=1, P=0 | Torch=0.0325 ms, Triton=0.2533 ms | Speedup=0.1283 | MAE=0.00481
# [126/3686] N=1, Cin=1, Cout=16, H=128, K=1, S=2, P=0 | Torch=0.0240 ms, Triton=0.2216 ms | Speedup=0.1082 | MAE=0.00372
# [127/3686] N=1, Cin=1, Cout=16, H=128, K=3, S=1, P=1 | Torch=0.0239 ms, Triton=0.2507 ms | Speedup=0.0952 | MAE=0.00476
# [128/3686] N=1, Cin=1, Cout=16, H=128, K=3, S=2, P=1 | Torch=0.0234 ms, Triton=0.2244 ms | Speedup=0.1042 | MAE=0.00452
# [129/3686] N=1, Cin=1, Cout=16, H=128, K=5, S=1, P=2 | Torch=0.0236 ms, Triton=0.2497 ms | Speedup=0.0946 | MAE=0.00510
# [130/3686] N=1, Cin=1, Cout=16, H=128, K=5, S=2, P=2 | Torch=0.0234 ms, Triton=0.2282 ms | Speedup=0.1026 | MAE=0.00455
# [131/3686] N=1, Cin=1, Cout=16, H=128, K=7, S=1, P=3 | Torch=0.0235 ms, Triton=0.2664 ms | Speedup=0.0883 | MAE=0.00459
# [132/3686] N=1, Cin=1, Cout=16, H=128, K=7, S=2, P=3 | Torch=0.0238 ms, Triton=0.2286 ms | Speedup=0.1042 | MAE=0.00507
# [133/3686] N=1, Cin=1, Cout=16, H=128, K=9, S=1, P=4 | Torch=0.0241 ms, Triton=0.2728 ms | Speedup=0.0885 | MAE=0.00458
# [134/3686] N=1, Cin=1, Cout=16, H=128, K=9, S=2, P=4 | Torch=0.0239 ms, Triton=0.2305 ms | Speedup=0.1038 | MAE=0.00490
# [135/3686] N=1, Cin=1, Cout=16, H=128, K=11, S=1, P=5 | Torch=0.0271 ms, Triton=0.3023 ms | Speedup=0.0897 | MAE=0.00541
# [136/3686] N=1, Cin=1, Cout=16, H=128, K=11, S=2, P=5 | Torch=0.0238 ms, Triton=0.2285 ms | Speedup=0.1042 | MAE=0.00461
# [137/3686] N=1, Cin=1, Cout=16, H=256, K=1, S=1, P=0 | Torch=0.0286 ms, Triton=0.3186 ms | Speedup=0.0897 | MAE=0.00470
# [138/3686] N=1, Cin=1, Cout=16, H=256, K=1, S=2, P=0 | Torch=0.0267 ms, Triton=0.2600 ms | Speedup=0.1026 | MAE=0.00553
# [139/3686] N=1, Cin=1, Cout=16, H=256, K=3, S=1, P=1 | Torch=0.0316 ms, Triton=0.3483 ms | Speedup=0.0907 | MAE=0.00472
# [140/3686] N=1, Cin=1, Cout=16, H=256, K=3, S=2, P=1 | Torch=0.0249 ms, Triton=0.2544 ms | Speedup=0.0977 | MAE=0.00509
# [141/3686] N=1, Cin=1, Cout=16, H=256, K=5, S=1, P=2 | Torch=0.0502 ms, Triton=0.3427 ms | Speedup=0.1465 | MAE=0.00492
# [142/3686] N=1, Cin=1, Cout=16, H=256, K=5, S=2, P=2 | Torch=0.0357 ms, Triton=0.2555 ms | Speedup=0.1396 | MAE=0.00480
# [143/3686] N=1, Cin=1, Cout=16, H=256, K=7, S=1, P=3 | Torch=0.0656 ms, Triton=0.3767 ms | Speedup=0.1740 | MAE=0.00464
# [144/3686] N=1, Cin=1, Cout=16, H=256, K=7, S=2, P=3 | Torch=0.0369 ms, Triton=0.2721 ms | Speedup=0.1356 | MAE=0.00492
# [145/3686] N=1, Cin=1, Cout=16, H=512, K=1, S=1, P=0 | Torch=0.0836 ms, Triton=0.9389 ms | Speedup=0.0891 | MAE=0.00558
# [146/3686] N=1, Cin=1, Cout=16, H=512, K=1, S=2, P=0 | Torch=0.0278 ms, Triton=0.3402 ms | Speedup=0.0817 | MAE=0.00504
# [147/3686] N=1, Cin=1, Cout=16, H=512, K=3, S=1, P=1 | Torch=0.0931 ms, Triton=1.1198 ms | Speedup=0.0831 | MAE=0.00582
# [148/3686] N=1, Cin=1, Cout=16, H=512, K=3, S=2, P=1 | Torch=0.0246 ms, Triton=0.3618 ms | Speedup=0.0679 | MAE=0.00566
# [149/3686] N=1, Cin=1, Cout=16, H=512, K=5, S=1, P=2 | Torch=0.1938 ms, Triton=1.1351 ms | Speedup=0.1707 | MAE=0.00479
# [150/3686] N=1, Cin=1, Cout=16, H=512, K=5, S=2, P=2 | Torch=0.0364 ms, Triton=0.3529 ms | Speedup=0.1032 | MAE=0.00523
# [151/3686] N=1, Cin=1, Cout=32, H=32, K=1, S=1, P=0 | Torch=0.0264 ms, Triton=0.2255 ms | Speedup=0.1169 | MAE=0.00364
# [152/3686] N=1, Cin=1, Cout=32, H=32, K=1, S=2, P=0 | Torch=0.0239 ms, Triton=0.2215 ms | Speedup=0.1079 | MAE=0.00408
# [153/3686] N=1, Cin=1, Cout=32, H=32, K=3, S=1, P=1 | Torch=0.0241 ms, Triton=0.2230 ms | Speedup=0.1079 | MAE=0.00388
# [154/3686] N=1, Cin=1, Cout=32, H=32, K=3, S=2, P=1 | Torch=0.0242 ms, Triton=0.2240 ms | Speedup=0.1079 | MAE=0.00416
# [155/3686] N=1, Cin=1, Cout=32, H=32, K=5, S=1, P=2 | Torch=0.0238 ms, Triton=0.2233 ms | Speedup=0.1066 | MAE=0.00377
# [156/3686] N=1, Cin=1, Cout=32, H=32, K=5, S=2, P=2 | Torch=0.0237 ms, Triton=0.2276 ms | Speedup=0.1040 | MAE=0.00422
# [157/3686] N=1, Cin=1, Cout=32, H=32, K=7, S=1, P=3 | Torch=0.0268 ms, Triton=0.2407 ms | Speedup=0.1113 | MAE=0.00389
# [158/3686] N=1, Cin=1, Cout=32, H=32, K=7, S=2, P=3 | Torch=0.0239 ms, Triton=0.2220 ms | Speedup=0.1077 | MAE=0.00358
# [159/3686] N=1, Cin=1, Cout=32, H=32, K=9, S=1, P=4 | Torch=0.0234 ms, Triton=0.2401 ms | Speedup=0.0974 | MAE=0.00358
# [160/3686] N=1, Cin=1, Cout=32, H=32, K=9, S=2, P=4 | Torch=0.0237 ms, Triton=0.2308 ms | Speedup=0.1025 | MAE=0.00380
# [161/3686] N=1, Cin=1, Cout=32, H=32, K=11, S=1, P=5 | Torch=0.0238 ms, Triton=0.2322 ms | Speedup=0.1023 | MAE=0.00372
# [162/3686] N=1, Cin=1, Cout=32, H=32, K=11, S=2, P=5 | Torch=0.0235 ms, Triton=0.2294 ms | Speedup=0.1026 | MAE=0.00340
# [163/3686] N=1, Cin=1, Cout=32, H=64, K=1, S=1, P=0 | Torch=0.0239 ms, Triton=0.2159 ms | Speedup=0.1107 | MAE=0.00437
# [164/3686] N=1, Cin=1, Cout=32, H=64, K=1, S=2, P=0 | Torch=0.0237 ms, Triton=0.2136 ms | Speedup=0.1108 | MAE=0.00383
# [165/3686] N=1, Cin=1, Cout=32, H=64, K=3, S=1, P=1 | Torch=0.0238 ms, Triton=0.2379 ms | Speedup=0.1002 | MAE=0.00464
# [166/3686] N=1, Cin=1, Cout=32, H=64, K=3, S=2, P=1 | Torch=0.0235 ms, Triton=0.2203 ms | Speedup=0.1068 | MAE=0.00466
# [167/3686] N=1, Cin=1, Cout=32, H=64, K=5, S=1, P=2 | Torch=0.0236 ms, Triton=0.2306 ms | Speedup=0.1022 | MAE=0.00451
# [168/3686] N=1, Cin=1, Cout=32, H=64, K=5, S=2, P=2 | Torch=0.0236 ms, Triton=0.2216 ms | Speedup=0.1066 | MAE=0.00417
# [169/3686] N=1, Cin=1, Cout=32, H=64, K=7, S=1, P=3 | Torch=0.0238 ms, Triton=0.2293 ms | Speedup=0.1036 | MAE=0.00374
# [170/3686] N=1, Cin=1, Cout=32, H=64, K=7, S=2, P=3 | Torch=0.0257 ms, Triton=0.2306 ms | Speedup=0.1113 | MAE=0.00426
# [171/3686] N=1, Cin=1, Cout=32, H=64, K=9, S=1, P=4 | Torch=0.0265 ms, Triton=0.2418 ms | Speedup=0.1097 | MAE=0.00395
# [172/3686] N=1, Cin=1, Cout=32, H=64, K=9, S=2, P=4 | Torch=0.0266 ms, Triton=0.2405 ms | Speedup=0.1107 | MAE=0.00444
# [173/3686] N=1, Cin=1, Cout=32, H=64, K=11, S=1, P=5 | Torch=0.0263 ms, Triton=0.2546 ms | Speedup=0.1033 | MAE=0.00445
# [174/3686] N=1, Cin=1, Cout=32, H=64, K=11, S=2, P=5 | Torch=0.0267 ms, Triton=0.2497 ms | Speedup=0.1070 | MAE=0.00440
# [175/3686] N=1, Cin=1, Cout=32, H=128, K=1, S=1, P=0 | Torch=0.0260 ms, Triton=0.2521 ms | Speedup=0.1032 | MAE=0.00422
# [176/3686] N=1, Cin=1, Cout=32, H=128, K=1, S=2, P=0 | Torch=0.0263 ms, Triton=0.2239 ms | Speedup=0.1173 | MAE=0.00434
# [177/3686] N=1, Cin=1, Cout=32, H=128, K=3, S=1, P=1 | Torch=0.0240 ms, Triton=0.2608 ms | Speedup=0.0922 | MAE=0.00484
# [178/3686] N=1, Cin=1, Cout=32, H=128, K=3, S=2, P=1 | Torch=0.0256 ms, Triton=0.2378 ms | Speedup=0.1075 | MAE=0.00452
# [179/3686] N=1, Cin=1, Cout=32, H=128, K=5, S=1, P=2 | Torch=0.0234 ms, Triton=0.2637 ms | Speedup=0.0889 | MAE=0.00438
# [180/3686] N=1, Cin=1, Cout=32, H=128, K=5, S=2, P=2 | Torch=0.0233 ms, Triton=0.2267 ms | Speedup=0.1026 | MAE=0.00439
# [181/3686] N=1, Cin=1, Cout=32, H=128, K=7, S=1, P=3 | Torch=0.0236 ms, Triton=0.2536 ms | Speedup=0.0930 | MAE=0.00478
# [182/3686] N=1, Cin=1, Cout=32, H=128, K=7, S=2, P=3 | Torch=0.0233 ms, Triton=0.2354 ms | Speedup=0.0989 | MAE=0.00532
# [183/3686] N=1, Cin=1, Cout=32, H=128, K=9, S=1, P=4 | Torch=0.0262 ms, Triton=0.2827 ms | Speedup=0.0928 | MAE=0.00440
# [184/3686] N=1, Cin=1, Cout=32, H=128, K=9, S=2, P=4 | Torch=0.0248 ms, Triton=0.2491 ms | Speedup=0.0996 | MAE=0.00439
# [185/3686] N=1, Cin=1, Cout=32, H=128, K=11, S=1, P=5 | Torch=0.0287 ms, Triton=0.3187 ms | Speedup=0.0900 | MAE=0.00492
# [186/3686] N=1, Cin=1, Cout=32, H=128, K=11, S=2, P=5 | Torch=0.0258 ms, Triton=0.2561 ms | Speedup=0.1006 | MAE=0.00489
# [187/3686] N=1, Cin=1, Cout=32, H=256, K=1, S=1, P=0 | Torch=0.0288 ms, Triton=0.3944 ms | Speedup=0.0731 | MAE=0.00401
# [188/3686] N=1, Cin=1, Cout=32, H=256, K=1, S=2, P=0 | Torch=0.0257 ms, Triton=0.2544 ms | Speedup=0.1010 | MAE=0.00598
# [189/3686] N=1, Cin=1, Cout=32, H=256, K=3, S=1, P=1 | Torch=0.0365 ms, Triton=0.4389 ms | Speedup=0.0831 | MAE=0.00454
# [190/3686] N=1, Cin=1, Cout=32, H=256, K=3, S=2, P=1 | Torch=0.0238 ms, Triton=0.2613 ms | Speedup=0.0911 | MAE=0.00505
# [191/3686] N=1, Cin=1, Cout=32, H=256, K=5, S=1, P=2 | Torch=0.0582 ms, Triton=0.4581 ms | Speedup=0.1270 | MAE=0.00516
# [192/3686] N=1, Cin=1, Cout=32, H=256, K=5, S=2, P=2 | Torch=0.0358 ms, Triton=0.2666 ms | Speedup=0.1343 | MAE=0.00495
# [193/3686] N=1, Cin=1, Cout=32, H=256, K=7, S=1, P=3 | Torch=0.0733 ms, Triton=0.4918 ms | Speedup=0.1491 | MAE=0.00500
# [194/3686] N=1, Cin=1, Cout=32, H=256, K=7, S=2, P=3 | Torch=0.0438 ms, Triton=0.2549 ms | Speedup=0.1719 | MAE=0.00470
# [195/3686] N=1, Cin=1, Cout=32, H=512, K=1, S=1, P=0 | Torch=0.1430 ms, Triton=1.3875 ms | Speedup=0.1031 | MAE=0.00514
# [196/3686] N=1, Cin=1, Cout=32, H=512, K=1, S=2, P=0 | Torch=0.0344 ms, Triton=0.3925 ms | Speedup=0.0877 | MAE=0.00575
# [197/3686] N=1, Cin=1, Cout=32, H=512, K=3, S=1, P=1 | Torch=0.1483 ms, Triton=1.5428 ms | Speedup=0.0961 | MAE=0.00479
# [198/3686] N=1, Cin=1, Cout=32, H=512, K=3, S=2, P=1 | Torch=0.0374 ms, Triton=0.4129 ms | Speedup=0.0906 | MAE=0.00490
# [199/3686] N=1, Cin=1, Cout=32, H=512, K=5, S=1, P=2 | Torch=0.2174 ms, Triton=1.5768 ms | Speedup=0.1379 | MAE=0.00533
# [200/3686] N=1, Cin=1, Cout=32, H=512, K=5, S=2, P=2 | Torch=0.0513 ms, Triton=0.4652 ms | Speedup=0.1103 | MAE=0.00534
# [201/3686] N=1, Cin=1, Cout=64, H=32, K=1, S=1, P=0 | Torch=0.0236 ms, Triton=0.2164 ms | Speedup=0.1088 | MAE=0.00379
# [202/3686] N=1, Cin=1, Cout=64, H=32, K=1, S=2, P=0 | Torch=0.0234 ms, Triton=0.2191 ms | Speedup=0.1069 | MAE=0.00394
# [203/3686] N=1, Cin=1, Cout=64, H=32, K=3, S=1, P=1 | Torch=0.0236 ms, Triton=0.2204 ms | Speedup=0.1069 | MAE=0.00375
# [204/3686] N=1, Cin=1, Cout=64, H=32, K=3, S=2, P=1 | Torch=0.0234 ms, Triton=0.2201 ms | Speedup=0.1063 | MAE=0.00386
# [205/3686] N=1, Cin=1, Cout=64, H=32, K=5, S=1, P=2 | Torch=0.0233 ms, Triton=0.2253 ms | Speedup=0.1034 | MAE=0.00334
# [206/3686] N=1, Cin=1, Cout=64, H=32, K=5, S=2, P=2 | Torch=0.0235 ms, Triton=0.2215 ms | Speedup=0.1060 | MAE=0.00376
# [207/3686] N=1, Cin=1, Cout=64, H=32, K=7, S=1, P=3 | Torch=0.0235 ms, Triton=0.2282 ms | Speedup=0.1031 | MAE=0.00394
# [208/3686] N=1, Cin=1, Cout=64, H=32, K=7, S=2, P=3 | Torch=0.0234 ms, Triton=0.2282 ms | Speedup=0.1025 | MAE=0.00410
# [209/3686] N=1, Cin=1, Cout=64, H=32, K=9, S=1, P=4 | Torch=0.0235 ms, Triton=0.2369 ms | Speedup=0.0990 | MAE=0.00381
# [210/3686] N=1, Cin=1, Cout=64, H=32, K=9, S=2, P=4 | Torch=0.0230 ms, Triton=0.2282 ms | Speedup=0.1010 | MAE=0.00349
# [211/3686] N=1, Cin=1, Cout=64, H=32, K=11, S=1, P=5 | Torch=0.0232 ms, Triton=0.2278 ms | Speedup=0.1017 | MAE=0.00360
# [212/3686] N=1, Cin=1, Cout=64, H=32, K=11, S=2, P=5 | Torch=0.0235 ms, Triton=0.2347 ms | Speedup=0.1002 | MAE=0.00378
# [213/3686] N=1, Cin=1, Cout=64, H=64, K=1, S=1, P=0 | Torch=0.0235 ms, Triton=0.2166 ms | Speedup=0.1087 | MAE=0.00415
# [214/3686] N=1, Cin=1, Cout=64, H=64, K=1, S=2, P=0 | Torch=0.0234 ms, Triton=0.2101 ms | Speedup=0.1114 | MAE=0.00374
# [215/3686] N=1, Cin=1, Cout=64, H=64, K=3, S=1, P=1 | Torch=0.0234 ms, Triton=0.2254 ms | Speedup=0.1040 | MAE=0.00430
# [216/3686] N=1, Cin=1, Cout=64, H=64, K=3, S=2, P=1 | Torch=0.0234 ms, Triton=0.2188 ms | Speedup=0.1068 | MAE=0.00459
# [217/3686] N=1, Cin=1, Cout=64, H=64, K=5, S=1, P=2 | Torch=0.0234 ms, Triton=0.2289 ms | Speedup=0.1025 | MAE=0.00410
# [218/3686] N=1, Cin=1, Cout=64, H=64, K=5, S=2, P=2 | Torch=0.0236 ms, Triton=0.2182 ms | Speedup=0.1082 | MAE=0.00471
# [219/3686] N=1, Cin=1, Cout=64, H=64, K=7, S=1, P=3 | Torch=0.0234 ms, Triton=0.2305 ms | Speedup=0.1016 | MAE=0.00401
# [220/3686] N=1, Cin=1, Cout=64, H=64, K=7, S=2, P=3 | Torch=0.0236 ms, Triton=0.2185 ms | Speedup=0.1078 | MAE=0.00417
# [221/3686] N=1, Cin=1, Cout=64, H=64, K=9, S=1, P=4 | Torch=0.0234 ms, Triton=0.2285 ms | Speedup=0.1023 | MAE=0.00446
# [222/3686] N=1, Cin=1, Cout=64, H=64, K=9, S=2, P=4 | Torch=0.0236 ms, Triton=0.2274 ms | Speedup=0.1039 | MAE=0.00405
# [223/3686] N=1, Cin=1, Cout=64, H=64, K=11, S=1, P=5 | Torch=0.0231 ms, Triton=0.2280 ms | Speedup=0.1012 | MAE=0.00417
# [224/3686] N=1, Cin=1, Cout=64, H=64, K=11, S=2, P=5 | Torch=0.0233 ms, Triton=0.2263 ms | Speedup=0.1028 | MAE=0.00381
# [225/3686] N=1, Cin=1, Cout=64, H=128, K=1, S=1, P=0 | Torch=0.0270 ms, Triton=0.2469 ms | Speedup=0.1091 | MAE=0.00471
# [226/3686] N=1, Cin=1, Cout=64, H=128, K=1, S=2, P=0 | Torch=0.0319 ms, Triton=0.2269 ms | Speedup=0.1408 | MAE=0.00445
# [227/3686] N=1, Cin=1, Cout=64, H=128, K=3, S=1, P=1 | Torch=0.0255 ms, Triton=0.2774 ms | Speedup=0.0919 | MAE=0.00427
# [228/3686] N=1, Cin=1, Cout=64, H=128, K=3, S=2, P=1 | Torch=0.0259 ms, Triton=0.2372 ms | Speedup=0.1091 | MAE=0.00489
# [229/3686] N=1, Cin=1, Cout=64, H=128, K=5, S=1, P=2 | Torch=0.0257 ms, Triton=0.2687 ms | Speedup=0.0956 | MAE=0.00473
# [230/3686] N=1, Cin=1, Cout=64, H=128, K=5, S=2, P=2 | Torch=0.0239 ms, Triton=0.2313 ms | Speedup=0.1033 | MAE=0.00500
# [231/3686] N=1, Cin=1, Cout=64, H=128, K=7, S=1, P=3 | Torch=0.0285 ms, Triton=0.2804 ms | Speedup=0.1015 | MAE=0.00427
# [232/3686] N=1, Cin=1, Cout=64, H=128, K=7, S=2, P=3 | Torch=0.0233 ms, Triton=0.2302 ms | Speedup=0.1014 | MAE=0.00442
# [233/3686] N=1, Cin=1, Cout=64, H=128, K=9, S=1, P=4 | Torch=0.0369 ms, Triton=0.2812 ms | Speedup=0.1313 | MAE=0.00416
# [234/3686] N=1, Cin=1, Cout=64, H=128, K=9, S=2, P=4 | Torch=0.0241 ms, Triton=0.2300 ms | Speedup=0.1049 | MAE=0.00443
# [235/3686] N=1, Cin=1, Cout=64, H=128, K=11, S=1, P=5 | Torch=0.0480 ms, Triton=0.3163 ms | Speedup=0.1518 | MAE=0.00436
# [236/3686] N=1, Cin=1, Cout=64, H=128, K=11, S=2, P=5 | Torch=0.0233 ms, Triton=0.2303 ms | Speedup=0.1012 | MAE=0.00487
# [237/3686] N=1, Cin=1, Cout=64, H=256, K=1, S=1, P=0 | Torch=0.0561 ms, Triton=0.6766 ms | Speedup=0.0829 | MAE=0.00467
# [238/3686] N=1, Cin=1, Cout=64, H=256, K=1, S=2, P=0 | Torch=0.0290 ms, Triton=0.2556 ms | Speedup=0.1136 | MAE=0.00511
# [239/3686] N=1, Cin=1, Cout=64, H=256, K=3, S=1, P=1 | Torch=0.0693 ms, Triton=0.7130 ms | Speedup=0.0972 | MAE=0.00467
# [240/3686] N=1, Cin=1, Cout=64, H=256, K=3, S=2, P=1 | Torch=0.0288 ms, Triton=0.2666 ms | Speedup=0.1082 | MAE=0.00492
# [241/3686] N=1, Cin=1, Cout=64, H=256, K=5, S=1, P=2 | Torch=0.0796 ms, Triton=0.7233 ms | Speedup=0.1100 | MAE=0.00463
# [242/3686] N=1, Cin=1, Cout=64, H=256, K=5, S=2, P=2 | Torch=0.0292 ms, Triton=0.2587 ms | Speedup=0.1130 | MAE=0.00498
# [243/3686] N=1, Cin=1, Cout=64, H=256, K=7, S=1, P=3 | Torch=0.0942 ms, Triton=0.7884 ms | Speedup=0.1195 | MAE=0.00461
# [244/3686] N=1, Cin=1, Cout=64, H=256, K=7, S=2, P=3 | Torch=0.0290 ms, Triton=0.2826 ms | Speedup=0.1025 | MAE=0.00517
# [245/3686] N=1, Cin=1, Cout=64, H=512, K=1, S=1, P=0 | Torch=0.2322 ms, Triton=2.6415 ms | Speedup=0.0879 | MAE=0.00472
# [246/3686] N=1, Cin=1, Cout=64, H=512, K=1, S=2, P=0 | Torch=0.0643 ms, Triton=0.6815 ms | Speedup=0.0944 | MAE=0.00526
# [247/3686] N=1, Cin=1, Cout=64, H=512, K=3, S=1, P=1 | Torch=0.2754 ms, Triton=2.7373 ms | Speedup=0.1006 | MAE=0.00513
# [248/3686] N=1, Cin=1, Cout=64, H=512, K=3, S=2, P=1 | Torch=0.0703 ms, Triton=0.7533 ms | Speedup=0.0933 | MAE=0.00508
# [249/3686] N=1, Cin=1, Cout=64, H=512, K=5, S=1, P=2 | Torch=0.3031 ms, Triton=2.8233 ms | Speedup=0.1074 | MAE=0.00526
# [250/3686] N=1, Cin=1, Cout=64, H=512, K=5, S=2, P=2 | Torch=0.0796 ms, Triton=0.7641 ms | Speedup=0.1042 | MAE=0.00498
# [251/3686] N=1, Cin=3, Cout=3, H=32, K=1, S=1, P=0 | Torch=0.0234 ms, Triton=0.2425 ms | Speedup=0.0965 | MAE=0.00344
# [252/3686] N=1, Cin=3, Cout=3, H=32, K=1, S=2, P=0 | Torch=0.0255 ms, Triton=0.2439 ms | Speedup=0.1047 | MAE=0.00417
# [398/3686] N=1, Cin=3, Cout=16, H=512, K=3, S=2, P=1 | Torch=0.0321 ms, Triton=0.3389 ms | Speedup=0.0946 | MAE=0.00527
# [399/3686] N=1, Cin=3, Cout=16, H=512, K=5, S=1, P=2 | Torch=0.2958 ms, Triton=2.0484 ms | Speedup=0.1444 | MAE=0.00550
# [400/3686] N=1, Cin=3, Cout=16, H=512, K=5, S=2, P=2 | Torch=0.0731 ms, Triton=0.5283 ms | Speedup=0.1383 | MAE=0.00556
# [401/3686] N=1, Cin=3, Cout=32, H=32, K=1, S=1, P=0 | Torch=0.0239 ms, Triton=0.2214 ms | Speedup=0.1078 | MAE=0.00407
# [402/3686] N=1, Cin=3, Cout=32, H=32, K=1, S=2, P=0 | Torch=0.0232 ms, Triton=0.2189 ms | Speedup=0.1058 | MAE=0.00480
# [403/3686] N=1, Cin=3, Cout=32, H=32, K=3, S=1, P=1 | Torch=0.0241 ms, Triton=0.2194 ms | Speedup=0.1100 | MAE=0.00401
# ...
# [3557/3686] N=16, Cin=16, Cout=64, H=32, K=3, S=1, P=1 | Torch=0.0389 ms, Triton=0.2681 ms | Speedup=0.1449 | MAE=0.00495
# [3558/3686] N=16, Cin=16, Cout=64, H=32, K=3, S=2, P=1 | Torch=0.0368 ms, Triton=0.2004 ms | Speedup=0.1836 | MAE=0.00499
# [3559/3686] N=16, Cin=16, Cout=64, H=32, K=5, S=1, P=2 | Torch=0.0529 ms, Triton=0.4662 ms | Speedup=0.1135 | MAE=0.00499
# [3560/3686] N=16, Cin=16, Cout=64, H=32, K=5, S=2, P=2 | Torch=0.0363 ms, Triton=0.2238 ms | Speedup=0.1623 | MAE=0.00503
# [3561/3686] N=16, Cin=16, Cout=64, H=32, K=7, S=1, P=3 | Torch=0.1102 ms, Triton=0.7652 ms | Speedup=0.1440 | MAE=0.00479
# [3562/3686] N=16, Cin=16, Cout=64, H=32, K=7, S=2, P=3 | Torch=0.0464 ms, Triton=0.3033 ms | Speedup=0.1532 | MAE=0.00485
# [3563/3686] N=16, Cin=16, Cout=64, H=32, K=9, S=1, P=4 | Torch=0.1626 ms, Triton=1.1768 ms | Speedup=0.1381 | MAE=0.00483
# [3564/3686] N=16, Cin=16, Cout=64, H=32, K=9, S=2, P=4 | Torch=0.1052 ms, Triton=0.4095 ms | Speedup=0.2570 | MAE=0.00464
# [3565/3686] N=16, Cin=16, Cout=64, H=32, K=11, S=1, P=5 | Torch=0.2316 ms, Triton=1.7107 ms | Speedup=0.1354 | MAE=0.00460
# [3566/3686] N=16, Cin=16, Cout=64, H=32, K=11, S=2, P=5 | Torch=0.1489 ms, Triton=0.5433 ms | Speedup=0.2741 | MAE=0.00486
# [3567/3686] N=16, Cin=16, Cout=64, H=64, K=1, S=1, P=0 | Torch=0.0640 ms, Triton=0.3525 ms | Speedup=0.1815 | MAE=0.00556
# [3568/3686] N=16, Cin=16, Cout=64, H=64, K=1, S=2, P=0 | Torch=0.0298 ms, Triton=0.2049 ms | Speedup=0.1454 | MAE=0.00536
# [3569/3686] N=16, Cin=16, Cout=64, H=64, K=3, S=1, P=1 | Torch=0.1571 ms, Triton=0.8061 ms | Speedup=0.1949 | MAE=0.00532
# [3570/3686] N=16, Cin=16, Cout=64, H=64, K=3, S=2, P=1 | Torch=0.0477 ms, Triton=0.3055 ms | Speedup=0.1562 | MAE=0.00555
# [3571/3686] N=16, Cin=16, Cout=64, H=64, K=5, S=1, P=2 | Torch=0.2732 ms, Triton=1.5623 ms | Speedup=0.1749 | MAE=0.00542
# [3572/3686] N=16, Cin=16, Cout=64, H=64, K=5, S=2, P=2 | Torch=0.0785 ms, Triton=0.4744 ms | Speedup=0.1654 | MAE=0.00526
# [3573/3686] N=16, Cin=16, Cout=64, H=64, K=7, S=1, P=3 | Torch=0.4055 ms, Triton=2.7441 ms | Speedup=0.1478 | MAE=0.00574
# [3574/3686] N=16, Cin=16, Cout=64, H=64, K=7, S=2, P=3 | Torch=0.0836 ms, Triton=0.7664 ms | Speedup=0.1091 | MAE=0.00571
# [3575/3686] N=16, Cin=16, Cout=64, H=64, K=9, S=1, P=4 | Torch=0.6171 ms, Triton=4.3694 ms | Speedup=0.1412 | MAE=0.00573
# [3576/3686] N=16, Cin=16, Cout=64, H=64, K=9, S=2, P=4 | Torch=0.1753 ms, Triton=1.2008 ms | Speedup=0.1460 | MAE=0.00505
# [3577/3686] N=16, Cin=16, Cout=64, H=64, K=11, S=1, P=5 | Torch=0.8359 ms, Triton=6.4505 ms | Speedup=0.1296 | MAE=0.00525
# [3578/3686] N=16, Cin=16, Cout=64, H=64, K=11, S=2, P=5 | Torch=0.2433 ms, Triton=1.6996 ms | Speedup=0.1431 | MAE=0.00509
# [3579/3686] N=16, Cin=16, Cout=64, H=128, K=1, S=1, P=0 | Torch=0.2292 ms, Triton=1.2860 ms | Speedup=0.1782 | MAE=0.00575
# [3580/3686] N=16, Cin=16, Cout=64, H=128, K=1, S=2, P=0 | Torch=0.0791 ms, Triton=0.3521 ms | Speedup=0.2247 | MAE=0.00581
# [3581/3686] N=16, Cin=16, Cout=64, H=128, K=3, S=1, P=1 | Torch=0.6004 ms, Triton=2.9988 ms | Speedup=0.2002 | MAE=0.00652
# [3582/3686] N=16, Cin=16, Cout=64, H=128, K=3, S=2, P=1 | Torch=0.1571 ms, Triton=0.7995 ms | Speedup=0.1965 | MAE=0.00559
# [3583/3686] N=16, Cin=16, Cout=64, H=128, K=5, S=1, P=2 | Torch=0.6980 ms, Triton=6.1640 ms | Speedup=0.1132 | MAE=0.00524
# [3584/3686] N=16, Cin=16, Cout=64, H=128, K=5, S=2, P=2 | Torch=0.2190 ms, Triton=1.5645 ms | Speedup=0.1400 | MAE=0.00543
# [3585/3686] N=16, Cin=16, Cout=64, H=128, K=7, S=1, P=3 | Torch=1.5523 ms, Triton=10.8147 ms | Speedup=0.1435 | MAE=0.00568
# [3586/3686] N=16, Cin=16, Cout=64, H=128, K=7, S=2, P=3 | Torch=0.2958 ms, Triton=2.7459 ms | Speedup=0.1077 | MAE=0.00566
# [3587/3686] N=16, Cin=16, Cout=64, H=128, K=9, S=1, P=4 | Torch=2.3263 ms, Triton=17.2790 ms | Speedup=0.1346 | MAE=0.00561
# [3588/3686] N=16, Cin=16, Cout=64, H=128, K=9, S=2, P=4 | Torch=0.6435 ms, Triton=4.3728 ms | Speedup=0.1472 | MAE=0.00558
# [3589/3686] N=16, Cin=16, Cout=64, H=128, K=11, S=1, P=5 | Torch=3.2468 ms, Triton=25.4842 ms | Speedup=0.1274 | MAE=0.00578
# [3590/3686] N=16, Cin=16, Cout=64, H=128, K=11, S=2, P=5 | Torch=0.9156 ms, Triton=6.4094 ms | Speedup=0.1429 | MAE=0.00555
# [3591/3686] N=16, Cin=16, Cout=64, H=256, K=1, S=1, P=0 | Torch=0.9036 ms, Triton=8.7264 ms | Speedup=0.1036 | MAE=0.00573
# [3592/3686] N=16, Cin=16, Cout=64, H=256, K=1, S=2, P=0 | Torch=0.3696 ms, Triton=1.3026 ms | Speedup=0.2837 | MAE=0.00611
# [3593/3686] N=16, Cin=16, Cout=64, H=256, K=3, S=1, P=1 | Torch=2.3068 ms, Triton=15.6260 ms | Speedup=0.1476 | MAE=0.00587
# [3594/3686] N=16, Cin=16, Cout=64, H=256, K=3, S=2, P=1 | Torch=0.5777 ms, Triton=2.9991 ms | Speedup=0.1926 | MAE=0.00606
# [3595/3686] N=16, Cin=16, Cout=64, H=256, K=5, S=1, P=2 | Torch=2.7776 ms, Triton=27.9909 ms | Speedup=0.0992 | MAE=0.00584
# [3596/3686] N=16, Cin=16, Cout=64, H=256, K=5, S=2, P=2 | Torch=0.8128 ms, Triton=6.1134 ms | Speedup=0.1330 | MAE=0.00624
# [3597/3686] N=16, Cin=16, Cout=64, H=256, K=7, S=1, P=3 | Torch=6.1553 ms, Triton=46.6811 ms | Speedup=0.1319 | MAE=0.00616
# [3598/3686] N=16, Cin=16, Cout=64, H=256, K=7, S=2, P=3 | Torch=1.1117 ms, Triton=10.8417 ms | Speedup=0.1025 | MAE=0.00588
# [3599/3686] N=16, Cin=32, Cout=32, H=32, K=1, S=1, P=0 | Torch=0.0238 ms, Triton=0.2044 ms | Speedup=0.1165 | MAE=0.00559
# [3600/3686] N=16, Cin=32, Cout=32, H=32, K=1, S=2, P=0 | Torch=0.0292 ms, Triton=0.1960 ms | Speedup=0.1491 | MAE=0.00560
# [3601/3686] N=16, Cin=32, Cout=32, H=32, K=3, S=1, P=1 | Torch=0.0382 ms, Triton=0.3784 ms | Speedup=0.1008 | MAE=0.00500
# [3602/3686] N=16, Cin=32, Cout=32, H=32, K=3, S=2, P=1 | Torch=0.0391 ms, Triton=0.2068 ms | Speedup=0.1892 | MAE=0.00511
# [3603/3686] N=16, Cin=32, Cout=32, H=32, K=5, S=1, P=2 | Torch=0.0558 ms, Triton=0.7778 ms | Speedup=0.0718 | MAE=0.00536
# [3604/3686] N=16, Cin=32, Cout=32, H=32, K=5, S=2, P=2 | Torch=0.0393 ms, Triton=0.3064 ms | Speedup=0.1281 | MAE=0.00527
# [3605/3686] N=16, Cin=32, Cout=32, H=32, K=7, S=1, P=3 | Torch=0.0900 ms, Triton=1.3926 ms | Speedup=0.0646 | MAE=0.00543
# [3606/3686] N=16, Cin=32, Cout=32, H=32, K=7, S=2, P=3 | Torch=0.0392 ms, Triton=0.4614 ms | Speedup=0.0849 | MAE=0.00505
# [3607/3686] N=16, Cin=32, Cout=32, H=32, K=9, S=1, P=4 | Torch=0.1456 ms, Triton=2.2225 ms | Speedup=0.0655 | MAE=0.00519
# [3608/3686] N=16, Cin=32, Cout=32, H=32, K=9, S=2, P=4 | Torch=0.0534 ms, Triton=0.6783 ms | Speedup=0.0787 | MAE=0.00524
# [3609/3686] N=16, Cin=32, Cout=32, H=32, K=11, S=1, P=5 | Torch=0.1920 ms, Triton=3.2528 ms | Speedup=0.0590 | MAE=0.00511
# [3610/3686] N=16, Cin=32, Cout=32, H=32, K=11, S=2, P=5 | Torch=0.0727 ms, Triton=0.9283 ms | Speedup=0.0783 | MAE=0.00480
# [3611/3686] N=16, Cin=32, Cout=32, H=64, K=1, S=1, P=0 | Torch=0.0369 ms, Triton=0.2293 ms | Speedup=0.1607 | MAE=0.00556
# [3612/3686] N=16, Cin=32, Cout=32, H=64, K=1, S=2, P=0 | Torch=0.0240 ms, Triton=0.2017 ms | Speedup=0.1191 | MAE=0.00595
# [3613/3686] N=16, Cin=32, Cout=32, H=64, K=3, S=1, P=1 | Torch=0.0992 ms, Triton=1.0850 ms | Speedup=0.0914 | MAE=0.00620
# [3614/3686] N=16, Cin=32, Cout=32, H=64, K=3, S=2, P=1 | Torch=0.0446 ms, Triton=0.3890 ms | Speedup=0.1147 | MAE=0.00604
# [3615/3686] N=16, Cin=32, Cout=32, H=64, K=5, S=1, P=2 | Torch=0.1853 ms, Triton=2.6631 ms | Speedup=0.0696 | MAE=0.00557
# [3616/3686] N=16, Cin=32, Cout=32, H=64, K=5, S=2, P=2 | Torch=0.0615 ms, Triton=0.7948 ms | Speedup=0.0774 | MAE=0.00554
# [3617/3686] N=16, Cin=32, Cout=32, H=64, K=7, S=1, P=3 | Torch=0.2966 ms, Triton=5.0964 ms | Speedup=0.0582 | MAE=0.00548
# [3618/3686] N=16, Cin=32, Cout=32, H=64, K=7, S=2, P=3 | Torch=0.0999 ms, Triton=1.3977 ms | Speedup=0.0714 | MAE=0.00569
# [3619/3686] N=16, Cin=32, Cout=32, H=64, K=9, S=1, P=4 | Torch=0.4450 ms, Triton=8.3748 ms | Speedup=0.0531 | MAE=0.00544
# [3620/3686] N=16, Cin=32, Cout=32, H=64, K=9, S=2, P=4 | Torch=0.1177 ms, Triton=2.2472 ms | Speedup=0.0524 | MAE=0.00526
# [3621/3686] N=16, Cin=32, Cout=32, H=64, K=11, S=1, P=5 | Torch=0.6317 ms, Triton=12.3848 ms | Speedup=0.0510 | MAE=0.00538
# [3622/3686] N=16, Cin=32, Cout=32, H=64, K=11, S=2, P=5 | Torch=0.1575 ms, Triton=3.2395 ms | Speedup=0.0486 | MAE=0.00518
# [3623/3686] N=16, Cin=32, Cout=32, H=128, K=1, S=1, P=0 | Torch=0.1438 ms, Triton=0.8057 ms | Speedup=0.1785 | MAE=0.00604
# [3624/3686] N=16, Cin=32, Cout=32, H=128, K=1, S=2, P=0 | Torch=0.0526 ms, Triton=0.2507 ms | Speedup=0.2098 | MAE=0.00579
# [3625/3686] N=16, Cin=32, Cout=32, H=128, K=3, S=1, P=1 | Torch=0.3497 ms, Triton=4.2129 ms | Speedup=0.0830 | MAE=0.00626
# [3626/3686] N=16, Cin=32, Cout=32, H=128, K=3, S=2, P=1 | Torch=0.1563 ms, Triton=1.0853 ms | Speedup=0.1440 | MAE=0.00594
# [3627/3686] N=16, Cin=32, Cout=32, H=128, K=5, S=1, P=2 | Torch=0.5616 ms, Triton=10.4435 ms | Speedup=0.0538 | MAE=0.00584
# [3628/3686] N=16, Cin=32, Cout=32, H=128, K=5, S=2, P=2 | Torch=0.3713 ms, Triton=2.6382 ms | Speedup=0.1407 | MAE=0.00594
# [3629/3686] N=16, Cin=32, Cout=32, H=128, K=7, S=1, P=3 | Torch=0.8766 ms, Triton=20.0891 ms | Speedup=0.0436 | MAE=0.00565
# [3630/3686] N=16, Cin=32, Cout=32, H=128, K=7, S=2, P=3 | Torch=0.2748 ms, Triton=5.0820 ms | Speedup=0.0541 | MAE=0.00569
# [3631/3686] N=16, Cin=32, Cout=32, H=128, K=9, S=1, P=4 | Torch=1.2934 ms, Triton=33.2116 ms | Speedup=0.0389 | MAE=0.00612
# [3632/3686] N=16, Cin=32, Cout=32, H=128, K=9, S=2, P=4 | Torch=0.3775 ms, Triton=8.4129 ms | Speedup=0.0449 | MAE=0.00562
# [3633/3686] N=16, Cin=32, Cout=32, H=128, K=11, S=1, P=5 | Torch=1.8173 ms, Triton=49.3682 ms | Speedup=0.0368 | MAE=0.00586
# [3634/3686] N=16, Cin=32, Cout=32, H=128, K=11, S=2, P=5 | Torch=0.5142 ms, Triton=12.4309 ms | Speedup=0.0414 | MAE=0.00587
# [3635/3686] N=16, Cin=32, Cout=32, H=256, K=1, S=1, P=0 | Torch=0.5424 ms, Triton=4.4691 ms | Speedup=0.1214 | MAE=0.00601
# [3636/3686] N=16, Cin=32, Cout=32, H=256, K=1, S=2, P=0 | Torch=0.3614 ms, Triton=0.8083 ms | Speedup=0.4471 | MAE=0.00698
# [3637/3686] N=16, Cin=32, Cout=32, H=256, K=3, S=1, P=1 | Torch=1.3363 ms, Triton=18.0698 ms | Speedup=0.0740 | MAE=0.00588
# [3638/3686] N=16, Cin=32, Cout=32, H=256, K=3, S=2, P=1 | Torch=0.5327 ms, Triton=4.1866 ms | Speedup=0.1272 | MAE=0.00593
# [3639/3686] N=16, Cin=32, Cout=32, H=256, K=5, S=1, P=2 | Torch=2.1739 ms, Triton=42.9635 ms | Speedup=0.0506 | MAE=0.00589
# [3640/3686] N=16, Cin=32, Cout=32, H=256, K=5, S=2, P=2 | Torch=1.3688 ms, Triton=10.7757 ms | Speedup=0.1270 | MAE=0.00621
# [3641/3686] N=16, Cin=32, Cout=32, H=256, K=7, S=1, P=3 | Torch=3.6014 ms, Triton=84.8953 ms | Speedup=0.0424 | MAE=0.00622
# [3642/3686] N=16, Cin=32, Cout=32, H=256, K=7, S=2, P=3 | Torch=1.0567 ms, Triton=20.4898 ms | Speedup=0.0516 | MAE=0.00618
# [3643/3686] N=16, Cin=32, Cout=64, H=32, K=1, S=1, P=0 | Torch=0.0318 ms, Triton=0.2169 ms | Speedup=0.1467 | MAE=0.00626
# [3644/3686] N=16, Cin=32, Cout=64, H=32, K=1, S=2, P=0 | Torch=0.0280 ms, Triton=0.2013 ms | Speedup=0.1392 | MAE=0.00541
# [3645/3686] N=16, Cin=32, Cout=64, H=32, K=3, S=1, P=1 | Torch=0.0475 ms, Triton=0.4003 ms | Speedup=0.1186 | MAE=0.00521
# [3646/3686] N=16, Cin=32, Cout=64, H=32, K=3, S=2, P=1 | Torch=0.0350 ms, Triton=0.2067 ms | Speedup=0.1691 | MAE=0.00516
# [3647/3686] N=16, Cin=32, Cout=64, H=32, K=5, S=1, P=2 | Torch=0.0870 ms, Triton=0.7986 ms | Speedup=0.1090 | MAE=0.00520
# [3648/3686] N=16, Cin=32, Cout=64, H=32, K=5, S=2, P=2 | Torch=0.0379 ms, Triton=0.3053 ms | Speedup=0.1242 | MAE=0.00554
# [3649/3686] N=16, Cin=32, Cout=64, H=32, K=7, S=1, P=3 | Torch=0.1119 ms, Triton=1.4055 ms | Speedup=0.0796 | MAE=0.00533
# [3650/3686] N=16, Cin=32, Cout=64, H=32, K=7, S=2, P=3 | Torch=0.0705 ms, Triton=0.4741 ms | Speedup=0.1487 | MAE=0.00503
# [3651/3686] N=16, Cin=32, Cout=64, H=32, K=9, S=1, P=4 | Torch=0.3103 ms, Triton=2.2211 ms | Speedup=0.1397 | MAE=0.00508
# [3652/3686] N=16, Cin=32, Cout=64, H=32, K=9, S=2, P=4 | Torch=0.1054 ms, Triton=0.6673 ms | Speedup=0.1580 | MAE=0.00481
# [3653/3686] N=16, Cin=32, Cout=64, H=32, K=11, S=1, P=5 | Torch=0.4364 ms, Triton=3.2636 ms | Speedup=0.1337 | MAE=0.00472
# [3654/3686] N=16, Cin=32, Cout=64, H=32, K=11, S=2, P=5 | Torch=0.1503 ms, Triton=0.9381 ms | Speedup=0.1602 | MAE=0.00498
# [3655/3686] N=16, Cin=32, Cout=64, H=64, K=1, S=1, P=0 | Torch=0.0653 ms, Triton=0.3664 ms | Speedup=0.1783 | MAE=0.00562
# [3656/3686] N=16, Cin=32, Cout=64, H=64, K=1, S=2, P=0 | Torch=0.0286 ms, Triton=0.1999 ms | Speedup=0.1433 | MAE=0.00556
# [3657/3686] N=16, Cin=32, Cout=64, H=64, K=3, S=1, P=1 | Torch=0.1671 ms, Triton=1.2475 ms | Speedup=0.1340 | MAE=0.00555
# [3658/3686] N=16, Cin=32, Cout=64, H=64, K=3, S=2, P=1 | Torch=0.0614 ms, Triton=0.3888 ms | Speedup=0.1580 | MAE=0.00523
# [3659/3686] N=16, Cin=32, Cout=64, H=64, K=5, S=1, P=2 | Torch=0.2811 ms, Triton=2.8828 ms | Speedup=0.0975 | MAE=0.00571
# [3660/3686] N=16, Cin=32, Cout=64, H=64, K=5, S=2, P=2 | Torch=0.0923 ms, Triton=0.7844 ms | Speedup=0.1176 | MAE=0.00578
# [3661/3686] N=16, Cin=32, Cout=64, H=64, K=7, S=1, P=3 | Torch=0.4274 ms, Triton=5.2439 ms | Speedup=0.0815 | MAE=0.00548
# [3662/3686] N=16, Cin=32, Cout=64, H=64, K=7, S=2, P=3 | Torch=0.1308 ms, Triton=1.3901 ms | Speedup=0.0941 | MAE=0.00548
# [3663/3686] N=16, Cin=32, Cout=64, H=64, K=9, S=1, P=4 | Torch=1.1139 ms, Triton=8.5503 ms | Speedup=0.1303 | MAE=0.00553
# [3664/3686] N=16, Cin=32, Cout=64, H=64, K=9, S=2, P=4 | Torch=0.1858 ms, Triton=2.2202 ms | Speedup=0.0837 | MAE=0.00624
# [3665/3686] N=16, Cin=32, Cout=64, H=64, K=11, S=1, P=5 | Torch=1.6163 ms, Triton=12.6066 ms | Speedup=0.1282 | MAE=0.00531
# [3666/3686] N=16, Cin=32, Cout=64, H=64, K=11, S=2, P=5 | Torch=0.2640 ms, Triton=3.2595 ms | Speedup=0.0810 | MAE=0.00550
# [3667/3686] N=16, Cin=32, Cout=64, H=128, K=1, S=1, P=0 | Torch=0.2440 ms, Triton=1.3673 ms | Speedup=0.1784 | MAE=0.00633
# [3668/3686] N=16, Cin=32, Cout=64, H=128, K=1, S=2, P=0 | Torch=0.0845 ms, Triton=0.3665 ms | Speedup=0.2307 | MAE=0.00594
# [3669/3686] N=16, Cin=32, Cout=64, H=128, K=3, S=1, P=1 | Torch=0.6172 ms, Triton=4.7547 ms | Speedup=0.1298 | MAE=0.00578
# [3670/3686] N=16, Cin=32, Cout=64, H=128, K=3, S=2, P=1 | Torch=0.2160 ms, Triton=1.2277 ms | Speedup=0.1760 | MAE=0.00581
# [3671/3686] N=16, Cin=32, Cout=64, H=128, K=5, S=1, P=2 | Torch=1.0226 ms, Triton=11.0158 ms | Speedup=0.0928 | MAE=0.00589
# [3672/3686] N=16, Cin=32, Cout=64, H=128, K=5, S=2, P=2 | Torch=0.3245 ms, Triton=2.7894 ms | Speedup=0.1163 | MAE=0.00558
# [3673/3686] N=16, Cin=32, Cout=64, H=128, K=7, S=1, P=3 | Torch=1.6165 ms, Triton=20.6734 ms | Speedup=0.0782 | MAE=0.00592
# [3674/3686] N=16, Cin=32, Cout=64, H=128, K=7, S=2, P=3 | Torch=0.4742 ms, Triton=5.2354 ms | Speedup=0.0906 | MAE=0.00599
# [3675/3686] N=16, Cin=32, Cout=64, H=128, K=9, S=1, P=4 | Torch=4.3561 ms, Triton=34.2695 ms | Speedup=0.1271 | MAE=0.00573
# [3676/3686] N=16, Cin=32, Cout=64, H=128, K=9, S=2, P=4 | Torch=0.6745 ms, Triton=8.5269 ms | Speedup=0.0791 | MAE=0.00581
# [3677/3686] N=16, Cin=32, Cout=64, H=128, K=11, S=1, P=5 | Torch=6.2788 ms, Triton=50.6989 ms | Speedup=0.1238 | MAE=0.00557
# [3678/3686] N=16, Cin=32, Cout=64, H=128, K=11, S=2, P=5 | Torch=0.9285 ms, Triton=12.5712 ms | Speedup=0.0739 | MAE=0.00567
# [3679/3686] N=16, Cin=32, Cout=64, H=256, K=1, S=1, P=0 | Torch=0.9482 ms, Triton=9.1258 ms | Speedup=0.1039 | MAE=0.00630
# [3680/3686] N=16, Cin=32, Cout=64, H=256, K=1, S=2, P=0 | Torch=0.4381 ms, Triton=1.3464 ms | Speedup=0.3254 | MAE=0.00622
# [3681/3686] N=16, Cin=32, Cout=64, H=256, K=3, S=1, P=1 | Torch=2.4839 ms, Triton=22.6994 ms | Speedup=0.1094 | MAE=0.00635
# [3682/3686] N=16, Cin=32, Cout=64, H=256, K=3, S=2, P=1 | Torch=0.8429 ms, Triton=4.8137 ms | Speedup=0.1751 | MAE=0.00611
# [3683/3686] N=16, Cin=32, Cout=64, H=256, K=5, S=1, P=2 | Torch=3.9552 ms, Triton=47.5945 ms | Speedup=0.0831 | MAE=0.00619
# [3684/3686] N=16, Cin=32, Cout=64, H=256, K=5, S=2, P=2 | Torch=1.2208 ms, Triton=11.1336 ms | Speedup=0.1097 | MAE=0.00611
# [3685/3686] N=16, Cin=32, Cout=64, H=256, K=7, S=1, P=3 | Torch=6.3437 ms, Triton=86.2293 ms | Speedup=0.0736 | MAE=0.00613
# [3686/3686] N=16, Cin=32, Cout=64, H=256, K=7, S=2, P=3 | Torch=1.8318 ms, Triton=20.7912 ms | Speedup=0.0881 | MAE=0.00630
#
# >>> Benchmark completed.

# %%
df_int8

# %% [markdown]
# ### Отбор лучших INT8 конфигураций
#
# Ниже сортируем результаты по времени/скорости (и опционально фильтруем по ошибке). Сохраняйте строки, где:
# - `speedup_vs_ref > 1` (INT8 быстрее),
# - Ошибка в допустимых пределах для inference (обычно `mae` ~1e-3–1e-2 в зависимости от диапазонов).
# Эти варианты можно рекомендовать для конкретных форматов входа/выхода.

# %%
df = df_int8.copy()

df["Shape_info"] = (
    df["N"].astype(str) + "/" +
    df["Cin"].astype(str) + "/" +
    df["H"].astype(str) + "/" +
    df["K"].astype(str)
)

idx = df.groupby("H")["speedup"].idxmax()

best = df.loc[idx].copy()

best = (
    best[["H", "Shape_info", "t_torch_ms", "t_triton_ms", "speedup", "mae", "max_err"]]
    .sort_values("H")
    .set_index("H")
)

best
# Out:
#       Shape_info  t_torch_ms  t_triton_ms   speedup       mae   max_err
# H
# 32    4/16/32/11    0.145446     0.299222  0.486082  0.004362  0.024794
# 64     4/16/64/5    0.102543     0.263209  0.389589  0.005172  0.031538
# 128    8/8/128/9    2.238710     6.648256  0.336736  0.005319  0.036072
# 256  16/16/256/1    0.257820     0.456352  0.564959  0.006160  0.040376
# 512   8/16/512/1    0.511160     1.029427  0.496548  0.006339  0.042889
