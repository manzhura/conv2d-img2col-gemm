# %% [markdown]
# # Sparsity Kernel Search (FP16)
# ????? ?? ??? ?? ?????, ??? ? baseline, ? block-grid ??? ? baseline_kernel_search.ipynb. ???????????? torch Conv2d, TritonConv2d (dense) ? ??? ???? ????????????? ?? ?????? keep_ratio. ??? ?????????? ????????? ?? ???? ?????????, ????? ?????? ????????.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))
print('sys.path[0]=', sys.path[0])
# Out:
# sys.path[0]= /mnt/d/VSCode-Projects/conv2d-img2col-gemm

# %%
import time
import torch
import pandas as pd
from pathlib import Path
import importlib
from conv_gemm.baseline_layers.triton_conv2d import TritonConv2d
import conv_gemm.baseline_operators.triton_conv2d_fp16_fn as tri_fn
from conv_gemm.configs import kernel_config as kc

torch.backends.cudnn.benchmark = True
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dtype = torch.float16 if device == 'cuda' else torch.float32
print(f'device={device}, dtype={dtype}')
if device != 'cuda':
    print('?? ????? ?????????? ?? GPU ? CUDA; ?? CPU ????? ????? ??????.')
# Out:
# device=cuda, dtype=torch.float16

# %%
def sync_device():
    if device == 'cuda':
        torch.cuda.synchronize()

def clone_weights(dst: torch.nn.Module, src: torch.nn.Module):
    with torch.no_grad():
        dst.weight.copy_(src.weight)
        if dst.bias is not None and src.bias is not None:
            dst.bias.copy_(src.bias)

def benchmark_layer(layer: torch.nn.Module, x: torch.Tensor, warmup: int = 10, iters: int = 50) -> float:
    layer.eval()
    with torch.no_grad():
        for _ in range(warmup):
            _ = layer(x)
        sync_device()
        if device == 'cuda':
            start = torch.cuda.Event(enable_timing=True)
            end = torch.cuda.Event(enable_timing=True)
            start.record()
            for _ in range(iters):
                _ = layer(x)
            end.record()
            sync_device()
            elapsed_ms = start.elapsed_time(end)
        else:
            t0 = time.perf_counter()
            for _ in range(iters):
                _ = layer(x)
            elapsed_ms = (time.perf_counter() - t0) * 1e3
    return elapsed_ms / iters

def build_torch_conv(cfg):
    return torch.nn.Conv2d(
        in_channels=cfg['in_channels'],
        out_channels=cfg['out_channels'],
        kernel_size=cfg['kernel_size'],
        stride=cfg['stride'],
        padding=cfg['padding'],
        dilation=cfg['dilation'],
        bias=True,
    ).to(device=device, dtype=dtype)

def calc_diff(ref: torch.Tensor, test: torch.Tensor):
    diff = (ref - test).float()
    return {
        'mae': diff.abs().mean().item(),
        'max': diff.abs().max().item(),
        'rel_l2': (torch.norm(diff) / torch.norm(ref)).item(),
    }

def apply_sparsity(layer: TritonConv2d, mode: str, ratio: float):
    layer.clear_sparsity()
    if mode == 'dense':
        return
    if mode == 'channel':
        layer.set_channel_sparsity(ratio)
    elif mode == 'block':
        layer.set_block_sparsity(ratio, block_size=4)
    elif mode == 'input':
        layer.set_input_channel_sparsity(ratio)
    else:
        raise ValueError(f'unknown mode {mode}')

def apply_block_cfg(cfg):
    # ??????????? GEMM-?????? ????? ???????? ?????
    tri_fn.FP16_GEMM_CFG = kc.KernelConfig(
        BLOCK_M=cfg['BLOCK_M'],
        BLOCK_N=cfg['BLOCK_N'],
        BLOCK_K=cfg['BLOCK_K'],
        NUM_WARPS=cfg['NUM_WARPS'],
        NUM_STAGES=cfg['NUM_STAGES'],
    )
    kc.FP16_GEMM_CFG = tri_fn.FP16_GEMM_CFG
    importlib.reload(tri_fn)

torch.manual_seed(0)
if device == 'cuda':
    torch.cuda.manual_seed(0)

# %%
kernel_grid = [
    dict(name='1x1@56', in_channels=64, out_channels=64, kernel_size=1, stride=1, padding=0, dilation=1, B=32, H=56, W=56),
    dict(name='3x3@56', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=16, H=56, W=56),
    dict(name='5x5@56', in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2, dilation=1, B=16, H=56, W=56),
    dict(name='7x7@56', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=16, H=56, W=56),
    dict(name='11x11@56', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=8, H=56, W=56),
    dict(name='3x3@112', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=16, H=112, W=112),
    dict(name='5x5@112', in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2, dilation=1, B=16, H=112, W=112),
    dict(name='7x7@112', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=12, H=112, W=112),
    dict(name='11x11@112', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=8, H=112, W=112),
    dict(name='3x3@224', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=8, H=224, W=224),
    dict(name='7x7@224', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=6, H=224, W=224),
    dict(name='11x11@224', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=4, H=224, W=224),
    dict(name='13x13@224', in_channels=64, out_channels=128, kernel_size=13, stride=1, padding=6, dilation=1, B=2, H=224, W=224),
    dict(name='3x3@512', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=4, H=512, W=512),
    dict(name='7x7@512', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=2, H=512, W=512),
    dict(name='3x3@32', in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, dilation=1, B=32, H=32, W=32),
    dict(name='5x5@32', in_channels=128, out_channels=256, kernel_size=5, stride=1, padding=2, dilation=1, B=32, H=32, W=32),
    dict(name='7x7@32', in_channels=128, out_channels=256, kernel_size=7, stride=1, padding=3, dilation=1, B=32, H=32, W=32),
    dict(name='3x3@16', in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, dilation=1, B=64, H=16, W=16),
    dict(name='3x3_s2@112', in_channels=64, out_channels=128, kernel_size=3, stride=2, padding=1, dilation=1, B=16, H=112, W=112),
    dict(name='3x3_dil2@56', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=2, dilation=2, B=16, H=56, W=56),
]
print('kernel configs:', len(kernel_grid))

block_grid = [
    dict(name='64-64-16/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=16, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-64-32/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-64-64/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=64, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-128-32/4x2', BLOCK_M=64, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='128-64-32/8x2', BLOCK_M=128, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-128-32/8x2', BLOCK_M=128, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-128-64/8x2', BLOCK_M=128, BLOCK_N=128, BLOCK_K=64, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-64-32/8x3', BLOCK_M=128, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=3),
    dict(name='64-128-32/4x3', BLOCK_M=64, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=3),
    dict(name='64-64-32/2x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=2, NUM_STAGES=2),
]
print('block configs:', len(block_grid))

keep_ratios = [1.0, 0.85, 0.75, 0.65, 0.5, 0.35, 0.25]
modes = ['dense', 'channel', 'block', 'input']
print('keep_ratios:', keep_ratios)
print('modes:', modes)
# Out:
# kernel configs: 21
# block configs: 10
# keep_ratios: [1.0, 0.85, 0.75, 0.65, 0.5, 0.35, 0.25]
# modes: ['dense', 'channel', 'block', 'input']

# %%
rows = []
if device != 'cuda':
    print('CUDA ?????????? ? ?????????? ????????.')
else:
    combos_per_kernel = len(block_grid) * (1 + 3 * len(keep_ratios))
    total = len(kernel_grid) * combos_per_kernel
    done = 0
    print(f'total combinations: {total}')
    for cfg in kernel_grid:
        torch_conv = build_torch_conv(cfg)
        x = torch.randn(cfg['B'], cfg['in_channels'], cfg['H'], cfg['W'], device=device, dtype=dtype)
        torch_time = benchmark_layer(torch_conv, x)
        torch_out = torch_conv(x).detach().float()
        for block in block_grid:
            apply_block_cfg(block)
            for mode in modes:
                ratios = keep_ratios if mode != 'dense' else [1.0]
                for ratio in ratios:
                    layer = TritonConv2d(
                        in_channels=cfg['in_channels'],
                        out_channels=cfg['out_channels'],
                        kernel_size=cfg['kernel_size'],
                        stride=cfg['stride'],
                        padding=cfg['padding'],
                        dilation=cfg['dilation'],
                        bias=True,
                    ).to(device)
                    clone_weights(layer, torch_conv)
                    apply_sparsity(layer, mode, ratio)
                    time_ms = benchmark_layer(layer, x)
                    with torch.no_grad():
                        y = layer(x).float()
                    diff_stats = calc_diff(torch_out, y)
                    done += 1
                    print(f"[{done}/{total}] kernel={cfg['name']}, block={block['name']}, mode={mode}, keep_ratio={ratio:.2f}, time_ms={time_ms:.3f}, speedup_vs_torch={torch_time/time_ms if time_ms>0 else float('nan'):.3f}", flush=True)
                    rows.append({
                        'kernel': cfg['name'],
                        'B': cfg['B'], 'H': cfg['H'], 'W': cfg['W'], 'k': cfg['kernel_size'],
                        'block': block['name'],
                        'BLOCK_M': block['BLOCK_M'], 'BLOCK_N': block['BLOCK_N'], 'BLOCK_K': block['BLOCK_K'],
                        'NUM_WARPS': block['NUM_WARPS'], 'NUM_STAGES': block['NUM_STAGES'],
                        'mode': mode,
                        'keep_ratio': float(ratio),
                        'time_ms': time_ms,
                        'torch_time_ms': torch_time,
                        'speedup_vs_torch': torch_time / time_ms if time_ms > 0 else float('nan'),
                        'mae': diff_stats['mae'],
                        'max': diff_stats['max'],
                        'rel_l2': diff_stats['rel_l2'],
                    })
results_df = pd.DataFrame(rows)
results_df
# Out:
# total combinations: 4620
# [1/4620] kernel=1x1@56, block=64-64-16/4x2, mode=dense, keep_ratio=1.00, time_ms=2.684, speedup_vs_torch=0.138
# [2/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=1.00, time_ms=2.752, speedup_vs_torch=0.134
# [3/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.85, time_ms=3.198, speedup_vs_torch=0.116
# [4/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.75, time_ms=3.159, speedup_vs_torch=0.117
# [5/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.65, time_ms=3.064, speedup_vs_torch=0.121
# [6/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.50, time_ms=2.720, speedup_vs_torch=0.136
# [7/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.35, time_ms=2.645, speedup_vs_torch=0.140
# [8/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.25, time_ms=2.453, speedup_vs_torch=0.151
# [9/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=1.00, time_ms=2.675, speedup_vs_torch=0.138
# [10/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.85, time_ms=3.354, speedup_vs_torch=0.110
# [11/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.75, time_ms=3.100, speedup_vs_torch=0.119
# [12/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.65, time_ms=2.931, speedup_vs_torch=0.126
# [13/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.50, time_ms=2.772, speedup_vs_torch=0.133
# [14/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.35, time_ms=2.749, speedup_vs_torch=0.135
# [15/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.25, time_ms=2.746, speedup_vs_torch=0.135
# [16/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=1.00, time_ms=2.858, speedup_vs_torch=0.129
# [17/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.85, time_ms=3.295, speedup_vs_torch=0.112
# [18/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.75, time_ms=3.131, speedup_vs_torch=0.118
# [19/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.65, time_ms=3.163, speedup_vs_torch=0.117
# [20/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.50, time_ms=2.992, speedup_vs_torch=0.124
# [21/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.35, time_ms=2.847, speedup_vs_torch=0.130
# [22/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.25, time_ms=2.840, speedup_vs_torch=0.130
# [23/4620] kernel=1x1@56, block=64-64-32/4x2, mode=dense, keep_ratio=1.00, time_ms=2.700, speedup_vs_torch=0.137
# [24/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=1.00, time_ms=2.762, speedup_vs_torch=0.134
# [25/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.85, time_ms=3.189, speedup_vs_torch=0.116
# [26/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.75, time_ms=3.089, speedup_vs_torch=0.120
# [27/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.65, time_ms=2.875, speedup_vs_torch=0.129
# [28/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.50, time_ms=2.771, speedup_vs_torch=0.133
# [29/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.35, time_ms=2.718, speedup_vs_torch=0.136
# [30/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.25, time_ms=2.459, speedup_vs_torch=0.150
# [31/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=1.00, time_ms=2.653, speedup_vs_torch=0.139
# [32/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.85, time_ms=3.073, speedup_vs_torch=0.120
# [33/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.75, time_ms=2.936, speedup_vs_torch=0.126
# [34/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.65, time_ms=2.735, speedup_vs_torch=0.135
# [35/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.50, time_ms=2.749, speedup_vs_torch=0.135
# [36/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.35, time_ms=2.501, speedup_vs_torch=0.148
# [37/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.25, time_ms=2.462, speedup_vs_torch=0.150
# [38/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=1.00, time_ms=2.805, speedup_vs_torch=0.132
# [39/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.85, time_ms=3.242, speedup_vs_torch=0.114
# [40/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.75, time_ms=3.113, speedup_vs_torch=0.119
# [41/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.65, time_ms=3.050, speedup_vs_torch=0.121
# [42/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.50, time_ms=3.065, speedup_vs_torch=0.121
# [43/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.35, time_ms=3.078, speedup_vs_torch=0.120
# [44/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.25, time_ms=2.758, speedup_vs_torch=0.134
# [45/4620] kernel=1x1@56, block=64-64-64/4x2, mode=dense, keep_ratio=1.00, time_ms=2.593, speedup_vs_torch=0.143
# [46/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=1.00, time_ms=2.675, speedup_vs_torch=0.138
# [47/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.85, time_ms=3.420, speedup_vs_torch=0.108
# [48/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.75, time_ms=2.997, speedup_vs_torch=0.123
# [49/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.65, time_ms=3.030, speedup_vs_torch=0.122
# [50/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.50, time_ms=2.821, speedup_vs_torch=0.131
# [51/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.35, time_ms=2.428, speedup_vs_torch=0.152
# [52/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.25, time_ms=2.507, speedup_vs_torch=0.148
# [53/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=1.00, time_ms=2.673, speedup_vs_torch=0.138
# [54/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.85, time_ms=3.178, speedup_vs_torch=0.116
# [55/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.75, time_ms=2.913, speedup_vs_torch=0.127
# [56/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.65, time_ms=2.853, speedup_vs_torch=0.130
# [57/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.50, time_ms=2.806, speedup_vs_torch=0.132
# [58/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.35, time_ms=2.825, speedup_vs_torch=0.131
# [59/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.25, time_ms=2.653, speedup_vs_torch=0.139
# [60/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=1.00, time_ms=2.786, speedup_vs_torch=0.133
# [61/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.85, time_ms=3.198, speedup_vs_torch=0.116
# [62/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.75, time_ms=3.553, speedup_vs_torch=0.104
# [63/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.65, time_ms=3.240, speedup_vs_torch=0.114
# [64/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.50, time_ms=3.015, speedup_vs_torch=0.123
# [65/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.35, time_ms=2.875, speedup_vs_torch=0.129
# [66/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.25, time_ms=2.947, speedup_vs_torch=0.125
# [67/4620] kernel=1x1@56, block=64-128-32/4x2, mode=dense, keep_ratio=1.00, time_ms=2.611, speedup_vs_torch=0.142
# [68/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=1.00, time_ms=2.754, speedup_vs_torch=0.134
# [69/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.85, time_ms=3.259, speedup_vs_torch=0.113
# [70/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.75, time_ms=3.286, speedup_vs_torch=0.113
# [71/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.65, time_ms=3.081, speedup_vs_torch=0.120
# [72/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.50, time_ms=2.846, speedup_vs_torch=0.130
# [73/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.35, time_ms=2.828, speedup_vs_torch=0.131
# [74/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.25, time_ms=2.775, speedup_vs_torch=0.133
# [75/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=1.00, time_ms=2.919, speedup_vs_torch=0.127
# [76/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.85, time_ms=3.275, speedup_vs_torch=0.113
# [77/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.75, time_ms=3.104, speedup_vs_torch=0.119
# [78/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.65, time_ms=3.101, speedup_vs_torch=0.119
# [79/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.50, time_ms=3.409, speedup_vs_torch=0.108
# [80/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.35, time_ms=2.803, speedup_vs_torch=0.132
# [81/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.25, time_ms=2.501, speedup_vs_torch=0.148
# [82/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=1.00, time_ms=2.728, speedup_vs_torch=0.136
# [83/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.85, time_ms=3.301, speedup_vs_torch=0.112
# [84/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.75, time_ms=3.126, speedup_vs_torch=0.118
# [85/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.65, time_ms=3.073, speedup_vs_torch=0.120
# [86/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.50, time_ms=2.864, speedup_vs_torch=0.129
# [87/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.35, time_ms=2.869, speedup_vs_torch=0.129
# [88/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.25, time_ms=2.785, speedup_vs_torch=0.133
# [89/4620] kernel=1x1@56, block=128-64-32/8x2, mode=dense, keep_ratio=1.00, time_ms=2.650, speedup_vs_torch=0.140
# [90/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=1.00, time_ms=2.639, speedup_vs_torch=0.140
# [91/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.85, time_ms=3.193, speedup_vs_torch=0.116
# [92/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.75, time_ms=3.099, speedup_vs_torch=0.119
# [93/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.65, time_ms=2.993, speedup_vs_torch=0.124
# [94/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.50, time_ms=2.799, speedup_vs_torch=0.132
# [95/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.35, time_ms=3.199, speedup_vs_torch=0.116
# [96/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.25, time_ms=2.588, speedup_vs_torch=0.143
# [97/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=1.00, time_ms=2.651, speedup_vs_torch=0.140
# [98/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.85, time_ms=3.175, speedup_vs_torch=0.117
# [99/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.75, time_ms=3.139, speedup_vs_torch=0.118
# [100/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.65, time_ms=3.278, speedup_vs_torch=0.113
# [101/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.50, time_ms=2.842, speedup_vs_torch=0.130
# [102/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.35, time_ms=2.647, speedup_vs_torch=0.140
# [103/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.25, time_ms=2.720, speedup_vs_torch=0.136
# [104/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=1.00, time_ms=2.745, speedup_vs_torch=0.135
# [105/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.85, time_ms=3.329, speedup_vs_torch=0.111
# [106/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.75, time_ms=3.491, speedup_vs_torch=0.106
# [107/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.65, time_ms=3.367, speedup_vs_torch=0.110
# [108/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.50, time_ms=3.012, speedup_vs_torch=0.123
# [109/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.35, time_ms=3.289, speedup_vs_torch=0.112
# [110/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.25, time_ms=2.983, speedup_vs_torch=0.124
# [111/4620] kernel=1x1@56, block=128-128-32/8x2, mode=dense, keep_ratio=1.00, time_ms=2.808, speedup_vs_torch=0.132
# [112/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=1.00, time_ms=2.742, speedup_vs_torch=0.135
# [113/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.85, time_ms=3.389, speedup_vs_torch=0.109
# [114/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.75, time_ms=3.091, speedup_vs_torch=0.120
# [115/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.65, time_ms=3.175, speedup_vs_torch=0.116
# [116/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.50, time_ms=2.914, speedup_vs_torch=0.127
# [117/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.35, time_ms=2.775, speedup_vs_torch=0.133
# [118/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.25, time_ms=2.618, speedup_vs_torch=0.141
# [119/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=1.00, time_ms=2.889, speedup_vs_torch=0.128
# [120/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.85, time_ms=3.792, speedup_vs_torch=0.098
# [121/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.75, time_ms=3.101, speedup_vs_torch=0.119
# [122/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.65, time_ms=3.155, speedup_vs_torch=0.117
# [123/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.50, time_ms=2.850, speedup_vs_torch=0.130
# [124/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.35, time_ms=2.836, speedup_vs_torch=0.130
# [125/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.25, time_ms=2.686, speedup_vs_torch=0.138
# [126/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=1.00, time_ms=2.604, speedup_vs_torch=0.142
# [127/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.85, time_ms=3.258, speedup_vs_torch=0.114
# [128/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.75, time_ms=3.107, speedup_vs_torch=0.119
# [129/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.65, time_ms=3.511, speedup_vs_torch=0.105
# [130/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.50, time_ms=3.018, speedup_vs_torch=0.123
# [131/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.35, time_ms=3.028, speedup_vs_torch=0.122
# [132/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.25, time_ms=2.851, speedup_vs_torch=0.130
# [133/4620] kernel=1x1@56, block=128-128-64/8x2, mode=dense, keep_ratio=1.00, time_ms=2.765, speedup_vs_torch=0.134
# [134/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=1.00, time_ms=2.682, speedup_vs_torch=0.138
# [135/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.85, time_ms=3.568, speedup_vs_torch=0.104
# [136/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.75, time_ms=3.108, speedup_vs_torch=0.119
# [137/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.65, time_ms=3.296, speedup_vs_torch=0.112
# [138/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.50, time_ms=3.113, speedup_vs_torch=0.119
# [139/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.35, time_ms=2.886, speedup_vs_torch=0.128
# [140/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.25, time_ms=3.095, speedup_vs_torch=0.120
# [141/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=1.00, time_ms=2.664, speedup_vs_torch=0.139
# [142/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.85, time_ms=3.517, speedup_vs_torch=0.105
# [143/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.75, time_ms=3.141, speedup_vs_torch=0.118
# [144/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.65, time_ms=3.193, speedup_vs_torch=0.116
# [145/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.50, time_ms=2.963, speedup_vs_torch=0.125
# [146/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.35, time_ms=2.787, speedup_vs_torch=0.133
# [147/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.25, time_ms=2.567, speedup_vs_torch=0.144
# [148/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=1.00, time_ms=2.897, speedup_vs_torch=0.128
# [149/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.85, time_ms=3.257, speedup_vs_torch=0.114
# [150/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.75, time_ms=3.099, speedup_vs_torch=0.119
# [151/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.65, time_ms=3.243, speedup_vs_torch=0.114
# [152/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.50, time_ms=3.184, speedup_vs_torch=0.116
# [153/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.35, time_ms=3.108, speedup_vs_torch=0.119
# [154/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.25, time_ms=3.010, speedup_vs_torch=0.123
# [155/4620] kernel=1x1@56, block=128-64-32/8x3, mode=dense, keep_ratio=1.00, time_ms=2.773, speedup_vs_torch=0.133
# [156/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=1.00, time_ms=2.642, speedup_vs_torch=0.140
# [157/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.85, time_ms=3.312, speedup_vs_torch=0.112
# [158/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.75, time_ms=3.152, speedup_vs_torch=0.117
# [159/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.65, time_ms=3.001, speedup_vs_torch=0.123
# [160/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.50, time_ms=2.832, speedup_vs_torch=0.131
# [161/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.35, time_ms=2.828, speedup_vs_torch=0.131
# [162/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.25, time_ms=2.697, speedup_vs_torch=0.137
# [163/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=1.00, time_ms=2.824, speedup_vs_torch=0.131
# [164/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.85, time_ms=3.203, speedup_vs_torch=0.115
# [165/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.75, time_ms=3.043, speedup_vs_torch=0.122
# [166/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.65, time_ms=3.114, speedup_vs_torch=0.119
# [167/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.50, time_ms=3.004, speedup_vs_torch=0.123
# [168/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.35, time_ms=3.332, speedup_vs_torch=0.111
# [169/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.25, time_ms=2.462, speedup_vs_torch=0.150
# [170/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=1.00, time_ms=2.640, speedup_vs_torch=0.140
# [171/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.85, time_ms=3.178, speedup_vs_torch=0.116
# [172/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.75, time_ms=3.008, speedup_vs_torch=0.123
# [173/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.65, time_ms=3.048, speedup_vs_torch=0.121
# [174/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=2.930, speedup_vs_torch=0.126
# [175/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=2.870, speedup_vs_torch=0.129
# [176/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=2.884, speedup_vs_torch=0.128
# [177/4620] kernel=1x1@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=2.626, speedup_vs_torch=0.141
# [178/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=2.685, speedup_vs_torch=0.138
# [179/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=3.141, speedup_vs_torch=0.118
# [180/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=3.197, speedup_vs_torch=0.116
# [181/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=2.910, speedup_vs_torch=0.127
# [182/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=2.914, speedup_vs_torch=0.127
# [183/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=2.624, speedup_vs_torch=0.141
# [184/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=2.738, speedup_vs_torch=0.135
# [185/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=2.655, speedup_vs_torch=0.139
# [186/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=3.141, speedup_vs_torch=0.118
# [187/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=3.086, speedup_vs_torch=0.120
# [188/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=2.852, speedup_vs_torch=0.130
# [189/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=2.635, speedup_vs_torch=0.140
# [190/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=2.764, speedup_vs_torch=0.134
# [191/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=3.097, speedup_vs_torch=0.119
# [192/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=2.562, speedup_vs_torch=0.144
# [193/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=3.106, speedup_vs_torch=0.119
# [194/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=2.965, speedup_vs_torch=0.125
# [195/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=3.247, speedup_vs_torch=0.114
# [196/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=3.016, speedup_vs_torch=0.123
# [197/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=2.935, speedup_vs_torch=0.126
# [198/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=3.031, speedup_vs_torch=0.122
# [199/4620] kernel=1x1@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=2.577, speedup_vs_torch=0.144
# [200/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=2.604, speedup_vs_torch=0.142
# [201/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.85, time_ms=3.389, speedup_vs_torch=0.109
# [202/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.75, time_ms=3.070, speedup_vs_torch=0.120
# [203/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.65, time_ms=3.032, speedup_vs_torch=0.122
# [204/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.50, time_ms=3.133, speedup_vs_torch=0.118
# [205/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.35, time_ms=2.890, speedup_vs_torch=0.128
# [206/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.25, time_ms=2.838, speedup_vs_torch=0.130
# [207/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=1.00, time_ms=2.648, speedup_vs_torch=0.140
# [208/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.85, time_ms=3.659, speedup_vs_torch=0.101
# [209/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.75, time_ms=3.191, speedup_vs_torch=0.116
# [210/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.65, time_ms=3.257, speedup_vs_torch=0.114
# [211/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.50, time_ms=3.029, speedup_vs_torch=0.122
# [212/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.35, time_ms=3.273, speedup_vs_torch=0.113
# [213/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.25, time_ms=2.536, speedup_vs_torch=0.146
# [214/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=1.00, time_ms=2.741, speedup_vs_torch=0.135
# [215/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.85, time_ms=3.301, speedup_vs_torch=0.112
# [216/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.75, time_ms=3.114, speedup_vs_torch=0.119
# [217/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.65, time_ms=3.003, speedup_vs_torch=0.123
# [218/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.50, time_ms=2.836, speedup_vs_torch=0.130
# [219/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.35, time_ms=2.843, speedup_vs_torch=0.130
# [220/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.25, time_ms=2.728, speedup_vs_torch=0.136
# [221/4620] kernel=3x3@56, block=64-64-16/4x2, mode=dense, keep_ratio=1.00, time_ms=4.572, speedup_vs_torch=0.195
# [222/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=1.00, time_ms=4.553, speedup_vs_torch=0.195
# [223/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.85, time_ms=5.351, speedup_vs_torch=0.166
# [224/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.75, time_ms=5.371, speedup_vs_torch=0.166
# [225/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.65, time_ms=5.228, speedup_vs_torch=0.170
# [226/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.50, time_ms=4.381, speedup_vs_torch=0.203
# [227/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.35, time_ms=4.225, speedup_vs_torch=0.210
# [228/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.25, time_ms=3.981, speedup_vs_torch=0.223
# [229/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=1.00, time_ms=4.806, speedup_vs_torch=0.185
# [230/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.85, time_ms=5.562, speedup_vs_torch=0.160
# [231/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.75, time_ms=4.894, speedup_vs_torch=0.182
# [232/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.65, time_ms=5.227, speedup_vs_torch=0.170
# [233/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.50, time_ms=3.972, speedup_vs_torch=0.224
# [234/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.35, time_ms=3.968, speedup_vs_torch=0.224
# [235/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.25, time_ms=3.697, speedup_vs_torch=0.241
# [236/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=1.00, time_ms=4.591, speedup_vs_torch=0.194
# [237/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.85, time_ms=4.801, speedup_vs_torch=0.185
# [238/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.75, time_ms=4.285, speedup_vs_torch=0.208
# [239/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.65, time_ms=4.434, speedup_vs_torch=0.201
# [240/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.50, time_ms=3.680, speedup_vs_torch=0.242
# [241/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.35, time_ms=3.649, speedup_vs_torch=0.244
# [242/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.25, time_ms=3.267, speedup_vs_torch=0.272
# [243/4620] kernel=3x3@56, block=64-64-32/4x2, mode=dense, keep_ratio=1.00, time_ms=4.307, speedup_vs_torch=0.206
# [244/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=1.00, time_ms=4.224, speedup_vs_torch=0.211
# [245/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.85, time_ms=5.351, speedup_vs_torch=0.166
# [246/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.75, time_ms=4.646, speedup_vs_torch=0.191
# [247/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.65, time_ms=5.056, speedup_vs_torch=0.176
# [248/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.50, time_ms=4.250, speedup_vs_torch=0.209
# [249/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.35, time_ms=4.070, speedup_vs_torch=0.219
# [250/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.25, time_ms=3.671, speedup_vs_torch=0.242
# [251/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=1.00, time_ms=4.314, speedup_vs_torch=0.206
# [252/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.85, time_ms=5.442, speedup_vs_torch=0.163
# [253/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.75, time_ms=4.775, speedup_vs_torch=0.186
# [254/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.65, time_ms=5.448, speedup_vs_torch=0.163
# [255/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.50, time_ms=4.449, speedup_vs_torch=0.200
# [256/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.35, time_ms=4.184, speedup_vs_torch=0.213
# [257/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.25, time_ms=4.368, speedup_vs_torch=0.204
# [258/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=1.00, time_ms=4.259, speedup_vs_torch=0.209
# [259/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.85, time_ms=4.862, speedup_vs_torch=0.183
# [260/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.75, time_ms=4.359, speedup_vs_torch=0.204
# [261/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.65, time_ms=4.285, speedup_vs_torch=0.208
# [262/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.50, time_ms=4.003, speedup_vs_torch=0.222
# [263/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.35, time_ms=3.852, speedup_vs_torch=0.231
# [264/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.25, time_ms=3.657, speedup_vs_torch=0.243
# [265/4620] kernel=3x3@56, block=64-64-64/4x2, mode=dense, keep_ratio=1.00, time_ms=4.215, speedup_vs_torch=0.211
# [266/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=1.00, time_ms=4.102, speedup_vs_torch=0.217
# [267/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.85, time_ms=5.598, speedup_vs_torch=0.159
# [268/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.75, time_ms=4.746, speedup_vs_torch=0.187
# [269/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.65, time_ms=5.168, speedup_vs_torch=0.172
# [270/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.50, time_ms=4.108, speedup_vs_torch=0.216
# [271/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.35, time_ms=4.104, speedup_vs_torch=0.217
# [272/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.25, time_ms=3.710, speedup_vs_torch=0.240
# [273/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=1.00, time_ms=4.228, speedup_vs_torch=0.210
# [274/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.85, time_ms=5.223, speedup_vs_torch=0.170
# [275/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.75, time_ms=4.479, speedup_vs_torch=0.199
# [276/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.65, time_ms=5.211, speedup_vs_torch=0.171
# [277/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.50, time_ms=3.949, speedup_vs_torch=0.225
# [278/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.35, time_ms=4.306, speedup_vs_torch=0.207
# [279/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.25, time_ms=3.769, speedup_vs_torch=0.236
# [280/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=1.00, time_ms=4.453, speedup_vs_torch=0.200
# [281/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.85, time_ms=4.917, speedup_vs_torch=0.181
# [282/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.75, time_ms=4.383, speedup_vs_torch=0.203
# [283/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.65, time_ms=4.193, speedup_vs_torch=0.212
# [284/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.50, time_ms=3.969, speedup_vs_torch=0.224
# [285/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.35, time_ms=3.765, speedup_vs_torch=0.236
# [286/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.25, time_ms=3.557, speedup_vs_torch=0.250
# [287/4620] kernel=3x3@56, block=64-128-32/4x2, mode=dense, keep_ratio=1.00, time_ms=4.021, speedup_vs_torch=0.221
# [288/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=1.00, time_ms=3.867, speedup_vs_torch=0.230
# [289/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.85, time_ms=5.411, speedup_vs_torch=0.164
# [290/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.75, time_ms=4.525, speedup_vs_torch=0.197
# [291/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.65, time_ms=5.163, speedup_vs_torch=0.172
# [292/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.50, time_ms=4.293, speedup_vs_torch=0.207
# [293/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.35, time_ms=4.703, speedup_vs_torch=0.189
# [294/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.25, time_ms=3.990, speedup_vs_torch=0.223
# [295/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=1.00, time_ms=3.994, speedup_vs_torch=0.223
# [296/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.85, time_ms=5.328, speedup_vs_torch=0.167
# [297/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.75, time_ms=4.298, speedup_vs_torch=0.207
# [298/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.65, time_ms=5.365, speedup_vs_torch=0.166
# [299/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.50, time_ms=3.974, speedup_vs_torch=0.224
# [300/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.35, time_ms=4.457, speedup_vs_torch=0.200
# [301/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.25, time_ms=3.804, speedup_vs_torch=0.234
# [302/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=1.00, time_ms=4.072, speedup_vs_torch=0.218
# [303/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.85, time_ms=4.572, speedup_vs_torch=0.195
# [304/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.75, time_ms=4.282, speedup_vs_torch=0.208
# [305/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.65, time_ms=3.841, speedup_vs_torch=0.232
# [306/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.50, time_ms=3.451, speedup_vs_torch=0.258
# [307/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.35, time_ms=3.485, speedup_vs_torch=0.255
# [308/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.25, time_ms=3.261, speedup_vs_torch=0.273
# [309/4620] kernel=3x3@56, block=128-64-32/8x2, mode=dense, keep_ratio=1.00, time_ms=4.255, speedup_vs_torch=0.209
# [310/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=1.00, time_ms=4.183, speedup_vs_torch=0.213
# [311/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.85, time_ms=5.127, speedup_vs_torch=0.173
# [312/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.75, time_ms=4.906, speedup_vs_torch=0.181
# [313/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.65, time_ms=5.114, speedup_vs_torch=0.174
# [314/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.50, time_ms=4.127, speedup_vs_torch=0.215
# [315/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.35, time_ms=4.176, speedup_vs_torch=0.213
# [316/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.25, time_ms=3.906, speedup_vs_torch=0.228
# [317/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=1.00, time_ms=4.394, speedup_vs_torch=0.202
# [318/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.85, time_ms=5.543, speedup_vs_torch=0.160
# [319/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.75, time_ms=4.832, speedup_vs_torch=0.184
# [320/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.65, time_ms=4.987, speedup_vs_torch=0.178
# [321/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.50, time_ms=4.419, speedup_vs_torch=0.201
# [322/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.35, time_ms=4.580, speedup_vs_torch=0.194
# [323/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.25, time_ms=3.726, speedup_vs_torch=0.239
# [324/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=1.00, time_ms=4.579, speedup_vs_torch=0.194
# [325/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.85, time_ms=4.970, speedup_vs_torch=0.179
# [326/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.75, time_ms=4.713, speedup_vs_torch=0.189
# [327/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.65, time_ms=4.439, speedup_vs_torch=0.200
# [328/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.50, time_ms=3.735, speedup_vs_torch=0.238
# [329/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.35, time_ms=4.134, speedup_vs_torch=0.215
# [330/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.25, time_ms=4.341, speedup_vs_torch=0.205
# [331/4620] kernel=3x3@56, block=128-128-32/8x2, mode=dense, keep_ratio=1.00, time_ms=4.855, speedup_vs_torch=0.183
# [332/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=1.00, time_ms=4.329, speedup_vs_torch=0.205
# [333/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.85, time_ms=5.686, speedup_vs_torch=0.156
# [334/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.75, time_ms=5.197, speedup_vs_torch=0.171
# [335/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.65, time_ms=5.493, speedup_vs_torch=0.162
# [336/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.50, time_ms=4.557, speedup_vs_torch=0.195
# [337/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.35, time_ms=4.957, speedup_vs_torch=0.179
# [338/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.25, time_ms=4.388, speedup_vs_torch=0.203
# [339/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=1.00, time_ms=4.458, speedup_vs_torch=0.199
# [340/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.85, time_ms=5.968, speedup_vs_torch=0.149
# [341/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.75, time_ms=4.800, speedup_vs_torch=0.185
# [342/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.65, time_ms=5.437, speedup_vs_torch=0.164
# [343/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.50, time_ms=4.836, speedup_vs_torch=0.184
# [344/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.35, time_ms=4.926, speedup_vs_torch=0.181
# [345/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.25, time_ms=4.367, speedup_vs_torch=0.204
# [346/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=1.00, time_ms=4.447, speedup_vs_torch=0.200
# [347/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.85, time_ms=5.032, speedup_vs_torch=0.177
# [348/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.75, time_ms=4.495, speedup_vs_torch=0.198
# [349/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.65, time_ms=4.749, speedup_vs_torch=0.187
# [350/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.50, time_ms=3.944, speedup_vs_torch=0.226
# [351/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.35, time_ms=4.284, speedup_vs_torch=0.208
# [352/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.25, time_ms=3.906, speedup_vs_torch=0.228
# [353/4620] kernel=3x3@56, block=128-128-64/8x2, mode=dense, keep_ratio=1.00, time_ms=4.505, speedup_vs_torch=0.197
# [354/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=1.00, time_ms=4.674, speedup_vs_torch=0.190
# [355/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.85, time_ms=6.979, speedup_vs_torch=0.127
# [356/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.75, time_ms=5.024, speedup_vs_torch=0.177
# [357/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.65, time_ms=6.396, speedup_vs_torch=0.139
# [358/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.50, time_ms=4.581, speedup_vs_torch=0.194
# [359/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.35, time_ms=5.169, speedup_vs_torch=0.172
# [360/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.25, time_ms=4.410, speedup_vs_torch=0.202
# [361/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=1.00, time_ms=4.329, speedup_vs_torch=0.205
# [362/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.85, time_ms=6.259, speedup_vs_torch=0.142
# [363/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.75, time_ms=4.856, speedup_vs_torch=0.183
# [364/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.65, time_ms=6.196, speedup_vs_torch=0.144
# [365/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.50, time_ms=4.902, speedup_vs_torch=0.181
# [366/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.35, time_ms=5.262, speedup_vs_torch=0.169
# [367/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.25, time_ms=4.552, speedup_vs_torch=0.195
# [368/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=1.00, time_ms=4.575, speedup_vs_torch=0.194
# [369/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.85, time_ms=5.091, speedup_vs_torch=0.175
# [370/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.75, time_ms=4.240, speedup_vs_torch=0.210
# [371/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.65, time_ms=4.414, speedup_vs_torch=0.202
# [372/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.50, time_ms=4.199, speedup_vs_torch=0.212
# [373/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.35, time_ms=4.017, speedup_vs_torch=0.221
# [374/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.25, time_ms=3.726, speedup_vs_torch=0.239
# [375/4620] kernel=3x3@56, block=128-64-32/8x3, mode=dense, keep_ratio=1.00, time_ms=4.813, speedup_vs_torch=0.185
# [376/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=1.00, time_ms=4.594, speedup_vs_torch=0.194
# [377/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.85, time_ms=5.808, speedup_vs_torch=0.153
# [378/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.75, time_ms=5.379, speedup_vs_torch=0.165
# [379/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.65, time_ms=7.399, speedup_vs_torch=0.120
# [380/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.50, time_ms=5.060, speedup_vs_torch=0.176
# [381/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.35, time_ms=4.989, speedup_vs_torch=0.178
# [382/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.25, time_ms=4.365, speedup_vs_torch=0.204
# [383/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=1.00, time_ms=4.503, speedup_vs_torch=0.198
# [384/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.85, time_ms=6.959, speedup_vs_torch=0.128
# [385/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.75, time_ms=5.393, speedup_vs_torch=0.165
# [386/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.65, time_ms=6.089, speedup_vs_torch=0.146
# [387/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.50, time_ms=5.694, speedup_vs_torch=0.156
# [388/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.35, time_ms=5.351, speedup_vs_torch=0.166
# [389/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.25, time_ms=5.497, speedup_vs_torch=0.162
# [390/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=1.00, time_ms=4.661, speedup_vs_torch=0.191
# [391/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.85, time_ms=4.683, speedup_vs_torch=0.190
# [392/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.75, time_ms=4.428, speedup_vs_torch=0.201
# [393/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.65, time_ms=5.092, speedup_vs_torch=0.175
# [394/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=4.031, speedup_vs_torch=0.221
# [395/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=3.742, speedup_vs_torch=0.238
# [396/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=3.461, speedup_vs_torch=0.257
# [397/4620] kernel=3x3@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=3.919, speedup_vs_torch=0.227
# [398/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=3.861, speedup_vs_torch=0.230
# [399/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=5.173, speedup_vs_torch=0.172
# [400/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=4.329, speedup_vs_torch=0.205
# [401/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=5.065, speedup_vs_torch=0.176
# [402/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=4.092, speedup_vs_torch=0.217
# [403/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=4.346, speedup_vs_torch=0.205
# [404/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=3.888, speedup_vs_torch=0.229
# [405/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=3.933, speedup_vs_torch=0.226
# [406/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=5.454, speedup_vs_torch=0.163
# [407/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=5.108, speedup_vs_torch=0.174
# [408/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=5.539, speedup_vs_torch=0.161
# [409/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=4.691, speedup_vs_torch=0.190
# [410/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=4.803, speedup_vs_torch=0.185
# [411/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=4.008, speedup_vs_torch=0.222
# [412/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=3.818, speedup_vs_torch=0.233
# [413/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=4.422, speedup_vs_torch=0.201
# [414/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=4.133, speedup_vs_torch=0.215
# [415/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=3.957, speedup_vs_torch=0.225
# [416/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=3.702, speedup_vs_torch=0.240
# [417/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=3.579, speedup_vs_torch=0.248
# [418/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=3.456, speedup_vs_torch=0.257
# [419/4620] kernel=3x3@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=4.257, speedup_vs_torch=0.209
# [420/4620] kernel=3x3@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=4.317, speedup_vs_torch=0.206
# ...
# [614/4620] kernel=5x5@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=5.660, speedup_vs_torch=0.306
# [615/4620] kernel=5x5@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=4.856, speedup_vs_torch=0.357
# [616/4620] kernel=5x5@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=4.173, speedup_vs_torch=0.415
# [617/4620] kernel=5x5@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=6.242, speedup_vs_torch=0.278
# [618/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=6.431, speedup_vs_torch=0.269
# [619/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=8.830, speedup_vs_torch=0.196
# [620/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=6.595, speedup_vs_torch=0.263
# [621/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=8.416, speedup_vs_torch=0.206
# [622/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=6.186, speedup_vs_torch=0.280
# [623/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=7.897, speedup_vs_torch=0.219
# [624/4620] kernel=5x5@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=6.152, speedup_vs_torch=0.282
# [625/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=6.005, speedup_vs_torch=0.289
# [626/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=8.646, speedup_vs_torch=0.200
# [627/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=6.406, speedup_vs_torch=0.271
# [628/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=8.347, speedup_vs_torch=0.208
# [629/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=6.164, speedup_vs_torch=0.281
# [630/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=7.838, speedup_vs_torch=0.221
# [631/4620] kernel=5x5@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=5.920, speedup_vs_torch=0.293
# [632/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=6.153, speedup_vs_torch=0.282
# [633/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=6.539, speedup_vs_torch=0.265
# [634/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=5.708, speedup_vs_torch=0.304
# [635/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=5.699, speedup_vs_torch=0.304
# [636/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=4.839, speedup_vs_torch=0.358
# [637/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=4.398, speedup_vs_torch=0.394
# [638/4620] kernel=5x5@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=3.875, speedup_vs_torch=0.447
# [639/4620] kernel=5x5@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=7.001, speedup_vs_torch=0.247
# [640/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=7.128, speedup_vs_torch=0.243
# [641/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.85, time_ms=11.593, speedup_vs_torch=0.149
# [642/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.75, time_ms=7.611, speedup_vs_torch=0.228
# [643/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.65, time_ms=11.439, speedup_vs_torch=0.151
# [644/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.50, time_ms=6.208, speedup_vs_torch=0.279
# [645/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.35, time_ms=8.005, speedup_vs_torch=0.216
# [646/4620] kernel=5x5@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.25, time_ms=5.737, speedup_vs_torch=0.302
# [647/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=1.00, time_ms=6.917, speedup_vs_torch=0.251
# [648/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.85, time_ms=12.188, speedup_vs_torch=0.142
# [649/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.75, time_ms=8.335, speedup_vs_torch=0.208
# [650/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.65, time_ms=11.826, speedup_vs_torch=0.147
# [651/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.50, time_ms=6.256, speedup_vs_torch=0.277
# [652/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.35, time_ms=8.385, speedup_vs_torch=0.207
# [653/4620] kernel=5x5@56, block=64-64-32/2x2, mode=block, keep_ratio=0.25, time_ms=5.974, speedup_vs_torch=0.290
# [654/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=1.00, time_ms=7.080, speedup_vs_torch=0.245
# [655/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.85, time_ms=9.163, speedup_vs_torch=0.189
# [656/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.75, time_ms=6.757, speedup_vs_torch=0.256
# [657/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.65, time_ms=8.033, speedup_vs_torch=0.216
# [658/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.50, time_ms=5.315, speedup_vs_torch=0.326
# [659/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.35, time_ms=5.770, speedup_vs_torch=0.300
# [660/4620] kernel=5x5@56, block=64-64-32/2x2, mode=input, keep_ratio=0.25, time_ms=4.523, speedup_vs_torch=0.383
# [661/4620] kernel=7x7@56, block=64-64-16/4x2, mode=dense, keep_ratio=1.00, time_ms=16.007, speedup_vs_torch=0.197
# [662/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=1.00, time_ms=16.141, speedup_vs_torch=0.195
# [663/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.85, time_ms=18.918, speedup_vs_torch=0.166
# [664/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.75, time_ms=16.859, speedup_vs_torch=0.187
# [665/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.65, time_ms=18.401, speedup_vs_torch=0.171
# [666/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.50, time_ms=11.704, speedup_vs_torch=0.269
# [667/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.35, time_ms=12.601, speedup_vs_torch=0.250
# [668/4620] kernel=7x7@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.25, time_ms=11.461, speedup_vs_torch=0.275
# [669/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=1.00, time_ms=16.397, speedup_vs_torch=0.192
# [670/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.85, time_ms=18.693, speedup_vs_torch=0.168
# [671/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.75, time_ms=16.521, speedup_vs_torch=0.191
# [672/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.65, time_ms=18.297, speedup_vs_torch=0.172
# [673/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.50, time_ms=11.653, speedup_vs_torch=0.270
# [674/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.35, time_ms=12.492, speedup_vs_torch=0.252
# [675/4620] kernel=7x7@56, block=64-64-16/4x2, mode=block, keep_ratio=0.25, time_ms=11.361, speedup_vs_torch=0.277
# [676/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=1.00, time_ms=15.898, speedup_vs_torch=0.198
# [677/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.85, time_ms=15.556, speedup_vs_torch=0.202
# [678/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.75, time_ms=13.612, speedup_vs_torch=0.231
# [679/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.65, time_ms=12.696, speedup_vs_torch=0.248
# [680/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.50, time_ms=9.492, speedup_vs_torch=0.332
# [681/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.35, time_ms=8.103, speedup_vs_torch=0.388
# [682/4620] kernel=7x7@56, block=64-64-16/4x2, mode=input, keep_ratio=0.25, time_ms=6.144, speedup_vs_torch=0.512
# [683/4620] kernel=7x7@56, block=64-64-32/4x2, mode=dense, keep_ratio=1.00, time_ms=11.916, speedup_vs_torch=0.264
# [684/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=1.00, time_ms=11.793, speedup_vs_torch=0.267
# [685/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.85, time_ms=15.920, speedup_vs_torch=0.198
# [686/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.75, time_ms=12.327, speedup_vs_torch=0.255
# [687/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.65, time_ms=15.825, speedup_vs_torch=0.199
# [688/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.50, time_ms=10.216, speedup_vs_torch=0.308
# [689/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.35, time_ms=11.940, speedup_vs_torch=0.264
# [690/4620] kernel=7x7@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.25, time_ms=9.566, speedup_vs_torch=0.329
# [691/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=1.00, time_ms=11.546, speedup_vs_torch=0.273
# [692/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.85, time_ms=15.602, speedup_vs_torch=0.202
# [693/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.75, time_ms=11.868, speedup_vs_torch=0.265
# [694/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.65, time_ms=14.797, speedup_vs_torch=0.213
# [695/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.50, time_ms=9.493, speedup_vs_torch=0.332
# [696/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.35, time_ms=10.646, speedup_vs_torch=0.296
# [697/4620] kernel=7x7@56, block=64-64-32/4x2, mode=block, keep_ratio=0.25, time_ms=8.595, speedup_vs_torch=0.366
# [698/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=1.00, time_ms=11.239, speedup_vs_torch=0.280
# [699/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.85, time_ms=11.712, speedup_vs_torch=0.269
# [700/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.75, time_ms=9.461, speedup_vs_torch=0.333
# [701/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.65, time_ms=9.770, speedup_vs_torch=0.322
# [702/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.50, time_ms=7.113, speedup_vs_torch=0.443
# [703/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.35, time_ms=6.635, speedup_vs_torch=0.474
# [704/4620] kernel=7x7@56, block=64-64-32/4x2, mode=input, keep_ratio=0.25, time_ms=5.198, speedup_vs_torch=0.606
# [705/4620] kernel=7x7@56, block=64-64-64/4x2, mode=dense, keep_ratio=1.00, time_ms=10.654, speedup_vs_torch=0.295
# [706/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=1.00, time_ms=10.722, speedup_vs_torch=0.294
# [707/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.85, time_ms=15.444, speedup_vs_torch=0.204
# [708/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.75, time_ms=11.106, speedup_vs_torch=0.283
# [709/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.65, time_ms=14.940, speedup_vs_torch=0.211
# [710/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.50, time_ms=8.819, speedup_vs_torch=0.357
# [711/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.35, time_ms=9.848, speedup_vs_torch=0.320
# [712/4620] kernel=7x7@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.25, time_ms=8.550, speedup_vs_torch=0.368
# [713/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=1.00, time_ms=10.978, speedup_vs_torch=0.287
# [714/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.85, time_ms=14.321, speedup_vs_torch=0.220
# [715/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.75, time_ms=11.186, speedup_vs_torch=0.281
# [716/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.65, time_ms=14.046, speedup_vs_torch=0.224
# [717/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.50, time_ms=8.731, speedup_vs_torch=0.361
# [718/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.35, time_ms=9.965, speedup_vs_torch=0.316
# [719/4620] kernel=7x7@56, block=64-64-64/4x2, mode=block, keep_ratio=0.25, time_ms=8.482, speedup_vs_torch=0.371
# [720/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=1.00, time_ms=10.843, speedup_vs_torch=0.290
# [721/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.85, time_ms=12.121, speedup_vs_torch=0.260
# [722/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.75, time_ms=9.770, speedup_vs_torch=0.322
# [723/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.65, time_ms=10.023, speedup_vs_torch=0.314
# [724/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.50, time_ms=7.223, speedup_vs_torch=0.436
# [725/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.35, time_ms=6.516, speedup_vs_torch=0.483
# [726/4620] kernel=7x7@56, block=64-64-64/4x2, mode=input, keep_ratio=0.25, time_ms=5.155, speedup_vs_torch=0.611
# [727/4620] kernel=7x7@56, block=64-128-32/4x2, mode=dense, keep_ratio=1.00, time_ms=9.717, speedup_vs_torch=0.324
# [728/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=1.00, time_ms=9.665, speedup_vs_torch=0.326
# [729/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.85, time_ms=14.457, speedup_vs_torch=0.218
# [730/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.75, time_ms=10.043, speedup_vs_torch=0.313
# [731/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.65, time_ms=14.054, speedup_vs_torch=0.224
# [732/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.50, time_ms=9.712, speedup_vs_torch=0.324
# [733/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.35, time_ms=13.829, speedup_vs_torch=0.228
# [734/4620] kernel=7x7@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.25, time_ms=9.666, speedup_vs_torch=0.326
# [735/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=1.00, time_ms=9.768, speedup_vs_torch=0.322
# [736/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.85, time_ms=14.569, speedup_vs_torch=0.216
# [737/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.75, time_ms=10.255, speedup_vs_torch=0.307
# [738/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.65, time_ms=14.353, speedup_vs_torch=0.219
# [739/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.50, time_ms=10.144, speedup_vs_torch=0.310
# [740/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.35, time_ms=14.086, speedup_vs_torch=0.223
# [741/4620] kernel=7x7@56, block=64-128-32/4x2, mode=block, keep_ratio=0.25, time_ms=9.942, speedup_vs_torch=0.317
# [742/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=1.00, time_ms=10.236, speedup_vs_torch=0.308
# [743/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.85, time_ms=11.742, speedup_vs_torch=0.268
# [744/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.75, time_ms=8.381, speedup_vs_torch=0.376
# [745/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.65, time_ms=9.138, speedup_vs_torch=0.344
# [746/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.50, time_ms=7.236, speedup_vs_torch=0.435
# [747/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.35, time_ms=6.544, speedup_vs_torch=0.481
# [748/4620] kernel=7x7@56, block=64-128-32/4x2, mode=input, keep_ratio=0.25, time_ms=5.135, speedup_vs_torch=0.613
# [749/4620] kernel=7x7@56, block=128-64-32/8x2, mode=dense, keep_ratio=1.00, time_ms=12.017, speedup_vs_torch=0.262
# [750/4620] kernel=7x7@56, block=128-64-32/8x2, mode=channel, keep_ratio=1.00, time_ms=11.923, speedup_vs_torch=0.264
# [751/4620] kernel=7x7@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.85, time_ms=14.854, speedup_vs_torch=0.212
# [752/4620] kernel=7x7@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.75, time_ms=12.326, speedup_vs_torch=0.255
# KeyboardInterrupt

# %%
if not results_df.empty:
    best_df = results_df.sort_values('time_ms', ascending=True).groupby('kernel', as_index=False).first()
    display(best_df[['kernel', 'block', 'mode', 'keep_ratio', 'time_ms', 'speedup_vs_torch']])
else:
    print('??? ???????????: ????????? ???????? ?? CUDA.')

# %%
if not results_df.empty:
    out_all = Path('notebooks/sparsity_kernel_search_results.csv')
    out_best = Path('notebooks/sparsity_kernel_best.csv')
    results_df.to_csv(out_all, index=False)
    results_df.sort_values('time_ms', ascending=True).groupby('kernel', as_index=False).first().to_csv(out_best, index=False)
    print('saved:', out_all)
    print('saved:', out_best)
else:
    print('??? ?????? ??? ??????????.')
