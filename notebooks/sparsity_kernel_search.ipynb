# %% [markdown]
# # Поиск быстрых конфигураций (shape × блоки Triton × sparsity)
#
# Этот ноутбук перебирает сетку параметров свёртки (Kh/Kw, H/W, batch B), тюнинг блоков Triton (BLOCK_M/N/K, NUM_WARPS/NUM_STAGES) и три режима разрежения (`channel`, `block`, `input` с `keep_ratio`). Цель — найти комбинации, где `TritonConv2d` быстрее `nn.Conv2d` при приемлемой точности. Все замеры на CUDA, с прогревом.
#
# **Метрики, которые считаются и выводятся:**
# - `time_ms` — среднее время forward TritonConv2d (мс) для конкретной конфигурации.
# - `torch_time_ms` — среднее время `nn.Conv2d` на той же задаче.
# - `speedup_vs_torch` — отношение `torch_time_ms / time_ms`; >1 — Triton быстрее, <1 — медленнее.
# - Ошибки (Triton vs torch): `mae`, `max`, `rel_l2`.
# - Описание задачи: `kernel` (формат `KhxKw@B,H,W,k`) и `block` (компактная строка `BLOCK_M-BLOCK_N-BLOCK_K/NUM_WARPSxNUM_STAGES`).
# - Sparsity: `mode` (`channel`, `block`, `input`), `keep_ratio` (доля оставленных каналов), `block_size` (для block sparsity), а также явные поля BLOCK_* для удобства фильтрации.
#
# **Как читать результаты:**
# - Сравнивайте `speedup_vs_torch` и ошибки: строки с `speedup_vs_torch > 1` и малыми `mae`/`rel_l2` — кандидаты на “лучшие”.
# - При малом `keep_ratio` ожидается ускорение, но эффективность зависит от паддинга K (img2col) и выбранных BLOCK_*; иногда `speedup_vs_torch` падает.
# - Для block sparsity оценивайте сочетание `keep_ratio` и `block_size` — группировка может улучшать или ухудшать тайлинг.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))
print('sys.path[0]=', sys.path[0])
# Out:
# sys.path[0]= /home/manzhura/ITMO/EDLM/conv2d-img2col-gemm

# %%
import time
import torch
import pandas as pd
from pathlib import Path
import importlib
from conv_gemm.baseline_layers.triton_conv2d import TritonConv2d
import conv_gemm.baseline_operators.triton_conv2d_fp16_fn as tri_fn
from conv_gemm.configs import kernel_config as kc

torch.backends.cudnn.benchmark = True
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dtype = torch.float16 if device == 'cuda' else torch.float32
print(f'device={device}, dtype={dtype}')
# Out:
# device=cuda, dtype=torch.float16

# %%
def sync_device():
    if device == 'cuda':
        torch.cuda.synchronize()

def clone_weights(dst: torch.nn.Module, src: torch.nn.Module):
    with torch.no_grad():
        dst.weight.copy_(src.weight)
        if dst.bias is not None and src.bias is not None:
            dst.bias.copy_(src.bias)

def benchmark_layer(layer: torch.nn.Module, x: torch.Tensor, warmup: int = 10, iters: int = 50) -> float:
    layer.eval()
    with torch.no_grad():
        for _ in range(warmup):
            _ = layer(x)
        sync_device()
        if device == 'cuda':
            start = torch.cuda.Event(enable_timing=True)
            end = torch.cuda.Event(enable_timing=True)
            start.record()
            for _ in range(iters):
                _ = layer(x)
            end.record()
            sync_device()
            elapsed_ms = start.elapsed_time(end)
        else:
            t0 = time.perf_counter()
            for _ in range(iters):
                _ = layer(x)
            elapsed_ms = (time.perf_counter() - t0) * 1e3
    return elapsed_ms / iters

def build_torch_conv(cfg):
    return torch.nn.Conv2d(
        in_channels=cfg['in_channels'],
        out_channels=cfg['out_channels'],
        kernel_size=cfg['kernel_size'],
        stride=cfg['stride'],
        padding=cfg['padding'],
        dilation=cfg['dilation'],
        bias=True,
    ).to(device=device, dtype=dtype)

def calc_diff(ref: torch.Tensor, test: torch.Tensor):
    diff = (ref - test).float()
    return {
        'mae': diff.abs().mean().item(),
        'max': diff.abs().max().item(),
        'rel_l2': (torch.norm(diff) / torch.norm(ref)).item(),
    }

def apply_sparsity(layer: TritonConv2d, mode: str, ratio: float):
    layer.clear_sparsity()
    if mode == 'dense':
        return
    if mode == 'channel':
        layer.set_channel_sparsity(ratio)
    elif mode == 'block':
        layer.set_block_sparsity(ratio, block_size=4)
    elif mode == 'input':
        layer.set_input_channel_sparsity(ratio)
    else:
        raise ValueError(f'unknown mode {mode}')

def apply_block_cfg(cfg):
    tri_fn.FP16_GEMM_CFG = kc.KernelConfig(
        BLOCK_M=cfg['BLOCK_M'],
        BLOCK_N=cfg['BLOCK_N'],
        BLOCK_K=cfg['BLOCK_K'],
        NUM_WARPS=cfg['NUM_WARPS'],
        NUM_STAGES=cfg['NUM_STAGES'],
    )
    kc.FP16_GEMM_CFG = tri_fn.FP16_GEMM_CFG
    importlib.reload(tri_fn)

torch.manual_seed(0)
if device == 'cuda':
    torch.cuda.manual_seed(0)

# %%
kernel_grid = [
    dict(name='1x1@56', in_channels=64, out_channels=64, kernel_size=1, stride=1, padding=0, dilation=1, B=32, H=56, W=56),
    dict(name='3x3@56', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=16, H=56, W=56),
    dict(name='5x5@56', in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2, dilation=1, B=16, H=56, W=56),
    dict(name='7x7@56', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=16, H=56, W=56),
    dict(name='11x11@56', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=8, H=56, W=56),
    dict(name='3x3@112', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=16, H=112, W=112),
    dict(name='5x5@112', in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2, dilation=1, B=16, H=112, W=112),
    dict(name='7x7@112', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=12, H=112, W=112),
    dict(name='11x11@112', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=8, H=112, W=112),
    dict(name='3x3@224', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=8, H=224, W=224),
    dict(name='7x7@224', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=6, H=224, W=224),
    dict(name='11x11@224', in_channels=64, out_channels=128, kernel_size=11, stride=1, padding=5, dilation=1, B=4, H=224, W=224),
    dict(name='13x13@224', in_channels=64, out_channels=128, kernel_size=13, stride=1, padding=6, dilation=1, B=2, H=224, W=224),
    dict(name='3x3@512', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, dilation=1, B=4, H=512, W=512),
    dict(name='7x7@512', in_channels=64, out_channels=128, kernel_size=7, stride=1, padding=3, dilation=1, B=2, H=512, W=512),
    dict(name='3x3@32', in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, dilation=1, B=32, H=32, W=32),
    dict(name='5x5@32', in_channels=128, out_channels=256, kernel_size=5, stride=1, padding=2, dilation=1, B=32, H=32, W=32),
    dict(name='7x7@32', in_channels=128, out_channels=256, kernel_size=7, stride=1, padding=3, dilation=1, B=32, H=32, W=32),
    dict(name='3x3@16', in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, dilation=1, B=64, H=16, W=16),
    dict(name='3x3_s2@112', in_channels=64, out_channels=128, kernel_size=3, stride=2, padding=1, dilation=1, B=16, H=112, W=112),
    dict(name='3x3_dil2@56', in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=2, dilation=2, B=16, H=56, W=56),
]
print('kernel configs:', len(kernel_grid))

block_grid = [
    dict(name='64-64-16/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=16, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-64-32/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-64-64/4x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=64, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='64-128-32/4x2', BLOCK_M=64, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=2),
    dict(name='128-64-32/8x2', BLOCK_M=128, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-128-32/8x2', BLOCK_M=128, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-128-64/8x2', BLOCK_M=128, BLOCK_N=128, BLOCK_K=64, NUM_WARPS=8, NUM_STAGES=2),
    dict(name='128-64-32/8x3', BLOCK_M=128, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=8, NUM_STAGES=3),
    dict(name='64-128-32/4x3', BLOCK_M=64, BLOCK_N=128, BLOCK_K=32, NUM_WARPS=4, NUM_STAGES=3),
    dict(name='64-64-32/2x2', BLOCK_M=64, BLOCK_N=64, BLOCK_K=32, NUM_WARPS=2, NUM_STAGES=2),
]
print('block configs:', len(block_grid))

keep_ratios = [1.0, 0.85, 0.75, 0.65, 0.5, 0.35, 0.25]
modes = ['dense', 'channel', 'block', 'input']
print('keep_ratios:', keep_ratios)
print('modes:', modes)
# Out:
# kernel configs: 21
# block configs: 10
# keep_ratios: [1.0, 0.85, 0.75, 0.65, 0.5, 0.35, 0.25]
# modes: ['dense', 'channel', 'block', 'input']

# %% [markdown]
# ### Что будет выведено в `results_df`
#
# `results_df` содержит строку на каждую комбинацию (shape × блоки Triton × sparsity режим/keep_ratio). Столбцы:
# - Время: `time_ms` (Triton), `torch_time_ms`, `speedup_vs_torch`.
# - Ошибки: `mae`, `max`, `rel_l2`.
# - Параметры: `kernel`, `mode`, `keep_ratio`, `block_size` (если есть), `block` и явные BLOCK_M/N/K, NUM_WARPS, NUM_STAGES.
# Файл сохраняется в `notebooks/notebooks/sparsity_kernel_search_results.csv` для дальнейшей фильтрации.

# %%
rows = []
if device != 'cuda':
    print('CUDA not available.')
else:
    combos_per_kernel = len(block_grid) * (1 + 3 * len(keep_ratios))
    total = len(kernel_grid) * combos_per_kernel
    done = 0
    print(f'total combinations: {total}')
    for cfg in kernel_grid:
        torch_conv = build_torch_conv(cfg)
        x = torch.randn(cfg['B'], cfg['in_channels'], cfg['H'], cfg['W'], device=device, dtype=dtype)
        torch_time = benchmark_layer(torch_conv, x)
        torch_out = torch_conv(x).detach().float()
        for block in block_grid:
            apply_block_cfg(block)
            for mode in modes:
                ratios = keep_ratios if mode != 'dense' else [1.0]
                for ratio in ratios:
                    layer = TritonConv2d(
                        in_channels=cfg['in_channels'],
                        out_channels=cfg['out_channels'],
                        kernel_size=cfg['kernel_size'],
                        stride=cfg['stride'],
                        padding=cfg['padding'],
                        dilation=cfg['dilation'],
                        bias=True,
                    ).to(device)
                    clone_weights(layer, torch_conv)
                    apply_sparsity(layer, mode, ratio)
                    time_ms = benchmark_layer(layer, x)
                    with torch.no_grad():
                        y = layer(x).float()
                    diff_stats = calc_diff(torch_out, y)
                    done += 1
                    print(f"[{done}/{total}] kernel={cfg['name']}, block={block['name']}, mode={mode}, keep_ratio={ratio:.2f}, time_ms={time_ms:.3f}, speedup_vs_torch={torch_time/time_ms if time_ms>0 else float('nan'):.3f}", flush=True)
                    rows.append({
                        'kernel': cfg['name'],
                        'B': cfg['B'], 'H': cfg['H'], 'W': cfg['W'], 'k': cfg['kernel_size'],
                        'block': block['name'],
                        'BLOCK_M': block['BLOCK_M'], 'BLOCK_N': block['BLOCK_N'], 'BLOCK_K': block['BLOCK_K'],
                        'NUM_WARPS': block['NUM_WARPS'], 'NUM_STAGES': block['NUM_STAGES'],
                        'mode': mode,
                        'keep_ratio': float(ratio),
                        'time_ms': time_ms,
                        'torch_time_ms': torch_time,
                        'speedup_vs_torch': torch_time / time_ms if time_ms > 0 else float('nan'),
                        'mae': diff_stats['mae'],
                        'max': diff_stats['max'],
                        'rel_l2': diff_stats['rel_l2'],
                    })
results_df = pd.DataFrame(rows)
results_df
# Out:
# total combinations: 4620
# [1/4620] kernel=1x1@56, block=64-64-16/4x2, mode=dense, keep_ratio=1.00, time_ms=0.690, speedup_vs_torch=0.169
# [2/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=1.00, time_ms=0.684, speedup_vs_torch=0.171
# [3/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.85, time_ms=0.863, speedup_vs_torch=0.136
# [4/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.75, time_ms=0.940, speedup_vs_torch=0.124
# [5/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.65, time_ms=0.815, speedup_vs_torch=0.143
# [6/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.50, time_ms=0.741, speedup_vs_torch=0.158
# [7/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.35, time_ms=0.705, speedup_vs_torch=0.166
# [8/4620] kernel=1x1@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.25, time_ms=0.633, speedup_vs_torch=0.185
# [9/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=1.00, time_ms=0.714, speedup_vs_torch=0.164
# [10/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.85, time_ms=0.887, speedup_vs_torch=0.132
# [11/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.75, time_ms=0.835, speedup_vs_torch=0.140
# [12/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.65, time_ms=0.794, speedup_vs_torch=0.147
# [13/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.50, time_ms=0.757, speedup_vs_torch=0.155
# [14/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.35, time_ms=0.704, speedup_vs_torch=0.166
# [15/4620] kernel=1x1@56, block=64-64-16/4x2, mode=block, keep_ratio=0.25, time_ms=0.675, speedup_vs_torch=0.173
# [16/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=1.00, time_ms=0.706, speedup_vs_torch=0.166
# [17/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.85, time_ms=0.818, speedup_vs_torch=0.143
# [18/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.75, time_ms=0.796, speedup_vs_torch=0.147
# [19/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.65, time_ms=0.801, speedup_vs_torch=0.146
# [20/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.50, time_ms=0.778, speedup_vs_torch=0.150
# [21/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.35, time_ms=0.759, speedup_vs_torch=0.154
# [22/4620] kernel=1x1@56, block=64-64-16/4x2, mode=input, keep_ratio=0.25, time_ms=0.758, speedup_vs_torch=0.154
# [23/4620] kernel=1x1@56, block=64-64-32/4x2, mode=dense, keep_ratio=1.00, time_ms=0.705, speedup_vs_torch=0.166
# [24/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=1.00, time_ms=0.690, speedup_vs_torch=0.169
# [25/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.85, time_ms=0.872, speedup_vs_torch=0.134
# [26/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.75, time_ms=0.816, speedup_vs_torch=0.143
# [27/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.65, time_ms=0.806, speedup_vs_torch=0.145
# [28/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.50, time_ms=0.753, speedup_vs_torch=0.155
# [29/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.35, time_ms=0.714, speedup_vs_torch=0.164
# [30/4620] kernel=1x1@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.25, time_ms=0.652, speedup_vs_torch=0.179
# [31/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=1.00, time_ms=0.730, speedup_vs_torch=0.160
# [32/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.85, time_ms=0.883, speedup_vs_torch=0.132
# [33/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.75, time_ms=0.851, speedup_vs_torch=0.137
# [34/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.65, time_ms=0.822, speedup_vs_torch=0.142
# [35/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.50, time_ms=0.774, speedup_vs_torch=0.151
# [36/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.35, time_ms=0.769, speedup_vs_torch=0.152
# [37/4620] kernel=1x1@56, block=64-64-32/4x2, mode=block, keep_ratio=0.25, time_ms=0.707, speedup_vs_torch=0.165
# [38/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=1.00, time_ms=0.750, speedup_vs_torch=0.156
# [39/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.85, time_ms=0.852, speedup_vs_torch=0.137
# [40/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.75, time_ms=0.810, speedup_vs_torch=0.144
# [41/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.65, time_ms=0.822, speedup_vs_torch=0.142
# [42/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.50, time_ms=0.814, speedup_vs_torch=0.144
# [43/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.35, time_ms=0.778, speedup_vs_torch=0.150
# [44/4620] kernel=1x1@56, block=64-64-32/4x2, mode=input, keep_ratio=0.25, time_ms=0.739, speedup_vs_torch=0.158
# [45/4620] kernel=1x1@56, block=64-64-64/4x2, mode=dense, keep_ratio=1.00, time_ms=0.713, speedup_vs_torch=0.164
# [46/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=1.00, time_ms=0.685, speedup_vs_torch=0.171
# [47/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.85, time_ms=0.854, speedup_vs_torch=0.137
# [48/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.75, time_ms=0.813, speedup_vs_torch=0.144
# [49/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.65, time_ms=0.823, speedup_vs_torch=0.142
# [50/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.50, time_ms=0.744, speedup_vs_torch=0.157
# [51/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.35, time_ms=0.730, speedup_vs_torch=0.160
# [52/4620] kernel=1x1@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.25, time_ms=0.653, speedup_vs_torch=0.179
# [53/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=1.00, time_ms=0.699, speedup_vs_torch=0.167
# [54/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.85, time_ms=0.862, speedup_vs_torch=0.136
# [55/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.75, time_ms=0.820, speedup_vs_torch=0.143
# [56/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.65, time_ms=0.774, speedup_vs_torch=0.151
# [57/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.50, time_ms=0.729, speedup_vs_torch=0.160
# [58/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.35, time_ms=0.683, speedup_vs_torch=0.171
# [59/4620] kernel=1x1@56, block=64-64-64/4x2, mode=block, keep_ratio=0.25, time_ms=0.667, speedup_vs_torch=0.175
# [60/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=1.00, time_ms=0.713, speedup_vs_torch=0.164
# [61/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.85, time_ms=0.820, speedup_vs_torch=0.143
# [62/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.75, time_ms=0.796, speedup_vs_torch=0.147
# [63/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.65, time_ms=0.792, speedup_vs_torch=0.148
# [64/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.50, time_ms=0.775, speedup_vs_torch=0.151
# [65/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.35, time_ms=0.759, speedup_vs_torch=0.154
# [66/4620] kernel=1x1@56, block=64-64-64/4x2, mode=input, keep_ratio=0.25, time_ms=0.765, speedup_vs_torch=0.153
# [67/4620] kernel=1x1@56, block=64-128-32/4x2, mode=dense, keep_ratio=1.00, time_ms=0.711, speedup_vs_torch=0.165
# [68/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=1.00, time_ms=0.739, speedup_vs_torch=0.158
# [69/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.85, time_ms=0.919, speedup_vs_torch=0.127
# [70/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.75, time_ms=0.891, speedup_vs_torch=0.131
# [71/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.65, time_ms=0.868, speedup_vs_torch=0.135
# [72/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.50, time_ms=0.777, speedup_vs_torch=0.151
# [73/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.35, time_ms=0.702, speedup_vs_torch=0.167
# [74/4620] kernel=1x1@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.25, time_ms=0.701, speedup_vs_torch=0.167
# [75/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=1.00, time_ms=0.708, speedup_vs_torch=0.165
# [76/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.85, time_ms=0.881, speedup_vs_torch=0.133
# [77/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.75, time_ms=0.839, speedup_vs_torch=0.139
# [78/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.65, time_ms=0.843, speedup_vs_torch=0.139
# [79/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.50, time_ms=0.739, speedup_vs_torch=0.158
# [80/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.35, time_ms=0.731, speedup_vs_torch=0.160
# [81/4620] kernel=1x1@56, block=64-128-32/4x2, mode=block, keep_ratio=0.25, time_ms=0.665, speedup_vs_torch=0.176
# [82/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=1.00, time_ms=0.714, speedup_vs_torch=0.164
# [83/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.85, time_ms=0.811, speedup_vs_torch=0.144
# [84/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.75, time_ms=0.805, speedup_vs_torch=0.145
# [85/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.65, time_ms=0.771, speedup_vs_torch=0.152
# [86/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.50, time_ms=0.759, speedup_vs_torch=0.154
# [87/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.35, time_ms=0.746, speedup_vs_torch=0.157
# [88/4620] kernel=1x1@56, block=64-128-32/4x2, mode=input, keep_ratio=0.25, time_ms=0.749, speedup_vs_torch=0.156
# [89/4620] kernel=1x1@56, block=128-64-32/8x2, mode=dense, keep_ratio=1.00, time_ms=0.690, speedup_vs_torch=0.169
# [90/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=1.00, time_ms=0.728, speedup_vs_torch=0.161
# [91/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.85, time_ms=0.859, speedup_vs_torch=0.136
# [92/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.75, time_ms=0.854, speedup_vs_torch=0.137
# [93/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.65, time_ms=0.788, speedup_vs_torch=0.148
# [94/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.50, time_ms=0.732, speedup_vs_torch=0.160
# [95/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.35, time_ms=0.691, speedup_vs_torch=0.169
# [96/4620] kernel=1x1@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.25, time_ms=0.638, speedup_vs_torch=0.183
# [97/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=1.00, time_ms=0.712, speedup_vs_torch=0.164
# [98/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.85, time_ms=0.922, speedup_vs_torch=0.127
# [99/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.75, time_ms=0.893, speedup_vs_torch=0.131
# [100/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.65, time_ms=0.828, speedup_vs_torch=0.141
# [101/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.50, time_ms=0.733, speedup_vs_torch=0.160
# [102/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.35, time_ms=0.692, speedup_vs_torch=0.169
# [103/4620] kernel=1x1@56, block=128-64-32/8x2, mode=block, keep_ratio=0.25, time_ms=0.657, speedup_vs_torch=0.178
# [104/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=1.00, time_ms=0.707, speedup_vs_torch=0.165
# [105/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.85, time_ms=0.789, speedup_vs_torch=0.148
# [106/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.75, time_ms=0.781, speedup_vs_torch=0.150
# [107/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.65, time_ms=0.766, speedup_vs_torch=0.153
# [108/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.50, time_ms=0.756, speedup_vs_torch=0.155
# [109/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.35, time_ms=0.741, speedup_vs_torch=0.158
# [110/4620] kernel=1x1@56, block=128-64-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.740, speedup_vs_torch=0.158
# [111/4620] kernel=1x1@56, block=128-128-32/8x2, mode=dense, keep_ratio=1.00, time_ms=0.695, speedup_vs_torch=0.168
# [112/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=1.00, time_ms=0.690, speedup_vs_torch=0.169
# [113/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.85, time_ms=0.930, speedup_vs_torch=0.126
# [114/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.75, time_ms=0.821, speedup_vs_torch=0.142
# [115/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.65, time_ms=0.843, speedup_vs_torch=0.139
# [116/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.50, time_ms=0.741, speedup_vs_torch=0.158
# [117/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.35, time_ms=0.740, speedup_vs_torch=0.158
# [118/4620] kernel=1x1@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.25, time_ms=0.648, speedup_vs_torch=0.180
# [119/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=1.00, time_ms=0.710, speedup_vs_torch=0.165
# [120/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.85, time_ms=0.939, speedup_vs_torch=0.125
# [121/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.75, time_ms=0.861, speedup_vs_torch=0.136
# [122/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.65, time_ms=0.841, speedup_vs_torch=0.139
# [123/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.50, time_ms=0.754, speedup_vs_torch=0.155
# [124/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.35, time_ms=0.750, speedup_vs_torch=0.156
# [125/4620] kernel=1x1@56, block=128-128-32/8x2, mode=block, keep_ratio=0.25, time_ms=0.650, speedup_vs_torch=0.180
# [126/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=1.00, time_ms=0.711, speedup_vs_torch=0.164
# [127/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.85, time_ms=0.839, speedup_vs_torch=0.139
# [128/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.75, time_ms=0.803, speedup_vs_torch=0.146
# [129/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.65, time_ms=0.815, speedup_vs_torch=0.143
# [130/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.50, time_ms=0.774, speedup_vs_torch=0.151
# [131/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.35, time_ms=0.768, speedup_vs_torch=0.152
# [132/4620] kernel=1x1@56, block=128-128-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.757, speedup_vs_torch=0.155
# [133/4620] kernel=1x1@56, block=128-128-64/8x2, mode=dense, keep_ratio=1.00, time_ms=0.744, speedup_vs_torch=0.157
# [134/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=1.00, time_ms=0.700, speedup_vs_torch=0.167
# [135/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.85, time_ms=0.906, speedup_vs_torch=0.129
# [136/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.75, time_ms=0.839, speedup_vs_torch=0.139
# [137/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.65, time_ms=0.846, speedup_vs_torch=0.138
# [138/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.50, time_ms=0.758, speedup_vs_torch=0.154
# [139/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.35, time_ms=0.741, speedup_vs_torch=0.158
# [140/4620] kernel=1x1@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.25, time_ms=0.683, speedup_vs_torch=0.171
# [141/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=1.00, time_ms=0.698, speedup_vs_torch=0.167
# [142/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.85, time_ms=0.910, speedup_vs_torch=0.129
# [143/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.75, time_ms=0.837, speedup_vs_torch=0.140
# [144/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.65, time_ms=0.830, speedup_vs_torch=0.141
# [145/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.50, time_ms=0.760, speedup_vs_torch=0.154
# [146/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.35, time_ms=0.750, speedup_vs_torch=0.156
# [147/4620] kernel=1x1@56, block=128-128-64/8x2, mode=block, keep_ratio=0.25, time_ms=0.680, speedup_vs_torch=0.172
# [148/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=1.00, time_ms=0.701, speedup_vs_torch=0.167
# [149/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.85, time_ms=0.814, speedup_vs_torch=0.144
# [150/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.75, time_ms=0.793, speedup_vs_torch=0.147
# [151/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.65, time_ms=0.820, speedup_vs_torch=0.143
# [152/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.50, time_ms=0.804, speedup_vs_torch=0.145
# [153/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.35, time_ms=0.820, speedup_vs_torch=0.143
# [154/4620] kernel=1x1@56, block=128-128-64/8x2, mode=input, keep_ratio=0.25, time_ms=0.790, speedup_vs_torch=0.148
# [155/4620] kernel=1x1@56, block=128-64-32/8x3, mode=dense, keep_ratio=1.00, time_ms=0.703, speedup_vs_torch=0.166
# [156/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=1.00, time_ms=0.703, speedup_vs_torch=0.166
# [157/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.85, time_ms=0.860, speedup_vs_torch=0.136
# [158/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.75, time_ms=0.817, speedup_vs_torch=0.143
# [159/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.65, time_ms=0.785, speedup_vs_torch=0.149
# [160/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.50, time_ms=0.729, speedup_vs_torch=0.161
# [161/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.35, time_ms=0.702, speedup_vs_torch=0.167
# [162/4620] kernel=1x1@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.25, time_ms=0.655, speedup_vs_torch=0.178
# [163/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=1.00, time_ms=0.711, speedup_vs_torch=0.165
# [164/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.85, time_ms=0.887, speedup_vs_torch=0.132
# [165/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.75, time_ms=0.844, speedup_vs_torch=0.139
# [166/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.65, time_ms=0.789, speedup_vs_torch=0.148
# [167/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.50, time_ms=0.767, speedup_vs_torch=0.153
# [168/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.35, time_ms=0.710, speedup_vs_torch=0.165
# [169/4620] kernel=1x1@56, block=128-64-32/8x3, mode=block, keep_ratio=0.25, time_ms=0.660, speedup_vs_torch=0.177
# [170/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=1.00, time_ms=0.704, speedup_vs_torch=0.166
# [171/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.85, time_ms=0.804, speedup_vs_torch=0.145
# [172/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.75, time_ms=0.793, speedup_vs_torch=0.148
# [173/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.65, time_ms=0.788, speedup_vs_torch=0.148
# [174/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=0.793, speedup_vs_torch=0.148
# [175/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=0.759, speedup_vs_torch=0.154
# [176/4620] kernel=1x1@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=0.742, speedup_vs_torch=0.158
# [177/4620] kernel=1x1@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=0.691, speedup_vs_torch=0.169
# [178/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=0.727, speedup_vs_torch=0.161
# [179/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=0.888, speedup_vs_torch=0.132
# [180/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=0.837, speedup_vs_torch=0.140
# [181/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=0.820, speedup_vs_torch=0.143
# [182/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=0.749, speedup_vs_torch=0.156
# [183/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=0.726, speedup_vs_torch=0.161
# [184/4620] kernel=1x1@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=0.664, speedup_vs_torch=0.176
# [185/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=0.710, speedup_vs_torch=0.165
# [186/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=0.972, speedup_vs_torch=0.120
# [187/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=0.834, speedup_vs_torch=0.140
# [188/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=0.802, speedup_vs_torch=0.146
# [189/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=0.756, speedup_vs_torch=0.155
# [190/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=0.723, speedup_vs_torch=0.162
# [191/4620] kernel=1x1@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=0.665, speedup_vs_torch=0.176
# [192/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=0.714, speedup_vs_torch=0.164
# [193/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=0.815, speedup_vs_torch=0.143
# [194/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=0.809, speedup_vs_torch=0.145
# [195/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=0.793, speedup_vs_torch=0.147
# [196/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=0.779, speedup_vs_torch=0.150
# [197/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=0.761, speedup_vs_torch=0.154
# [198/4620] kernel=1x1@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=0.757, speedup_vs_torch=0.155
# [199/4620] kernel=1x1@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=0.706, speedup_vs_torch=0.166
# [200/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=0.705, speedup_vs_torch=0.166
# [201/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.85, time_ms=0.870, speedup_vs_torch=0.135
# [202/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.75, time_ms=0.838, speedup_vs_torch=0.140
# [203/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.65, time_ms=0.805, speedup_vs_torch=0.145
# [204/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.50, time_ms=0.751, speedup_vs_torch=0.156
# [205/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.35, time_ms=0.698, speedup_vs_torch=0.168
# [206/4620] kernel=1x1@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.25, time_ms=0.658, speedup_vs_torch=0.178
# [207/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=1.00, time_ms=0.714, speedup_vs_torch=0.164
# [208/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.85, time_ms=0.887, speedup_vs_torch=0.132
# [209/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.75, time_ms=0.835, speedup_vs_torch=0.140
# [210/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.65, time_ms=0.797, speedup_vs_torch=0.147
# [211/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.50, time_ms=0.747, speedup_vs_torch=0.157
# [212/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.35, time_ms=0.737, speedup_vs_torch=0.159
# [213/4620] kernel=1x1@56, block=64-64-32/2x2, mode=block, keep_ratio=0.25, time_ms=0.658, speedup_vs_torch=0.178
# [214/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=1.00, time_ms=0.704, speedup_vs_torch=0.166
# [215/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.85, time_ms=0.812, speedup_vs_torch=0.144
# [216/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.75, time_ms=0.809, speedup_vs_torch=0.145
# [217/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.65, time_ms=0.803, speedup_vs_torch=0.146
# [218/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.50, time_ms=0.788, speedup_vs_torch=0.149
# [219/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.35, time_ms=0.767, speedup_vs_torch=0.153
# [220/4620] kernel=1x1@56, block=64-64-32/2x2, mode=input, keep_ratio=0.25, time_ms=0.772, speedup_vs_torch=0.152
# [221/4620] kernel=3x3@56, block=64-64-16/4x2, mode=dense, keep_ratio=1.00, time_ms=1.456, speedup_vs_torch=0.214
# [222/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=1.00, time_ms=1.474, speedup_vs_torch=0.211
# [223/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.85, time_ms=1.531, speedup_vs_torch=0.203
# [224/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.75, time_ms=1.691, speedup_vs_torch=0.184
# [225/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.65, time_ms=1.541, speedup_vs_torch=0.202
# [226/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.50, time_ms=1.194, speedup_vs_torch=0.261
# [227/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.35, time_ms=1.094, speedup_vs_torch=0.285
# [228/4620] kernel=3x3@56, block=64-64-16/4x2, mode=channel, keep_ratio=0.25, time_ms=1.151, speedup_vs_torch=0.271
# [229/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=1.00, time_ms=1.540, speedup_vs_torch=0.202
# [230/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.85, time_ms=1.518, speedup_vs_torch=0.205
# [231/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.75, time_ms=1.651, speedup_vs_torch=0.189
# [232/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.65, time_ms=1.445, speedup_vs_torch=0.216
# [233/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.50, time_ms=1.194, speedup_vs_torch=0.261
# [234/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.35, time_ms=1.094, speedup_vs_torch=0.285
# [235/4620] kernel=3x3@56, block=64-64-16/4x2, mode=block, keep_ratio=0.25, time_ms=1.108, speedup_vs_torch=0.281
# [236/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=1.00, time_ms=1.454, speedup_vs_torch=0.214
# [237/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.85, time_ms=1.353, speedup_vs_torch=0.230
# [238/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.75, time_ms=1.333, speedup_vs_torch=0.234
# [239/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.65, time_ms=1.160, speedup_vs_torch=0.268
# [240/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.50, time_ms=1.021, speedup_vs_torch=0.305
# [241/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.35, time_ms=0.897, speedup_vs_torch=0.347
# [242/4620] kernel=3x3@56, block=64-64-16/4x2, mode=input, keep_ratio=0.25, time_ms=0.854, speedup_vs_torch=0.365
# [243/4620] kernel=3x3@56, block=64-64-32/4x2, mode=dense, keep_ratio=1.00, time_ms=1.172, speedup_vs_torch=0.266
# [244/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=1.00, time_ms=1.150, speedup_vs_torch=0.271
# [245/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.85, time_ms=1.278, speedup_vs_torch=0.244
# [246/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.75, time_ms=1.285, speedup_vs_torch=0.242
# [247/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.65, time_ms=1.205, speedup_vs_torch=0.259
# [248/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.50, time_ms=1.052, speedup_vs_torch=0.296
# [249/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.35, time_ms=0.983, speedup_vs_torch=0.317
# [250/4620] kernel=3x3@56, block=64-64-32/4x2, mode=channel, keep_ratio=0.25, time_ms=0.969, speedup_vs_torch=0.321
# [251/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=1.00, time_ms=1.151, speedup_vs_torch=0.271
# [252/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.85, time_ms=1.277, speedup_vs_torch=0.244
# [253/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.75, time_ms=1.283, speedup_vs_torch=0.243
# [254/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.65, time_ms=1.224, speedup_vs_torch=0.254
# [255/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.50, time_ms=1.052, speedup_vs_torch=0.296
# [256/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.35, time_ms=0.963, speedup_vs_torch=0.323
# [257/4620] kernel=3x3@56, block=64-64-32/4x2, mode=block, keep_ratio=0.25, time_ms=0.953, speedup_vs_torch=0.327
# [258/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=1.00, time_ms=1.151, speedup_vs_torch=0.271
# [259/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.85, time_ms=1.146, speedup_vs_torch=0.272
# [260/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.75, time_ms=1.133, speedup_vs_torch=0.275
# [261/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.65, time_ms=0.999, speedup_vs_torch=0.312
# [262/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.50, time_ms=0.933, speedup_vs_torch=0.334
# [263/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.35, time_ms=0.878, speedup_vs_torch=0.355
# [264/4620] kernel=3x3@56, block=64-64-32/4x2, mode=input, keep_ratio=0.25, time_ms=0.837, speedup_vs_torch=0.372
# [265/4620] kernel=3x3@56, block=64-64-64/4x2, mode=dense, keep_ratio=1.00, time_ms=1.044, speedup_vs_torch=0.298
# [266/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=1.00, time_ms=1.048, speedup_vs_torch=0.297
# [267/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.85, time_ms=1.242, speedup_vs_torch=0.251
# [268/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.75, time_ms=1.177, speedup_vs_torch=0.265
# [269/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.65, time_ms=1.188, speedup_vs_torch=0.262
# [270/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.50, time_ms=0.986, speedup_vs_torch=0.316
# [271/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.35, time_ms=0.950, speedup_vs_torch=0.328
# [272/4620] kernel=3x3@56, block=64-64-64/4x2, mode=channel, keep_ratio=0.25, time_ms=0.912, speedup_vs_torch=0.342
# [273/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=1.00, time_ms=1.045, speedup_vs_torch=0.298
# [274/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.85, time_ms=1.230, speedup_vs_torch=0.253
# [275/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.75, time_ms=1.181, speedup_vs_torch=0.264
# [276/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.65, time_ms=1.167, speedup_vs_torch=0.267
# [277/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.50, time_ms=0.997, speedup_vs_torch=0.312
# [278/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.35, time_ms=0.958, speedup_vs_torch=0.325
# [279/4620] kernel=3x3@56, block=64-64-64/4x2, mode=block, keep_ratio=0.25, time_ms=0.914, speedup_vs_torch=0.341
# [280/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=1.00, time_ms=1.044, speedup_vs_torch=0.298
# [281/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.85, time_ms=1.091, speedup_vs_torch=0.286
# [282/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.75, time_ms=1.035, speedup_vs_torch=0.301
# [283/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.65, time_ms=1.207, speedup_vs_torch=0.258
# [284/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.50, time_ms=1.010, speedup_vs_torch=0.309
# [285/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.35, time_ms=0.940, speedup_vs_torch=0.331
# [286/4620] kernel=3x3@56, block=64-64-64/4x2, mode=input, keep_ratio=0.25, time_ms=0.874, speedup_vs_torch=0.356
# [287/4620] kernel=3x3@56, block=64-128-32/4x2, mode=dense, keep_ratio=1.00, time_ms=1.035, speedup_vs_torch=0.301
# [288/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=1.00, time_ms=1.009, speedup_vs_torch=0.309
# [289/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.85, time_ms=1.209, speedup_vs_torch=0.258
# [290/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.75, time_ms=1.145, speedup_vs_torch=0.272
# [291/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.65, time_ms=1.150, speedup_vs_torch=0.271
# [292/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.50, time_ms=1.117, speedup_vs_torch=0.279
# [293/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.35, time_ms=1.099, speedup_vs_torch=0.283
# [294/4620] kernel=3x3@56, block=64-128-32/4x2, mode=channel, keep_ratio=0.25, time_ms=1.031, speedup_vs_torch=0.302
# [295/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=1.00, time_ms=1.074, speedup_vs_torch=0.290
# [296/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.85, time_ms=1.290, speedup_vs_torch=0.241
# [297/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.75, time_ms=1.217, speedup_vs_torch=0.256
# [298/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.65, time_ms=1.214, speedup_vs_torch=0.257
# [299/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.50, time_ms=1.098, speedup_vs_torch=0.284
# [300/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.35, time_ms=1.069, speedup_vs_torch=0.291
# [301/4620] kernel=3x3@56, block=64-128-32/4x2, mode=block, keep_ratio=0.25, time_ms=0.979, speedup_vs_torch=0.318
# [302/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=1.00, time_ms=1.010, speedup_vs_torch=0.308
# [303/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.85, time_ms=1.061, speedup_vs_torch=0.294
# [304/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.75, time_ms=1.006, speedup_vs_torch=0.310
# [305/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.65, time_ms=1.001, speedup_vs_torch=0.311
# [306/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.50, time_ms=0.932, speedup_vs_torch=0.334
# [307/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.35, time_ms=0.888, speedup_vs_torch=0.351
# [308/4620] kernel=3x3@56, block=64-128-32/4x2, mode=input, keep_ratio=0.25, time_ms=0.854, speedup_vs_torch=0.365
# [309/4620] kernel=3x3@56, block=128-64-32/8x2, mode=dense, keep_ratio=1.00, time_ms=1.161, speedup_vs_torch=0.268
# [310/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=1.00, time_ms=1.147, speedup_vs_torch=0.271
# [311/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.85, time_ms=1.492, speedup_vs_torch=0.209
# [312/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.75, time_ms=1.383, speedup_vs_torch=0.225
# [313/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.65, time_ms=1.328, speedup_vs_torch=0.235
# [314/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.50, time_ms=1.025, speedup_vs_torch=0.304
# [315/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.35, time_ms=0.998, speedup_vs_torch=0.312
# [316/4620] kernel=3x3@56, block=128-64-32/8x2, mode=channel, keep_ratio=0.25, time_ms=0.982, speedup_vs_torch=0.317
# [317/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=1.00, time_ms=1.217, speedup_vs_torch=0.256
# [318/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.85, time_ms=1.406, speedup_vs_torch=0.222
# [319/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.75, time_ms=1.307, speedup_vs_torch=0.238
# [320/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.65, time_ms=1.237, speedup_vs_torch=0.252
# [321/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.50, time_ms=1.024, speedup_vs_torch=0.304
# [322/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.35, time_ms=0.975, speedup_vs_torch=0.319
# [323/4620] kernel=3x3@56, block=128-64-32/8x2, mode=block, keep_ratio=0.25, time_ms=0.967, speedup_vs_torch=0.322
# [324/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=1.00, time_ms=1.167, speedup_vs_torch=0.267
# [325/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.85, time_ms=1.135, speedup_vs_torch=0.275
# [326/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.75, time_ms=1.108, speedup_vs_torch=0.281
# [327/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.65, time_ms=1.011, speedup_vs_torch=0.308
# [328/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.50, time_ms=0.941, speedup_vs_torch=0.331
# [329/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.35, time_ms=0.867, speedup_vs_torch=0.359
# [330/4620] kernel=3x3@56, block=128-64-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.819, speedup_vs_torch=0.380
# [331/4620] kernel=3x3@56, block=128-128-32/8x2, mode=dense, keep_ratio=1.00, time_ms=1.013, speedup_vs_torch=0.308
# [332/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=1.00, time_ms=1.013, speedup_vs_torch=0.308
# [333/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.85, time_ms=1.345, speedup_vs_torch=0.231
# [334/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.75, time_ms=1.145, speedup_vs_torch=0.272
# [335/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.65, time_ms=1.264, speedup_vs_torch=0.246
# [336/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.50, time_ms=1.056, speedup_vs_torch=0.295
# [337/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.35, time_ms=1.121, speedup_vs_torch=0.278
# [338/4620] kernel=3x3@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.25, time_ms=0.977, speedup_vs_torch=0.319
# [339/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=1.00, time_ms=1.013, speedup_vs_torch=0.308
# [340/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.85, time_ms=1.340, speedup_vs_torch=0.232
# [341/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.75, time_ms=1.144, speedup_vs_torch=0.272
# [342/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.65, time_ms=1.292, speedup_vs_torch=0.241
# [343/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.50, time_ms=1.059, speedup_vs_torch=0.294
# [344/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.35, time_ms=1.117, speedup_vs_torch=0.279
# [345/4620] kernel=3x3@56, block=128-128-32/8x2, mode=block, keep_ratio=0.25, time_ms=0.985, speedup_vs_torch=0.316
# [346/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=1.00, time_ms=1.014, speedup_vs_torch=0.307
# [347/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.85, time_ms=1.120, speedup_vs_torch=0.278
# [348/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.75, time_ms=1.007, speedup_vs_torch=0.309
# [349/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.65, time_ms=0.997, speedup_vs_torch=0.313
# [350/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.50, time_ms=0.894, speedup_vs_torch=0.348
# [351/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.35, time_ms=0.886, speedup_vs_torch=0.352
# [352/4620] kernel=3x3@56, block=128-128-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.818, speedup_vs_torch=0.381
# [353/4620] kernel=3x3@56, block=128-128-64/8x2, mode=dense, keep_ratio=1.00, time_ms=1.085, speedup_vs_torch=0.287
# [354/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=1.00, time_ms=1.109, speedup_vs_torch=0.281
# [355/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.85, time_ms=1.299, speedup_vs_torch=0.240
# [356/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.75, time_ms=1.179, speedup_vs_torch=0.264
# [357/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.65, time_ms=1.251, speedup_vs_torch=0.249
# [358/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.50, time_ms=1.154, speedup_vs_torch=0.270
# [359/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.35, time_ms=1.168, speedup_vs_torch=0.267
# [360/4620] kernel=3x3@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.25, time_ms=1.013, speedup_vs_torch=0.308
# [361/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=1.00, time_ms=1.042, speedup_vs_torch=0.299
# [362/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.85, time_ms=1.299, speedup_vs_torch=0.240
# [363/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.75, time_ms=1.201, speedup_vs_torch=0.259
# [364/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.65, time_ms=1.240, speedup_vs_torch=0.251
# [365/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.50, time_ms=1.090, speedup_vs_torch=0.286
# [366/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.35, time_ms=1.109, speedup_vs_torch=0.281
# [367/4620] kernel=3x3@56, block=128-128-64/8x2, mode=block, keep_ratio=0.25, time_ms=1.009, speedup_vs_torch=0.309
# [368/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=1.00, time_ms=1.042, speedup_vs_torch=0.299
# [369/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.85, time_ms=1.092, speedup_vs_torch=0.285
# [370/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.75, time_ms=1.026, speedup_vs_torch=0.304
# [371/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.65, time_ms=0.996, speedup_vs_torch=0.313
# [372/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.50, time_ms=0.924, speedup_vs_torch=0.337
# [373/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.35, time_ms=0.884, speedup_vs_torch=0.352
# [374/4620] kernel=3x3@56, block=128-128-64/8x2, mode=input, keep_ratio=0.25, time_ms=0.834, speedup_vs_torch=0.374
# [375/4620] kernel=3x3@56, block=128-64-32/8x3, mode=dense, keep_ratio=1.00, time_ms=1.129, speedup_vs_torch=0.276
# [376/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=1.00, time_ms=1.128, speedup_vs_torch=0.276
# [377/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.85, time_ms=1.264, speedup_vs_torch=0.246
# [378/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.75, time_ms=1.257, speedup_vs_torch=0.248
# [379/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.65, time_ms=1.192, speedup_vs_torch=0.261
# [380/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.50, time_ms=1.023, speedup_vs_torch=0.304
# [381/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.35, time_ms=0.962, speedup_vs_torch=0.324
# [382/4620] kernel=3x3@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.25, time_ms=0.931, speedup_vs_torch=0.334
# [383/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=1.00, time_ms=1.126, speedup_vs_torch=0.276
# [384/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.85, time_ms=1.260, speedup_vs_torch=0.247
# [385/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.75, time_ms=1.257, speedup_vs_torch=0.248
# [386/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.65, time_ms=1.202, speedup_vs_torch=0.259
# [387/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.50, time_ms=1.025, speedup_vs_torch=0.304
# [388/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.35, time_ms=0.959, speedup_vs_torch=0.325
# [389/4620] kernel=3x3@56, block=128-64-32/8x3, mode=block, keep_ratio=0.25, time_ms=0.934, speedup_vs_torch=0.333
# [390/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=1.00, time_ms=1.126, speedup_vs_torch=0.277
# [391/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.85, time_ms=1.113, speedup_vs_torch=0.280
# [392/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.75, time_ms=1.104, speedup_vs_torch=0.282
# [393/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.65, time_ms=0.996, speedup_vs_torch=0.313
# [394/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=0.920, speedup_vs_torch=0.338
# [395/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=0.867, speedup_vs_torch=0.359
# [396/4620] kernel=3x3@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=0.821, speedup_vs_torch=0.379
# [397/4620] kernel=3x3@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=0.979, speedup_vs_torch=0.318
# [398/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=0.977, speedup_vs_torch=0.319
# [399/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=1.195, speedup_vs_torch=0.261
# [400/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=1.116, speedup_vs_torch=0.279
# [401/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=1.146, speedup_vs_torch=0.272
# [402/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=1.032, speedup_vs_torch=0.302
# [403/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=1.020, speedup_vs_torch=0.305
# [404/4620] kernel=3x3@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=0.956, speedup_vs_torch=0.326
# [405/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=0.978, speedup_vs_torch=0.319
# [406/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=1.194, speedup_vs_torch=0.261
# [407/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=1.115, speedup_vs_torch=0.279
# [408/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=1.124, speedup_vs_torch=0.277
# [409/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=1.064, speedup_vs_torch=0.293
# [410/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=1.077, speedup_vs_torch=0.289
# [411/4620] kernel=3x3@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=0.957, speedup_vs_torch=0.325
# [412/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=1.017, speedup_vs_torch=0.306
# [413/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=1.101, speedup_vs_torch=0.283
# [414/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=1.042, speedup_vs_torch=0.299
# [415/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=0.945, speedup_vs_torch=0.329
# [416/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=0.872, speedup_vs_torch=0.357
# [417/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=0.849, speedup_vs_torch=0.367
# [418/4620] kernel=3x3@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=0.815, speedup_vs_torch=0.382
# [419/4620] kernel=3x3@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=1.235, speedup_vs_torch=0.252
# [420/4620] kernel=3x3@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=1.245, speedup_vs_torch=0.250
# ...
# [4510/4620] kernel=3x3_dil2@56, block=128-64-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.848, speedup_vs_torch=0.365
# [4511/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=dense, keep_ratio=1.00, time_ms=1.065, speedup_vs_torch=0.291
# [4512/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=1.00, time_ms=1.062, speedup_vs_torch=0.292
# [4513/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.85, time_ms=1.403, speedup_vs_torch=0.221
# [4514/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.75, time_ms=1.219, speedup_vs_torch=0.254
# [4515/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.65, time_ms=1.307, speedup_vs_torch=0.237
# [4516/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.50, time_ms=1.108, speedup_vs_torch=0.280
# [4517/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.35, time_ms=1.174, speedup_vs_torch=0.264
# [4518/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=channel, keep_ratio=0.25, time_ms=1.025, speedup_vs_torch=0.302
# [4519/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=1.00, time_ms=1.059, speedup_vs_torch=0.293
# [4520/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.85, time_ms=1.429, speedup_vs_torch=0.217
# [4521/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.75, time_ms=1.197, speedup_vs_torch=0.259
# [4522/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.65, time_ms=1.310, speedup_vs_torch=0.237
# [4523/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.50, time_ms=1.125, speedup_vs_torch=0.275
# [4524/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.35, time_ms=1.183, speedup_vs_torch=0.262
# [4525/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=block, keep_ratio=0.25, time_ms=1.030, speedup_vs_torch=0.301
# [4526/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=1.00, time_ms=1.061, speedup_vs_torch=0.292
# [4527/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.85, time_ms=1.175, speedup_vs_torch=0.264
# [4528/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.75, time_ms=1.080, speedup_vs_torch=0.287
# [4529/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.65, time_ms=1.041, speedup_vs_torch=0.298
# [4530/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.50, time_ms=0.940, speedup_vs_torch=0.330
# [4531/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.35, time_ms=0.914, speedup_vs_torch=0.339
# [4532/4620] kernel=3x3_dil2@56, block=128-128-32/8x2, mode=input, keep_ratio=0.25, time_ms=0.836, speedup_vs_torch=0.371
# [4533/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=dense, keep_ratio=1.00, time_ms=1.091, speedup_vs_torch=0.284
# [4534/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=1.00, time_ms=1.094, speedup_vs_torch=0.283
# [4535/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.85, time_ms=1.374, speedup_vs_torch=0.226
# [4536/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.75, time_ms=1.235, speedup_vs_torch=0.251
# [4537/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.65, time_ms=1.289, speedup_vs_torch=0.240
# [4538/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.50, time_ms=1.150, speedup_vs_torch=0.270
# [4539/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.35, time_ms=1.172, speedup_vs_torch=0.264
# [4540/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=channel, keep_ratio=0.25, time_ms=1.072, speedup_vs_torch=0.289
# [4541/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=1.00, time_ms=1.094, speedup_vs_torch=0.283
# [4542/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.85, time_ms=1.381, speedup_vs_torch=0.224
# [4543/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.75, time_ms=1.234, speedup_vs_torch=0.251
# [4544/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.65, time_ms=1.295, speedup_vs_torch=0.239
# [4545/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.50, time_ms=1.149, speedup_vs_torch=0.270
# [4546/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.35, time_ms=1.172, speedup_vs_torch=0.264
# [4547/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=block, keep_ratio=0.25, time_ms=1.067, speedup_vs_torch=0.290
# [4548/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=1.00, time_ms=1.109, speedup_vs_torch=0.279
# [4549/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.85, time_ms=1.136, speedup_vs_torch=0.273
# [4550/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.75, time_ms=1.074, speedup_vs_torch=0.288
# [4551/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.65, time_ms=1.026, speedup_vs_torch=0.302
# [4552/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.50, time_ms=0.993, speedup_vs_torch=0.312
# [4553/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.35, time_ms=0.914, speedup_vs_torch=0.339
# [4554/4620] kernel=3x3_dil2@56, block=128-128-64/8x2, mode=input, keep_ratio=0.25, time_ms=0.869, speedup_vs_torch=0.357
# [4555/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=dense, keep_ratio=1.00, time_ms=1.181, speedup_vs_torch=0.262
# [4556/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=1.00, time_ms=1.172, speedup_vs_torch=0.264
# [4557/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.85, time_ms=1.318, speedup_vs_torch=0.235
# [4558/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.75, time_ms=1.333, speedup_vs_torch=0.232
# [4559/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.65, time_ms=1.248, speedup_vs_torch=0.248
# [4560/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.50, time_ms=1.073, speedup_vs_torch=0.289
# [4561/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.35, time_ms=1.023, speedup_vs_torch=0.303
# [4562/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=channel, keep_ratio=0.25, time_ms=0.987, speedup_vs_torch=0.314
# [4563/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=1.00, time_ms=1.171, speedup_vs_torch=0.265
# [4564/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.85, time_ms=1.312, speedup_vs_torch=0.236
# [4565/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.75, time_ms=1.316, speedup_vs_torch=0.235
# [4566/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.65, time_ms=1.246, speedup_vs_torch=0.249
# [4567/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.50, time_ms=1.074, speedup_vs_torch=0.288
# [4568/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.35, time_ms=1.016, speedup_vs_torch=0.305
# [4569/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=block, keep_ratio=0.25, time_ms=0.988, speedup_vs_torch=0.314
# [4570/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=1.00, time_ms=1.193, speedup_vs_torch=0.260
# [4571/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.85, time_ms=1.158, speedup_vs_torch=0.268
# [4572/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.75, time_ms=1.155, speedup_vs_torch=0.268
# [4573/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.65, time_ms=1.034, speedup_vs_torch=0.300
# [4574/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.50, time_ms=0.960, speedup_vs_torch=0.323
# [4575/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.35, time_ms=0.898, speedup_vs_torch=0.345
# [4576/4620] kernel=3x3_dil2@56, block=128-64-32/8x3, mode=input, keep_ratio=0.25, time_ms=0.850, speedup_vs_torch=0.365
# [4577/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=dense, keep_ratio=1.00, time_ms=1.055, speedup_vs_torch=0.294
# [4578/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=1.00, time_ms=1.032, speedup_vs_torch=0.300
# [4579/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.85, time_ms=1.252, speedup_vs_torch=0.247
# [4580/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.75, time_ms=1.185, speedup_vs_torch=0.261
# [4581/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.65, time_ms=1.183, speedup_vs_torch=0.262
# [4582/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.50, time_ms=1.098, speedup_vs_torch=0.282
# [4583/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.35, time_ms=1.089, speedup_vs_torch=0.285
# [4584/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=channel, keep_ratio=0.25, time_ms=1.015, speedup_vs_torch=0.305
# [4585/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=1.00, time_ms=1.052, speedup_vs_torch=0.295
# [4586/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.85, time_ms=1.248, speedup_vs_torch=0.248
# [4587/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.75, time_ms=1.179, speedup_vs_torch=0.263
# [4588/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.65, time_ms=1.186, speedup_vs_torch=0.261
# [4589/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.50, time_ms=1.086, speedup_vs_torch=0.285
# [4590/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.35, time_ms=1.083, speedup_vs_torch=0.286
# [4591/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=block, keep_ratio=0.25, time_ms=1.028, speedup_vs_torch=0.302
# [4592/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=1.00, time_ms=1.027, speedup_vs_torch=0.302
# [4593/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.85, time_ms=1.087, speedup_vs_torch=0.285
# [4594/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.75, time_ms=1.037, speedup_vs_torch=0.299
# [4595/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.65, time_ms=0.982, speedup_vs_torch=0.316
# [4596/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.50, time_ms=0.911, speedup_vs_torch=0.340
# [4597/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.35, time_ms=0.874, speedup_vs_torch=0.354
# [4598/4620] kernel=3x3_dil2@56, block=64-128-32/4x3, mode=input, keep_ratio=0.25, time_ms=0.824, speedup_vs_torch=0.376
# [4599/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=dense, keep_ratio=1.00, time_ms=1.213, speedup_vs_torch=0.255
# [4600/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=1.00, time_ms=1.239, speedup_vs_torch=0.250
# [4601/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.85, time_ms=1.347, speedup_vs_torch=0.230
# [4602/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.75, time_ms=1.353, speedup_vs_torch=0.229
# [4603/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.65, time_ms=1.262, speedup_vs_torch=0.245
# [4604/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.50, time_ms=1.104, speedup_vs_torch=0.281
# [4605/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.35, time_ms=1.015, speedup_vs_torch=0.305
# [4606/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=channel, keep_ratio=0.25, time_ms=1.026, speedup_vs_torch=0.302
# [4607/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=1.00, time_ms=1.214, speedup_vs_torch=0.255
# [4608/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.85, time_ms=1.351, speedup_vs_torch=0.229
# [4609/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.75, time_ms=1.350, speedup_vs_torch=0.229
# [4610/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.65, time_ms=1.270, speedup_vs_torch=0.244
# [4611/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.50, time_ms=1.109, speedup_vs_torch=0.279
# [4612/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.35, time_ms=1.020, speedup_vs_torch=0.304
# [4613/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=block, keep_ratio=0.25, time_ms=1.039, speedup_vs_torch=0.298
# [4614/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=1.00, time_ms=1.218, speedup_vs_torch=0.254
# [4615/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.85, time_ms=1.183, speedup_vs_torch=0.262
# [4616/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.75, time_ms=1.192, speedup_vs_torch=0.260
# [4617/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.65, time_ms=1.037, speedup_vs_torch=0.299
# [4618/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.50, time_ms=0.963, speedup_vs_torch=0.322
# [4619/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.35, time_ms=0.898, speedup_vs_torch=0.345
# [4620/4620] kernel=3x3_dil2@56, block=64-64-32/2x2, mode=input, keep_ratio=0.25, time_ms=0.871, speedup_vs_torch=0.356
#            kernel   B   H   W  k         block  BLOCK_M  BLOCK_N  BLOCK_K  \
# 0          1x1@56  32  56  56  1  64-64-16/4x2       64       64       16
# 1          1x1@56  32  56  56  1  64-64-16/4x2       64       64       16
# 2          1x1@56  32  56  56  1  64-64-16/4x2       64       64       16
# 3          1x1@56  32  56  56  1  64-64-16/4x2       64       64       16
# 4          1x1@56  32  56  56  1  64-64-16/4x2       64       64       16
# ...           ...  ..  ..  .. ..           ...      ...      ...      ...
# 4615  3x3_dil2@56  16  56  56  3  64-64-32/2x2       64       64       32
# 4616  3x3_dil2@56  16  56  56  3  64-64-32/2x2       64       64       32
# 4617  3x3_dil2@56  16  56  56  3  64-64-32/2x2       64       64       32
# 4618  3x3_dil2@56  16  56  56  3  64-64-32/2x2       64       64       32
# 4619  3x3_dil2@56  16  56  56  3  64-64-32/2x2       64       64       32
#
#       NUM_WARPS  NUM_STAGES     mode  keep_ratio   time_ms  torch_time_ms  \
# 0             4           2    dense        1.00  0.690237       0.116961
# 1             4           2  channel        1.00  0.684175       0.116961
# 2             4           2  channel        0.85  0.862966       0.116961
# 3             4           2  channel        0.75  0.940052       0.116961
# 4             4           2  channel        0.65  0.815452       0.116961
# ...         ...         ...      ...         ...       ...            ...
# 4615          2           2    input        0.75  1.192079       0.309840
# 4616          2           2    input        0.65  1.037353       0.309840
# 4617          2           2    input        0.50  0.962518       0.309840
# 4618          2           2    input        0.35  0.898109       0.309840
# 4619          2           2    input        0.25  0.870830       0.309840
#
#       speedup_vs_torch       mae       max    rel_l2
# 0             0.169451  0.000081  0.001953  0.000349
# 1             0.170952  0.000081  0.001953  0.000349
# 2             0.135534  0.066459  3.164062  0.363663
# 3             0.124420  0.107343  3.164062  0.464506
# 4             0.143431  0.149413  3.164062  0.551657
# ...                ...       ...       ...       ...
# 4615          0.259916  0.220624  1.561493  0.491858
# 4616          0.298683  0.259121  1.747925  0.577678
# 4617          0.321906  0.313619  2.298828  0.698951
# 4618          0.344991  0.360284  2.861572  0.802752
# 4619          0.355798  0.385856  3.080322  0.859654
#
# [4620 rows x 19 columns]

# %% [markdown]
# ### Отбор лучших конфигураций
#
# Здесь результаты сортируются и сохраняются:
# - `sparsity_kernel_search_results.csv` — полный протокол (все комбинации).
# - `sparsity_kernel_best.csv` — по одной лучшей строке на каждый `kernel`, отобранной по минимальному `time_ms` (или максимальному `speedup_vs_torch`, если так настроено), при условии приемлемой ошибки.
# Смотрите в `sparsity_kernel_best.csv` поля `block`, BLOCK_*, `mode`, `keep_ratio` — их можно использовать как готовые настройки для конкретных размерностей задач.

# %%
if not results_df.empty:
    best_df = results_df.sort_values('speedup_vs_torch', ascending= False).groupby('kernel', as_index=False).first()
    display(best_df[['kernel', 'block', 'mode', 'keep_ratio', 'time_ms', 'speedup_vs_torch']])
else:
    print('CUDA not available.')
# Out:
#          kernel           block     mode  keep_ratio    time_ms  \
# 0     11x11@112   64-128-32/4x3    input        0.25   4.055122
# 1     11x11@224   64-128-32/4x2    input        0.25   9.451843
# 2      11x11@56   64-128-32/4x2    input        0.25   1.313570
# 3     13x13@224  128-128-32/8x2    input        0.25   6.089298
# 4        1x1@56    64-64-16/4x2  channel        0.25   0.633467
# 5       3x3@112   64-128-32/4x2    input        0.25   2.235843
# 6        3x3@16   64-128-32/4x3    input        0.25   1.035939
# 7       3x3@224    64-64-64/4x2    block        0.25   5.116416
# 8        3x3@32   64-128-32/4x3    input        0.25   0.950318
# 9       3x3@512    64-64-64/4x2    block        0.25  12.938813
# 10       3x3@56   64-128-32/4x3    input        0.25   0.814714
# 11  3x3_dil2@56   64-128-32/4x3    input        0.25   0.824114
# 12   3x3_s2@112   64-128-32/4x2    input        0.25   0.835604
# 13      5x5@112   64-128-32/4x3    input        0.25   3.134382
# 14       5x5@32   64-128-32/4x3    input        0.25   1.305682
# 15       5x5@56  128-128-32/8x2    input        0.25   1.024881
# 16      7x7@112   64-128-32/4x3    input        0.25   3.260621
# 17      7x7@224   64-128-32/4x2    input        0.25   8.698839
# 18       7x7@32   64-128-32/4x3    input        0.25   1.860874
# 19      7x7@512   64-128-32/4x3    input        0.25  16.074220
# 20       7x7@56   64-128-32/4x2    input        0.25   1.309507
#
#     speedup_vs_torch
# 0           1.156814
# 1           0.972255
# 2           1.029903
# 3           1.051223
# 4           0.184637
# 5           0.548419
# 6           1.016548
# 7           0.457800
# 8           0.658760
# 9           0.466389
# 10          0.382294
# 11          0.375967
# 12          0.455528
# 13          0.793422
# 14          1.059541
# 15          0.623264
# 16          0.942089
# 17          0.687049
# 18          1.353994
# 19          0.695449
# 20          0.801538

# %%
if not results_df.empty:
    out_all = Path('notebooks/sparsity_kernel_search_results.csv')
    out_best = Path('notebooks/sparsity_kernel_best.csv')
    results_df.to_csv(out_all, index=False)
    results_df.sort_values('time_ms', ascending=True).groupby('kernel', as_index=False).first().to_csv(out_best, index=False)
    print('saved:', out_all)
    print('saved:', out_best)
else:
    print('result dataframe is empty.')
# Out:
# saved: notebooks/sparsity_kernel_search_results.csv
# saved: notebooks/sparsity_kernel_best.csv

# %% [markdown]
# ### Как интерпретировать “best” выборку
#
# Показаны лучшие конфигурации по каждой задаче `kernel`. Обращайте внимание на:
# - `speedup_vs_torch`: >1 — ускорение, <1 — проигрыш.
# - Ошибки (`mae`, `rel_l2`): должны оставаться низкими (обычно 1e-4–1e-3 для fp16).
# - `mode`/`keep_ratio`: какие режимы разрежения реально помогают на данном размере.
# - `block`: совпадение BLOCK_M/N/K с формой задачи (не всегда крупные блоки дают выигрыш при малом K).
# Используйте эти строки как шпаргалку для дальнейших бенчей или фиксации параметров в коде.

# %%
import pandas as pd
from pathlib import Path

csv_path = Path("notebooks/sparsity_kernel_search_results.csv")

if csv_path.exists():
    results_df = pd.read_csv(csv_path)
    print(f"Loaded: {csv_path}")
else:
    raise FileNotFoundError(f"CSV not found: {csv_path}")
df = results_df.copy()

# === 1) Топ-3 для input ===
top3_input = (
    df[df["mode"] == "input"]
    .sort_values("speedup_vs_torch", ascending=False)
    .head(3)
)

# === 2) Топ-1 для block ===
top1_block = (
    df[df["mode"] == "block"]
    .sort_values("speedup_vs_torch", ascending=False)
    .head(1)
)

# === 3) Топ-1 для channel ===
top1_channel = (
    df[df["mode"] == "channel"]
    .sort_values("speedup_vs_torch", ascending=False)
    .head(1)
)

slide_df = pd.concat([top3_input, top1_block, top1_channel], ignore_index=True)

slide_df = slide_df[[
    "kernel", "block", "mode", "keep_ratio",
    "time_ms", "speedup_vs_torch"
]]

slide_df = slide_df.set_index(["kernel", "block", "mode", "keep_ratio"])

slide_df
# Out:
# Loaded: notebooks/sparsity_kernel_search_results.csv
#                                            time_ms  speedup_vs_torch
# kernel block          mode    keep_ratio
# 7x7@32 64-128-32/4x3  input   0.25        1.860874          1.353994
#        64-128-32/4x2  input   0.25        1.899889          1.326189
#        128-128-32/8x2 input   0.25        1.902182          1.324590
# 3x3@16 64-128-32/4x3  block   0.25        1.156465          0.910604
#                       channel 0.25        1.161277          0.906830
